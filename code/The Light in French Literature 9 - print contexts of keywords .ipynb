# %%
import os
import pandas as pd
from pathlib import Path
import textdistance
import re

from tqdm.notebook import tqdm
tqdm.pandas()

# %% [markdown]
# # Get data

# %%
input_dir = Path.cwd() / '../data/csv_files' # input directory
df = pd.read_csv(input_dir /'text_data230826.csv', sep='|')

# %%
df
# Out:
#      year          author                                              title  \
# 0    1838          Balzac  Splendeurs et misères des courtisanes 1 Esther...
# 1    1838          Balzac  Splendeurs et misères des courtisanes 2 A comb...
# 2    1838          Balzac  Splendeurs et misères des courtisanes 3 Où mèn...
# 3    1838          Balzac  Splendeurs et misères des courtisanes 4 La der...
# 4    1842          Balzac                                    La Rabouilleuse
# ..    ...             ...                                                ...
# 96   1910         Colette                                       La Vagabonde
# 97   1910  DelarueMardrus                                Comme tout le monde
# 98   1910      Maupassant               Les Dimanches d'un bourgeois à Paris
# 99   1911          Daudet                                    Rose et Ninette
# 100  1913          Proust                              Du côté de chez Swann
#
#                                                   text  \
# 0    SPLENDEURS ET MISÈRESDES COURTISANES   Laissez...
# 1    Depuis huit jours, Nucingen allait marchander ...
# 2    Le lendemain, à six heures, deux voitures mené...
# 3    — Qu’y a-t-il, Madeleine? dit madame Camusot e...
# 4    LES CÉLIBATAIRES. Voici, mon cher Nodier, un o...
# ..                                                 ...
# 96   LA VAGABONDE \n\n\n\nParu dans Le Livre de Poc...
# 97   Première partie     C’est un wagon de deuxième...
# 98   Monsieur Patissot, né à Paris, après avoir fai...
# 99   au poëte et au philosophe, je dédie cette page...
# 100  À MONSIEUR GASTON CALMETTE        PREMIÈRE PAR...
#
#                                             clean_text
# 0    splendeurs et misèresdes courtisanes laissez-m...
# 1    depuis huit jours nucingen allait marchander l...
# 2    le lendemain à six heures deux voitures menées...
# 3    qu’y a-t-il madeleine dit madame camusot en vo...
# 4    les célibataires voici mon cher nodier un ouvr...
# ..                                                 ...
# 96   la vagabonde paru dans le livre de poche l'ing...
# 97   première partie c’est un wagon de deuxième cla...
# 98   monsieur patissot né à paris après avoir fait ...
# 99   au poëte et au philosophe je dédie cette page ...
# 100  à monsieur gaston calmette première partiecomb...
#
# [101 rows x 5 columns]

# %%
# The function called 'get_sentenses' takes a DataFrame and a search term as input.
# It runs through each novel and returns the sentences that holds the search term 

def find_word(search_term, text):
    # Create a regular expression pattern to match the word with optional plural forms
    pattern = r'\b{}\b'.format(re.escape(search_term))

    # Search for the pattern in the text
    if re.search(pattern, text, re.IGNORECASE):
        return True
    else:
        return False 
    
    
def get_sentenses(data_frame, search_term):
         
    # Iterate over rows using iterrows()
    for index, row in data_frame.iterrows():
        sent_list = row['text'].split('.')
        for sent in sent_list:
            search = find_word(search_term, sent)
            # Check if the search term exists in the current paragraph
            if search == True:
                # Retrieve author and title information from the current row
                au = row['author']
                ti = row['title']
                # Print a separator line
                print('*' * 20)
                # Print a message indicating where the search term was found
                print(f'In {ti.upper()} by {au.upper()}, the word {search_term.upper()} is in this sentence:\n\n {sent}')
                print('\n')

# Call the 'get_paragraphs' function with the DataFrame 'df' and the search term 'nightingale'
get_sentenses(df, 'battement de cœur')
# Out:
# ********************
# In SPLENDEURS ET MISÈRES DES COURTISANES 2 A COMBIEN L'AMOUR REVIENT AUX VIEILLARDS by BALZAC, the word BATTEMENT DE CŒUR is in this sentence:
#
#   Toujours amoureuse de son mari, elle respectait en lui l’homme de talent assez modeste pour renoncer  au tapage de la gloire; enfin, pour la peindre, il suffit peut-être  de dire que, dans toute sa vie, elle n’avait pas à compter un seul  battement de cœur qui ne fût inspiré par ses enfants ou par son mari
#
#
# ********************
# In LE COMPTE DE MONTE CRISTO by DUMAS, the word BATTEMENT DE CŒUR is in this sentence:
#
#     Dantès vit avec un battement de cœur joyeux que ce  plâtre se détachait par fragments; ces fragments étaient  presque des atomes, c’est vrai; mais au bout d’une  demi-heure, cependant, Dantès en avait détaché une poignée à peu près
#
#
# ********************
# In LES TROIS MOUSQUETAIRES by DUMAS, the word BATTEMENT DE CŒUR is in this sentence:
#
#    Il se hâta de redescendre sur la route avec un horrible battement de cœur; il voulait voir s’il ne trouverait pas d’autres traces de violence
#
#
# ********************
# In CARMEN by MÉRIMÉE, the word BATTEMENT DE CŒUR is in this sentence:
#
#     De retour à la maison, elle courut à la fenêtre avec un battement de cœur; l’officier était à sa place habituelle, fixant sur elle un regard ardent
#
#
# ********************
# In LA DAME AUX CAMÉLIAS by DUMAS, the word BATTEMENT DE CŒUR is in this sentence:
#
#
#
# — Savez-vous que c'est très-beau? Eh bien! que
#
# faut-il que je fasse pour reconnaître ce grand amour?
#
# — Il faut m'aimer un peu, dis-je avec un battement de cœur qui m'empêchait presque de parler; car, malgré les sourires demi-moqueurs dont elle avait accompagné toute cette conversation, il me semblait que Marguerite commençait à partager mon trouble, et que j'approchais de l'heure attendue depuis si longtemps
#
#
# ********************
# In LA DAME AUX CAMÉLIAS by DUMAS, the word BATTEMENT DE CŒUR is in this sentence:
#
#   Quant à moi, un violent battement de cœur m'ébranla la poitrine; mais je parvins à donner une expression froide à mon visage, et je saluai froidement mon ancienne maîtresse, qui rejoignit presque aussitôt sa voiture, dans laquelle elle monta avec son amie
#
#
# ********************
# In LE CAPITAINE FRACASSE by GAUTIER, the word BATTEMENT DE CŒUR is in this sentence:
#
#   Le Léandre, raccommodant d’un petit peigne d’écaille l’économie un peu compromise de sa perruque, se demandait, avec un battement de cœur, si ce féerique manoir renfermait une châtelaine
#
#
# ********************
# In LE CAPITAINE FRACASSE by GAUTIER, the word BATTEMENT DE CŒUR is in this sentence:
#
#   Léandre avait été aperçu par l’enfant et le cocher; il s’avança donc d’un air délibéré que démentait intérieurement un fort battement de cœur, et il monta dans la voiture avec l’intrépidité apparente d’un Galaor
#
#
# ********************
# In UN DIVORCE by LÉO, the word BATTEMENT DE CŒUR is in this sentence:
#
#    Une demi-minute de silence s’écoula, pendant laquelle un battement de cœur la prit à la pensée qu’il n’était peut-être pas là, qu’elle ne pourrait pas lui parler
#
#
# ********************
# In L'ÉDUCATION SENTIMENTALE by FLAUBERT, the word BATTEMENT DE CŒUR is in this sentence:
#
#    Il eut un battement de cœur quand Rosanette, accompagnée de Frédéric, arriva chez lui pour la première séance
#
#
# ********************
# In L'ÉDUCATION SENTIMENTALE by FLAUBERT, the word BATTEMENT DE CŒUR is in this sentence:
#
#    — «Ah! on casse quelques bourgeois», dit Frédéric tranquillement, car il y a des situations où l’homme le moins cruel est si détaché des autres, qu’il verrait périr le genre humain sans un battement de cœur
#
#
# ********************
# In L'AMÉRICAIN À PARIS TOME 1 by JAMES, the word BATTEMENT DE CŒUR is in this sentence:
#
#
#
# Newman attendit, non sans un certain battement de cœur
#
#
# ********************
# In BOUVARD ET PÉCUCHET by FLAUBERT, the word BATTEMENT DE CŒUR is in this sentence:
#
#    Alors Pécuchet fut libre!  Avec quelle impatience il attendait la sortie de Bouvard! Quel battement de cœur, dès que la porte était refermée!  Mélie travaillait sur un guéridon, près de la fenêtre, à la clarté d’une chandelle; de temps à autre, elle cassait son fil avec ses dents, puis clignait les yeux, pour l’ajuster dans la fente de l’aiguille
#
#
# ********************
# In MISS HARRIET by MAUPASSANT, the word BATTEMENT DE CŒUR is in this sentence:
#
#  »  Il eut un battement de cœur et demeura tout  ému: «Ah! vraiment
#
#
# ********************
# In LA JOIE DE VIVRE by ZOLA, the word BATTEMENT DE CŒUR is in this sentence:
#
#   Il vivait dans l’attente du malheur, sursautant à chaque porte ouverte trop fort, pris d’un battement de cœur violent à la réception d’une lettre
#
#
# ********************
# In LE DISCIPLE by BOURGET, the word BATTEMENT DE CŒUR is in this sentence:
#
#   J’ai constamment éprouvé, par exemple, une horreur singulière pour l’action,  si faible fût-elle, au point que de faire une simple visite me causait autrefois un battement de cœur, que les plus légers exercices physiques m’étaient intolérables, que d’entrer en lutte ouverte  avec une autre personne, même pour discuter  mes idées les plus chères, m’apparait, encore  aujourd’hui, chose presque impossible
#
#
# ********************
# In LE DISCIPLE by BOURGET, the word BATTEMENT DE CŒUR is in this sentence:
#
#   Je ne pus me retenir d’écouter avec ce battement de cœur que m’a longtemps donné l’idée de ma personnalité  jugée par les autres
#
#
# ********************
# In LA MAISON DU PÉCHÉ by TINAYRE, the word BATTEMENT DE CŒUR is in this sentence:
#
#     — Vous ne voulez pas me répondre?   — Que sais-je?…  Il eut un vif battement de cœur
#
#
# ********************
# In LES EBLOUISSEMENTS by NOUAILLES, the word BATTEMENT DE CŒUR is in this sentence:
#
#   Nulle ombre ne ternit ce calme long, égal ; L’azur a l’éclat net et dur d’un minéral ; La verdure est d’un vert trop doux, plus doux encore… Chaque arbre est enroulé d’une liquide aurore ; Un geai semble emporté vers la claire hauteur Par la force et l’élan d’un battement de cœur
#
#
# ********************
# In LE BACHELIER by VALLÉS, the word BATTEMENT DE CŒUR is in this sentence:
#
#
#
# En remettant le pied sur le sol de Paris, j’ai de nouveau pourtant un petit battement de cœur
