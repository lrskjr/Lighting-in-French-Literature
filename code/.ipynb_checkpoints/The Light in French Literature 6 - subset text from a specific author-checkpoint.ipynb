# %%
import re
import os
import pandas as pd
from pathlib import Path

# %%
input_dir = Path.cwd() / '../data/csv_files' # input directory
df = pd.read_csv(input_dir /'text_data230826.csv', sep='|')

# %%
all_zola = ' '.join(df[df['author'] == 'Zola']['text'])
all_balzac = ' '.join(df[df['author'] == 'Balzac']['text'])

output_dir = Path.cwd() / '../data' # input directory
with open(output_dir / 'all_of_zola.txt', 'w', encoding='utf-8-sig') as f:
    f.write(all_zola)
    
with open(output_dir / 'all_of_balzac.txt', 'w', encoding='utf-8-sig') as f:
    f.write(all_balzac)

# %%
# Group by 'author' and join the text strings using a space as a separator
grouped_df = df.groupby('author')['text'].agg(' '.join).reset_index()

# 'grouped_df' now contains the joined text strings for each author
grouped_df
# Out:
#             author                                               text
# 0           Audoux  — ROMAN —   ────   Préface d’OCTAVE MIRBEAU   ...
# 1           Balzac  SPLENDEURS ET MISÈRESDES COURTISANES   Laissez...
# 2       Baudelaire  —— PARIS. — IMP. SIMON RAÇON ET COMP., RUE D’E...
# 3          Bourget  C’est à toi que je veux dédier ce livre, jeune...
# 4            Bovet  AUTOUR DE L'ÉTENDARD\n\nLa mutine tête blonde ...
# 5          Colette  Préambule\nÀ l’âge de 20 ans, en 1893, Colette...
# 6           Daudet  LES ROIS EN EXIL\n\nVoici bien certainement ce...
# 7   DelarueMardrus  Première partie     C’est un wagon de deuxième...
# 8          Dickens  LIVRE PREMIER\n\nRESSUSCITÉ\nCHAPITRE I\n\n177...
# 9            Dumas  Le 24 février 1815, la vigie de Notre-Dame de ...
# 10        Flaubert  Éditions définitive suivie des réquisitoires, ...
# 11          France  À LECONTE DE LISLE\n\nAUTEUR DES POÈMES ANTIQU...
# 12           Féval  LES\n\nNUITS DE PARIS\n\n\nPREMIÈRE NUIT\n\nGA...
# 13         Gautier  Voici un roman dont l’annonce figurait, il y a...
# 14             Gyp  La marquise de Bracieux travaillait pour  ses ...
# 15            Hugo  En 1815, M. Charles-François-Bienvenu Myriel é...
# 16        Huysmans  ‌ J.-K. HUYSMANS  -  A REBOURS  AVEC  UNE PRÉF...
# 17           James  L'AMÉRICAIN A PARIS\n\nCHAPITRE PREMIER\n\nPar...
# 18        Laforgue  LES COMPLAINTES\n\nLES\n\nCOMPLAINTES\n\nPAR\n...
# 19             Léo  UN DIVORCE   — Voilà de ces nouvelles qui écra...
# 20        Mallarmé  Les Poésies de S. Mallarmé\nEdmond Deman, libr...
# 21      Maupassant  La Maison Tellier     LA MAISON TELLIER On all...
# 22         Mérimée  L’ABBÉ AUBAIN — LA DAME DE PIQUE — LES BOHÉMIE...
# 23          Nerval  EL DESDICHADO\n\nJe suis le ténébreux, — le ve...
# 24       Nouailles  LE PAYS Ma France, quand on a nourri son cœur ...
# 25          Proust  TEXTE INTÉGRAL\n\nÀ MON AMI WILLIE HEATH\n\nMo...
# 26       Prudhomme  ﻿  Mon cher ami,   Quand je vous livre mon poè...
# 27        Rachilde  Nous donnons à nos lecteurs une réédition défi...
# 28         Rimbaud  Poésies\n\n\n\n\nLes Étrennes des Orphelins\n\...
# 29             Sue  Les Mystères de Paris (texte intégral):LES MYS...
# 30         Tinayre  LA     PARIS   CALMANN-LÉVY, ÉDITEURS    blanc...
# 31          Vallès  L’ENFANT       Ai-je été nourri par ma mère? E...
# 32          Vallés  à tous ceux qui, victimes de l’injustice socia...
# 33        Verlaine  Volume I\n\n\n\nPaul Verlaine\n\n\n\n\n\nVanie...
# 34           Verne  I Le 24 mai 1863, un dimanche, mon oncle, le p...
# 35          Vivien  ────       PARIS   ALPHONSE LEMERRE, ÉDITEUR  ...
# 36            Zola  LA FAUTE\nDE\nL’ABBÉ MOURET\n\n\nLIVRE PREMIER...

# %%
print (grouped_df.at[4, 'text'][0:1000])
# Out:
# AUTOUR DE L'ÉTENDARD
#
# La mutine tête blonde de Suzanne Sabatier se montra dans l'entre-bâillement de la porte. « As-tu fini, Marthe, ou faut-il que je t'aide avant de passer ma robe?
#
# Ce n'est pas la peine, répondit l'aînée, encore en peignoir d'indienne, devant qui la pyramide de sandwiches montait dans un plat de &ïence persane. Encore deux ou trois et je vais m'habiller.
#
# J'ai arrangé les fleurs et donné le coup de fion général. Comme cela, nous demeurons chacune dans nos attributions toi l'utile, moi l'agréable, et Lucie le farniente. » Dans la voix claire où toujours perçait un rire argentin, il n'y avait aucune intention de reproche. Tranquille, du fond de la chambre qu'elle occupait en commun avec sa jeune sœur, et où, devant un miroir, elle achevait sa toilette, la cadette remarqua
#
# <
#
# « Puisque vous vous partagez la besogne, je n'ai rien à faire.
#
# A moins que ce soit parce que tu ne fais rien que nous nous chargeons du reste.
#
# Au lieu de vous taquiner, mes enfants, vous feriez
