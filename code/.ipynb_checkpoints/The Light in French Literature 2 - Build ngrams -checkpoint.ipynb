# %%
import os
import pandas as pd
from pathlib import Path
import textdistance

from tqdm.notebook import tqdm
tqdm.pandas()


from nltk import word_tokenize
from nltk.collocations import BigramCollocationFinder, TrigramCollocationFinder
from nltk.metrics import BigramAssocMeasures, TrigramAssocMeasures
from nltk.stem.snowball import SnowballStemmer

# %% [markdown]
# # Get data

# %%
input_dir = Path.cwd() / '../data/csv_files' # input directory
df = pd.read_csv(input_dir /'text_data230826.csv', sep='|')

# %%
df
# Out:
#      year          author                                              title  \
# 0    1838          Balzac  Splendeurs et misères des courtisanes 1 Esther...
# 1    1838          Balzac  Splendeurs et misères des courtisanes 2 A comb...
# 2    1838          Balzac  Splendeurs et misères des courtisanes 3 Où mèn...
# 3    1838          Balzac  Splendeurs et misères des courtisanes 4 La der...
# 4    1842          Balzac                                    La Rabouilleuse
# ..    ...             ...                                                ...
# 96   1910         Colette                                       La Vagabonde
# 97   1910  DelarueMardrus                                Comme tout le monde
# 98   1910      Maupassant               Les Dimanches d'un bourgeois à Paris
# 99   1911          Daudet                                    Rose et Ninette
# 100  1913          Proust                              Du côté de chez Swann
#
#                                                   text  \
# 0    SPLENDEURS ET MISÈRESDES COURTISANES   Laissez...
# 1    Depuis huit jours, Nucingen allait marchander ...
# 2    Le lendemain, à six heures, deux voitures mené...
# 3    — Qu’y a-t-il, Madeleine? dit madame Camusot e...
# 4    LES CÉLIBATAIRES. Voici, mon cher Nodier, un o...
# ..                                                 ...
# 96   LA VAGABONDE \n\n\n\nParu dans Le Livre de Poc...
# 97   Première partie     C’est un wagon de deuxième...
# 98   Monsieur Patissot, né à Paris, après avoir fai...
# 99   au poëte et au philosophe, je dédie cette page...
# 100  À MONSIEUR GASTON CALMETTE        PREMIÈRE PAR...
#
#                                             clean_text
# 0    splendeurs et misèresdes courtisanes laissez-m...
# 1    depuis huit jours nucingen allait marchander l...
# 2    le lendemain à six heures deux voitures menées...
# 3    qu’y a-t-il madeleine dit madame camusot en vo...
# 4    les célibataires voici mon cher nodier un ouvr...
# ..                                                 ...
# 96   la vagabonde paru dans le livre de poche l'ing...
# 97   première partie c’est un wagon de deuxième cla...
# 98   monsieur patissot né à paris après avoir fait ...
# 99   au poëte et au philosophe je dédie cette page ...
# 100  à monsieur gaston calmette première partiecomb...
#
# [101 rows x 5 columns]

# %% [markdown]
# ## Remove stopwords

# %%
# get stop words list
input_dir = Path.cwd() / '../data/stopwords' # input directory
with open(input_dir  / 'fr_stopwords.txt', 'r', encoding='utf-8-sig') as f:
    stopwords =  f.read()

stopword_list = stopwords.split('\n')

def remove_stopwords(text_string, stopword_list):
    
    tokens = text_string.split(' ')

    wo_stopword = [i for i in tokens if i not in stopword_list]
    
    return ' '.join(wo_stopword)

# %%
df['clean_text_wo_stopwords'] = df['clean_text'].progress_apply(lambda x : remove_stopwords(x, stopword_list))
# Out:
#   0%|          | 0/101 [00:00<?, ?it/s]

# %%
df
# Out:
#      year          author                                              title  \
# 0    1838          Balzac  Splendeurs et misères des courtisanes 1 Esther...
# 1    1838          Balzac  Splendeurs et misères des courtisanes 2 A comb...
# 2    1838          Balzac  Splendeurs et misères des courtisanes 3 Où mèn...
# 3    1838          Balzac  Splendeurs et misères des courtisanes 4 La der...
# 4    1842          Balzac                                    La Rabouilleuse
# ..    ...             ...                                                ...
# 96   1910         Colette                                       La Vagabonde
# 97   1910  DelarueMardrus                                Comme tout le monde
# 98   1910      Maupassant               Les Dimanches d'un bourgeois à Paris
# 99   1911          Daudet                                    Rose et Ninette
# 100  1913          Proust                              Du côté de chez Swann
#
#                                                   text  \
# 0    SPLENDEURS ET MISÈRESDES COURTISANES   Laissez...
# 1    Depuis huit jours, Nucingen allait marchander ...
# 2    Le lendemain, à six heures, deux voitures mené...
# 3    — Qu’y a-t-il, Madeleine? dit madame Camusot e...
# 4    LES CÉLIBATAIRES. Voici, mon cher Nodier, un o...
# ..                                                 ...
# 96   LA VAGABONDE \n\n\n\nParu dans Le Livre de Poc...
# 97   Première partie     C’est un wagon de deuxième...
# 98   Monsieur Patissot, né à Paris, après avoir fai...
# 99   au poëte et au philosophe, je dédie cette page...
# 100  À MONSIEUR GASTON CALMETTE        PREMIÈRE PAR...
#
#                                             clean_text  \
# 0    splendeurs et misèresdes courtisanes laissez-m...
# 1    depuis huit jours nucingen allait marchander l...
# 2    le lendemain à six heures deux voitures menées...
# 3    qu’y a-t-il madeleine dit madame camusot en vo...
# 4    les célibataires voici mon cher nodier un ouvr...
# ..                                                 ...
# 96   la vagabonde paru dans le livre de poche l'ing...
# 97   première partie c’est un wagon de deuxième cla...
# 98   monsieur patissot né à paris après avoir fait ...
# 99   au poëte et au philosophe je dédie cette page ...
# 100  à monsieur gaston calmette première partiecomb...
#
#                                clean_text_wo_stopwords
# 0    splendeurs misèresdes courtisanes laissez-moi ...
# 1    jours nucingen allait marchander livraison qu’...
# 2    lendemain heures voitures menées poste appelée...
# 3    qu’y a-t-il madeleine dit madame camusot voyan...
# 4    célibataires nodier ouvrage faits soustraits l...
# ..                                                 ...
# 96   vagabonde paru livre poche l'ingénue libertine...
# 97   partie c’est wagon classe route long train noi...
# 98   monsieur patissot né paris d’autres mauvaises ...
# 99   poëte philosophe dédie page divorcé jours l’iv...
# 100  monsieur gaston calmette partiecombray couché ...
#
# [101 rows x 6 columns]

# %%
def build_NGrams(text_string, n_grams=2):
    
    # split text sting
    wordlist = text_string.split(' ')
    
    
    # build ngrams    
    ngrams_list = [wordlist[i:i+n_grams] for i in range(len(wordlist)-(n_grams-1))]
    
    new_ngrams_list = [' '.join(list(set(i))) for i in ngrams_list]
    
    
    return new_ngrams_list

# %%
# Build bigrams  

author = 'Balzac'

text_string = ' '.join(df[df['author'] == author]['clean_text_wo_stopwords'])

bigrams = build_NGrams(text_string, n_grams=2)

# get keyword list
input_dir = Path.cwd() / '../data/key_word_lists' # input directory
with open(input_dir  / 'emotion_list.txt', 'r', encoding='utf-8-sig') as f:
    keywords =  f.read().split()
    
match = []
for word in keywords:
    for pair in bigrams:
        if word in pair:
            match.append(pair)

# %%
match
# Out:
# ['abattue torpille',
#  'abattue coup',
#  'abattue fille',
#  'abattue linges',
#  'abattu peuplier',
#  'abattu paysage',
#  'abattu coupable',
#  'abattu laissait',
#  'abattue mortellerie',
#  'abattue entière',
#  'abattu coupables',
#  'abattu main',
#  'abattu collin',
#  'abattu violence',
#  'conciergerie abattu',
#  'abattu douleur',
#  'abattu homme',
#  'mort abattu',
#  'abattue femme',
#  'abattue mourante',
#  'abattu scélérat',
#  'abattu l’homme',
#  'm’a abattu',
#  'sphère abattu',
#  'abattue fut',
#  'abattue colonne',
#  'abattu aurait',
#  'abattu tête',
#  'abattu max',
#  'fièvre abattu',
#  'sombre très-abattu',
#  'affaissé…—hélas très-abattu',
#  'abattu brésilien',
#  'abattu religion',
#  'abattus yeux',
#  'abattus amie',
#  'abattu malade',
#  'abattu trouva',
#  'abattu rêverie',
#  'coups abattu',
#  'résiste l’abrutissement',
#  'l’espèce l’abrutissement',
#  'devine l’agonie',
#  'l’agonie misère',
#  'comédie agonie',
#  'agonie l’a',
#  'dit l’agonie',
#  'l’agonie vingt-quatre',
#  'entendait l’agonie',
#  'pauvre l’agonie',
#  'déploré l’agonie',
#  'l’empereur l’agonie',
#  'présence agonie',
#  'neveu agonie',
#  'maladie l’agonie',
#  'pauvre l’agonie',
#  'commença agonie',
#  'mourut agonie',
#  'convulsions l’agonie',
#  'éteignit l’agonie',
#  'honteuses agonies',
#  'agonies misère',
#  'senti agonie',
#  'rêve agonie',
#  'désespoir l’agonie',
#  'l’agonie l’honneur',
#  'qu’à l’agonie',
#  'l’agonie monsieur',
#  'l’affreuse agonie',
#  'd’une agonie',
#  'l’agonie veille',
#  'l’agonie voyait',
#  'inquiet agonie',
#  'j’ai agonie',
#  'poitrinaire agonie',
#  'voyez-vous agonie',
#  'humain l’agonie',
#  'l’agonie sagesse',
#  'agonie philosophie',
#  'viendra agonie',
#  'l’agonie tailleur',
#  'l’agonie commençait',
#  'spectacle l’agonie',
#  'l’agonie résignée',
#  'progrès l’agonie',
#  'l’agonie pons',
#  'l’agonie mourant',
#  'l’agonie reçoit',
#  'l’agonie suit',
#  'l’agonie revint',
#  'agonie presque',
#  'sottises agonie',
#  'aimé jeune',
#  'aimé presque',
#  'aimée d’être',
#  'aimée lucien',
#  'aimée fille',
#  'aimée lucien',
#  'loin bien-aimé',
#  'mourrai bien-aimé',
#  'aimées femmes',
#  'désirs aimées',
#  'aimée qu’esther',
#  'environnée aimée',
#  'jamais aimé',
#  'pauvre aimé',
#  'aimée femme',
#  'aimée qu’une',
#  'aimée fois',
#  'aimée vie',
#  'aimée hier',
#  'aimée ambition',
#  'd’avoir aimé',
#  'coralie aimé',
#  'aimé qu’on',
#  'honnête aimé',
#  'montrer aimé',
#  'aimé d’elle',
#  'aimé d’être',
#  'aimé l’entraînement',
#  'aimé enfin',
#  'aimé absolument',
#  'aimé amour',
#  'aimé lucien',
#  'jamais aimé',
#  'aimé aime',
#  'aimé pauvre',
#  'aimé riche',
#  'aimé n’a',
#  'lord aimé',
#  'aimé guère',
#  'aimé rousseau',
#  'aimées femmes',
#  'enfin aimées',
#  'aimée mère',
#  'aimée demoiselles',
#  'ie aimé',
#  'aimé bocop',
#  'aimé l’ait',
#  'vue aimé',
#  'estimée qu’aimée',
#  'beauté qu’aimée',
#  'croyait aimé',
#  'pauvre aimé',
#  'aimé d’être',
#  'plaisir aimé',
#  'aimé d’être',
#  'aimé argent',
#  'aimés d’être',
#  'aimés napoléon',
#  'aimé t’ai',
#  'ami aimé',
#  'jamais aimé',
#  'aimé monde',
#  'homme aimé',
#  'duchesse aimé',
#  'aimé alors',
#  'aimé venait',
#  'l’arrestation bien-aimé',
#  'comtesse bien-aimé',
#  'biche aimée',
#  'aimée morte',
#  'aimé voulez-vous',
#  'demandez aimé',
#  'qu’a-t-il aimé',
#  'aimé pensa-t-il',
#  'aimée fille',
#  'aimée j’étais',
#  'homme aimé',
#  'juge aimé',
#  'aimé vie',
#  'aimé véritablement',
#  'aimé l’homme',
#  'vécu aimé',
#  'jamais aimé',
#  'planche aimé',
#  'aimé yeux',
#  'aimé petit',
#  'tendrement aimé',
#  'fils aimé',
#  'aimés n’ont',
#  'aimés peut-être',
#  'créatures aimées',
#  'heureuses aimées',
#  'aimée qu’elle',
#  'aimée rigueurs',
#  'aimée d’être',
#  'uniquement aimée',
#  'fils bien-aimé',
#  'savait bien-aimé',
#  'aimée savait',
#  'aimée mourut',
#  'aimé estimé',
#  'donné aimé',
#  'bien-aimé au-devant',
#  'fils bien-aimé',
#  'aimé heureux',
#  'aimé qu’il',
#  'aimé sentait',
#  'amour aimé',
#  'fils aimé',
#  'aimé n’avait',
#  'aimé d’être',
#  'souvenez-vous aimé',
#  'aimé lousteau',
#  'madame aimé',
#  'dit-on louis-le-bien-aimé',
#  'louis-le-bien-aimé petite',
#  'aimée aime',
#  'aimée moment',
#  'serez aimé',
#  'vous-même aimé',
#  'aimé heureux',
#  'aimé flore',
#  'dieu l’aimé-je',
#  'l’aimé-je âme',
#  'aimé t’ai',
#  'aimé méritais',
#  'm’avez aimé',
#  'aimé ans',
#  'aimé sens',
#  'aimé moment',
#  'd’arthez aimé',
#  'brigand aimé',
#  'aimée respectée',
#  'aimée famille',
#  'baronne aimé',
#  'aimé mari',
#  'bonheur aimée',
#  'aimée publiquement',
#  'eût aimé',
#  'protéger aimé',
#  'aimée peut-elle',
#  'aimée d’un',
#  'aimé d’être',
#  'aimé regard',
#  'l’ai aimé',
#  'aimé as',
#  'aimé as',
#  'aimé maman',
#  'croyez-vous aimé',
#  'aimé demanda',
#  'j’aime aimé',
#  'aimé sois',
#  'étiez aimé',
#  'aimé m’auriez',
#  'wenceslas bien-aimé',
#  'famille bien-aimé',
#  'l’avaient aimé',
#  'aimé tandis',
#  'aimée jamais',
#  'aimée chagrins',
#  'homme aimé',
#  'l’univers aimé',
#  'aimée femme',
#  'aimée traversée',
#  'homme aimé',
#  'aimé affreuse',
#  'jamais aimé',
#  'aimé valérie',
#  'aimée josépha',
#  'aimée dit-elle',
#  'aimé seul',
#  'jamais aimé',
#  'vouloir aimés',
#  'dit aimés',
#  'disant aimées',
#  'voient aimées',
#  'aimé j’aie',
#  'revenu aimé',
#  'jamais aimé',
#  'n’aime aimé',
#  'homme aimé',
#  'l’on aimé',
#  'aimé l’esprit',
#  'aimé d’elle',
#  'aimé l’homme',
#  'situation aimé',
#  'aimé stidmann',
#  'aimé femme',
#  'aimé l’imiter',
#  'aimé qu’elle',
#  'aimé d’être',
#  'veut aimé',
#  'wenceslas aimé',
#  'madame aimé',
#  'jamais aimé',
#  'rappelé aimé',
#  'grognard aimé',
#  'figurer aimé',
#  'aimé qu’il',
#  'aimable aimé',
#  'aimé conseiller-d’état.—être',
#  'voir aimé',
#  'aimée jamais',
#  'aimée n’aurais',
#  'jamais aimé',
#  'hulot aimé',
#  'aimé écus',
#  'd’une aimé',
#  'aimé d’être',
#  'foi aimé',
#  'aimée veux',
#  'aimée millions',
#  'aimé j’ai',
#  'aimé faible',
#  'pardonnes-tu bien-aimée',
#  'bien-aimée adeline',
#  'jour aimé',
#  'très-aimé aimé',
#  'très-aimé souvent',
#  'souvent aimé',
#  'aimé',
#  'dit aimé',
#  'aimée femme',
#  'aimée polonais',
#  'aimé l’homme',
#  'm’êtes aimé',
#  'aimé d’être',
#  'aimé d’elle',
#  'aimé ait',
#  'aimé femme',
#  'jamais aimé',
#  'aimé jenny',
#  'aimé d’être',
#  'vous-même aimé',
#  'parfums aimés',
#  'grisent aimés',
#  'jamais aimé',
#  'célibat aimé',
#  'excessivement aimés',
#  'théâtre aimés',
#  'eût aimées',
#  'chéri aimées',
#  'aimé généralement',
#  'aimé docteur',
#  'n’aurez aimé',
#  'jeunesse aimé',
#  'jamais aimé',
#  'dit aimé',
#  'n’aimé n’aurais',
#  'n’aimé j’ai',
#  'jamais aimé',
#  'aimé exemple',
#  'aimé d’être',
#  'n’ai aimé',
#  'dit bien-aimé',
#  'chéri bien-aimé',
#  'aimé l’aurais',
#  'aimé aime',
#  'n’ai aimé',
#  'aimé vie',
#  'cœurs aimé',
#  'aimé sincèrement',
#  'aimé croyais',
#  'aimé femmes',
#  'aimé êtes',
#  'maison aimé',
#  'aimée jamais',
#  'm’a aimée',
#  'aimé m’ait',
#  'dit aimé',
#  'aimé j’aurais',
#  'aimé femme',
#  'l’eût aimé',
#  'aller aimé',
#  'morts aimés',
#  'aimés vie',
#  'aimée femme',
#  'aimée tombe',
#  'aimé mieux',
#  'vendre aimé',
#  'aimeriez frère',
#  'aimeriez êtes',
#  'aimer rencontre',
#  'pareil aimer',
#  'détriment aimer',
#  'qu’il aimer',
#  'triste d’aimer',
#  'fille d’aimer',
#  'puis-je aimer',
#  'lucien aimer',
#  'faire aimer',
#  'l’une aimer',
#  'libre aimer',
#  'prostituée aimer',
#  'l’aimer lassé',
#  'l’aimer n’est-ce',
#  'n’aimerait-on minceur',
#  'pauvre n’aimerait-on',
#  'faire aimer',
#  'spirituelle aimer',
#  'vous-même aimerais',
#  'aimerais esprit',
#  't’aimer naturel',
#  't’aimer respirer',
#  'pâtissier aimerait',
#  'friandises aimerait',
#  'riche n’aimerez',
#  'fois n’aimerez',
#  'faire aimer',
#  'as aimer',
#  'seilement aimer',
#  'bar aimer',
#  'cents aimer',
#  'écoute aimer',
#  'disent aimer',
#  'souvent aimer',
#  'aimer croient',
#  'dansent aimer',
#  'père aimerais',
#  'aimerais quitterais',
#  'aimerais fortune',
#  'soyez aimerais',
#  'enfant j’aimerais',
#  'femme j’aimerais',
#  'm’aimer pu',
#  'bonheur m’aimer',
#  'affection j’aimerais',
#  'mieux j’aimerais',
#  'monsieur aimer',
#  'femme-là aimer',
#  'commencé aimer',
#  'coralie aimer',
#  'sauver aimer',
#  'femmes aimer',
#  't’aimer fini',
#  't’aimer jeune',
#  'l’aimer voulais',
#  'l’aimer t’aimais',
#  'reprit-elle t’aimerai',
#  'emportons-là t’aimerai',
#  'aimera général',
#  'aimera mieux',
#  'bêtes aimer',
#  'femme aimer',
#  'bêtise aimer',
#  'oui aimer',
#  'faiblesse d’aimer',
#  'madame d’aimer',
#  'savait aimer',
#  'pendu aimer',
#  'aimera philippe',
#  'aimera frère',
#  'pratique aimer',
#  'mariette aimer',
#  'garçon aimerait',
#  'maison aimerait',
#  'sentiments aimer',
#  'l’empereur aimer',
#  'philippe j’aimerais',
#  'mieux j’aimerais',
#  'impossible d’aimer',
#  'fils d’aimer',
#  'roi l’aimerait',
#  'l’aimerait mal',
#  'mal aimer',
#  'gouvernante aimer',
#  'manières d’aimer',
#  'd’aimer gulnare',
#  'fils l’aimerais',
#  'l’aimerais autant',
#  'mouilleron n’aimerez-vous',
#  'mieux n’aimerez-vous',
#  'aimera flore',
#  'aimera tonnerre',
#  'craindre aimer',
#  'respecter aimer',
#  'pleurant m’aimera',
#  'aimera m’aimera',
#  'aimera dru',
#  'd’aimer l’air',
#  'pauvre d’aimer',
#  'railleur aimer',
#  'quelqu’un aimer',
#  'l’accident d’aimer',
#  'quelqu’un d’aimer',
#  'fini aimer',
#  'napoléon aimer',
#  'charbonnée aimer',
#  'qu’un aimer',
#  'tourné aimer',
#  'vieille aimer',
#  'd’aimer.—nous c’est',
#  'd’aimer.—nous savons',
#  'aimer qu’on',
#  'qu’elles.—tiens aimer',
#  'chose aimer',
#  'tracasser aimer',
#  'royale aimerais-tu',
#  'madame aimerais-tu',
#  'heureuse d’aimer',
#  'répliqua-t-elle d’aimer',
#  's’appelle aimer',
#  'vue aimer',
#  'd’aimer art',
#  'consomme d’aimer',
#  'dites aimer',
#  'disait aimer',
#  'malheur aimerons',
#  'aimerons quitterions-nous',
#  'brisées m’aimera',
#  'jamais m’aimera',
#  'passions l’aimerais',
#  'l’aimerais j’étais',
#  'joliment aimer',
#  'femme aimer',
#  'd’aimer manie',
#  'd’aimer anges',
#  'travaille aimer',
#  'wenceslas aimer',
#  'crevel j’aimerais',
#  'voir j’aimerais',
#  'crevel j’aimerais',
#  'mieux j’aimerais',
#  'dites aimer',
#  'femme aimer',
#  'dit aimer',
#  's’écria-t-elle aimer',
#  'dit-il aimer',
#  'répondit-elle aimer',
#  'savoir aimer',
#  'disait aimer',
#  'faire aimer',
#  'demandait aimer',
#  'n’aimerai n’aime',
#  'jamais n’aimerai',
#  'aimer dû',
#  'samson aimer',
#  'l’aimer stidmann',
#  'l’aimer entendu',
#  'pouvoir aimer',
#  'wenceslas aimer',
#  'liberté t’aimerai',
#  'poëte t’aimerai',
#  't’aimer femme',
#  'frénésie t’aimer',
#  'puisse t’aimer',
#  't’aimer liberté',
#  'd’aimer précieuse',
#  'limites d’aimer',
#  'aimerai célestine',
#  'peut-être aimerai',
#  'passions aimerai',
#  's’écria-t-elle aimerai',
#  'faut aimer',
#  'homme aimer',
#  'mieux n’aimerais',
#  'fils n’aimerais',
#  'm’aimer pouvez',
#  'm’aimer véritablement',
#  'riche aimer',
#  'l’amour aimer',
#  'fier d’aimer',
#  'valérie d’aimer',
#  'l’aimeras-tu brésilien',
#  'l’aimeras-tu feras-tu',
#  'hulot aimer',
#  'valérie aimer',
#  'pouvais aimer',
#  'trahison aimer',
#  'délaisse aimer',
#  'créateur aimer',
#  'signifiait aimerait',
#  'maman aimerait',
#  'aimera camusot',
#  'aimera mieux',
#  'n’aimer s’est',
#  'd’une n’aimer',
#  'bête d’aimer',
#  'm’être d’aimer',
#  'aimerais-je force',
#  'aimerais-je dit',
#  'm’aimerez connaissez',
#  'm’aimerez mieux',
#  'pons aimerez',
#  'bonne aimerez',
#  'aimer l’air',
#  'vouloir aimer',
#  'poulain j’aimerais',
#  'mieux j’aimerais',
#  'c’haimerais pric-à-prac',
#  'c’haimerais mieux',
#  'pons j’aimerais',
#  'mieux j’aimerais',
#  'j’aimerais cliente',
#  'mieux j’aimerais',
#  'aimeriez frère',
#  'aimeriez êtes',
#  'aimer rencontre',
#  'pareil aimer',
#  'détriment aimer',
#  'qu’il aimer',
#  'triste d’aimer',
#  'fille d’aimer',
#  'puis-je aimer',
#  'lucien aimer',
#  'faire aimer',
#  'l’une aimer',
#  'libre aimer',
#  'prostituée aimer',
#  'l’aimer lassé',
#  'l’aimer n’est-ce',
#  'n’aimerait-on minceur',
#  'pauvre n’aimerait-on',
#  'faire aimer',
#  'spirituelle aimer',
#  'vous-même aimerais',
#  'aimerais esprit',
#  't’aimer naturel',
#  't’aimer respirer',
#  'pâtissier aimerait',
#  'friandises aimerait',
#  'riche n’aimerez',
#  'fois n’aimerez',
#  'faire aimer',
#  'as aimer',
#  'seilement aimer',
#  'bar aimer',
#  'cents aimer',
#  'écoute aimer',
#  'disent aimer',
#  'souvent aimer',
#  'aimer croient',
#  'dansent aimer',
#  'père aimerais',
#  'aimerais quitterais',
#  'aimerais fortune',
#  'soyez aimerais',
#  'enfant j’aimerais',
#  'femme j’aimerais',
#  'm’aimer pu',
#  'bonheur m’aimer',
#  'affection j’aimerais',
#  'mieux j’aimerais',
#  'monsieur aimer',
#  'femme-là aimer',
#  'commencé aimer',
#  'coralie aimer',
#  'sauver aimer',
#  'femmes aimer',
#  't’aimer fini',
#  't’aimer jeune',
#  'l’aimer voulais',
#  'l’aimer t’aimais',
#  'reprit-elle t’aimerai',
#  'emportons-là t’aimerai',
#  'aimera général',
#  'aimera mieux',
#  'bêtes aimer',
#  'femme aimer',
#  'bêtise aimer',
#  'oui aimer',
#  'faiblesse d’aimer',
#  'madame d’aimer',
#  'savait aimer',
#  'pendu aimer',
#  'aimera philippe',
#  'aimera frère',
#  'pratique aimer',
#  'mariette aimer',
#  'garçon aimerait',
#  'maison aimerait',
#  'sentiments aimer',
#  'l’empereur aimer',
#  'philippe j’aimerais',
#  'mieux j’aimerais',
#  'impossible d’aimer',
#  'fils d’aimer',
#  'roi l’aimerait',
#  'l’aimerait mal',
#  'mal aimer',
#  'gouvernante aimer',
#  'manières d’aimer',
#  'd’aimer gulnare',
#  'fils l’aimerais',
#  'l’aimerais autant',
#  'mouilleron n’aimerez-vous',
#  'mieux n’aimerez-vous',
#  'aimera flore',
#  'aimera tonnerre',
#  'craindre aimer',
#  'respecter aimer',
#  'pleurant m’aimera',
#  'aimera m’aimera',
#  'aimera dru',
#  'd’aimer l’air',
#  'pauvre d’aimer',
#  'railleur aimer',
#  'quelqu’un aimer',
#  'l’accident d’aimer',
#  'quelqu’un d’aimer',
#  'fini aimer',
#  'napoléon aimer',
#  'charbonnée aimer',
#  'qu’un aimer',
#  'tourné aimer',
#  'vieille aimer',
#  'd’aimer.—nous c’est',
#  'd’aimer.—nous savons',
#  'aimer qu’on',
#  'qu’elles.—tiens aimer',
#  'chose aimer',
#  'tracasser aimer',
#  'royale aimerais-tu',
#  'madame aimerais-tu',
#  'heureuse d’aimer',
#  'répliqua-t-elle d’aimer',
#  's’appelle aimer',
#  'vue aimer',
#  'd’aimer art',
#  'consomme d’aimer',
#  'dites aimer',
#  'disait aimer',
#  'malheur aimerons',
#  'aimerons quitterions-nous',
#  'brisées m’aimera',
#  'jamais m’aimera',
#  'passions l’aimerais',
#  'l’aimerais j’étais',
#  'joliment aimer',
#  'femme aimer',
#  'd’aimer manie',
#  'd’aimer anges',
#  'travaille aimer',
#  'wenceslas aimer',
#  'crevel j’aimerais',
#  'voir j’aimerais',
#  'crevel j’aimerais',
#  'mieux j’aimerais',
#  'dites aimer',
#  'femme aimer',
#  'dit aimer',
#  's’écria-t-elle aimer',
#  'dit-il aimer',
#  'répondit-elle aimer',
#  'savoir aimer',
#  'disait aimer',
#  'faire aimer',
#  'demandait aimer',
#  'n’aimerai n’aime',
#  'jamais n’aimerai',
#  'aimer dû',
#  'samson aimer',
#  'l’aimer stidmann',
#  'l’aimer entendu',
#  'pouvoir aimer',
#  'wenceslas aimer',
#  'liberté t’aimerai',
#  'poëte t’aimerai',
#  't’aimer femme',
#  'frénésie t’aimer',
#  'puisse t’aimer',
#  't’aimer liberté',
#  'd’aimer précieuse',
#  'limites d’aimer',
#  'aimerai célestine',
#  'peut-être aimerai',
#  'passions aimerai',
#  's’écria-t-elle aimerai',
#  'faut aimer',
#  'homme aimer',
#  'mieux n’aimerais',
#  'fils n’aimerais',
#  'm’aimer pouvez',
#  'm’aimer véritablement',
#  'riche aimer',
#  'l’amour aimer',
#  'fier d’aimer',
#  'valérie d’aimer',
#  'l’aimeras-tu brésilien',
#  'l’aimeras-tu feras-tu',
#  'hulot aimer',
#  'valérie aimer',
#  'pouvais aimer',
#  'trahison aimer',
#  'délaisse aimer',
#  'créateur aimer',
#  'signifiait aimerait',
#  'maman aimerait',
#  'aimera camusot',
#  'aimera mieux',
#  'n’aimer s’est',
#  'd’une n’aimer',
#  'bête d’aimer',
#  'm’être d’aimer',
#  'aimerais-je force',
#  'aimerais-je dit',
#  'm’aimerez connaissez',
#  'm’aimerez mieux',
#  'pons aimerez',
#  'bonne aimerez',
#  'aimer l’air',
#  'vouloir aimer',
#  'poulain j’aimerais',
#  'mieux j’aimerais',
#  'c’haimerais pric-à-prac',
#  'c’haimerais mieux',
#  'pons j’aimerais',
#  'mieux j’aimerais',
#  'j’aimerais cliente',
#  'mieux j’aimerais',
#  'l’amant journaliste',
#  'mademoiselle l’amant',
#  'avez amants',
#  'amants qu’elle',
#  'l’amant paris',
#  'd’une l’amant',
#  'amant contenter',
#  'amant beautés',
#  'usent diamant',
#  'diamant',
#  'rome diamant',
#  'mois amant',
#  'amant pauvre',
#  'claquemuré amants',
#  'amants maris',
#  'amants servi',
#  'amants rencontrèrent',
#  'l’amant devenir',
#  'l’amant d’esther',
#  'amant lucien',
#  'amant êtes',
#  'économique amants',
#  'dirigèrent amants',
#  'amant d’un',
#  'amant faire',
#  'l’amant sourire',
#  'l’amant d’esther',
#  'l’amant échangeait',
#  'madame l’amant',
#  'faux diamant',
#  'épingle diamant',
#  'sali diamant',
#  'père diamant',
#  'amant tué',
#  'amant accès',
#  'l’amant gin',
#  'l’amant misérable',
#  'boutons diamant',
#  'valent diamant',
#  'rubempré amant',
#  'amant jaloux',
#  'illusions amants',
#  'amants enfants',
#  'louchard réclamant',
#  'soins réclamant',
#  'faits amant',
#  'amant idée',
#  'preuve amant',
#  'amant jaloux',
#  'l’amant lucien',
#  'l’amant mystérieux',
#  'amants tric-trac',
#  'serons amants',
#  'épouser amant',
#  'amant sera-t-elle',
#  'amant malheureux',
#  'amant aperçut',
#  'infamante cas',
#  'infamante proposent',
#  'réclamant français',
#  'ambassadeur réclamant',
#  'diamants propose',
#  'diamants dit',
#  'confié diamants',
#  'mois diamants',
#  'contrées amants',
#  'vérité amants',
#  'amant lucien',
#  'amant d’esther',
#  'ancien amant',
#  'amant duchesse',
#  'infamante peine',
#  'infamante donne',
#  'l’amant châle',
#  'l’amant vole',
#  'l’amant degrés',
#  'l’échafaud l’amant',
#  'monstrueux amants',
#  'épouvantails amants',
#  'amant d’infidélité',
#  'serré amant',
#  'expression d’amant',
#  'désespoir d’amant',
#  'l’amant répondit',
#  'l’amant biffe',
#  'l’amant l’orgueil',
#  'l’amant inspiré',
#  'amant part',
#  'l’exécution amant',
#  'diamants costumes',
#  'diamants uniformes',
#  's’adorer amants',
#  'amants brouillent',
#  'fut diamant',
#  'brut diamant',
#  'madame diamants',
#  'oreilles diamants',
#  'oreilles diamants',
#  'diamants écus',
#  'amant augure',
#  'amant répliqua-t-elle',
#  'expression amant',
#  'amant',
#  'dites amant',
#  'parle d’amant',
#  'd’amour d’amant',
#  'amant singulier',
#  'amant coupant',
#  'mot amant',
#  'amant faire',
#  'l’amant arrondissement',
#  'l’amant maris',
#  'exaspération d’amant',
#  'rebuté d’amant',
#  'veulent amants',
#  'amants tuer',
#  'diamants rivière',
#  'diamants distingua',
#  'qu’avec diamants',
#  'diamants tête',
#  'diamants j’ai',
#  'diamants sauve',
#  'diamants oncle',
#  'valent diamants',
#  'diamants offrait',
#  'père diamants',
#  'laisse diamants',
#  'diamants c’est',
#  'diamants incisifs',
#  'diamants conversation',
#  'chausses amants',
#  'marguerite amants',
#  'l’amant reconnu',
#  'l’amant quelques-unes',
#  'diamants troqué',
#  'diamants femme',
#  'regard amants',
#  'amants échangèrent',
#  'vendre diamants',
#  'diamants marier',
#  'diamants gardât',
#  'diamants voudrais',
#  'amant désirs',
#  'sœur amant',
#  'amant hortense',
#  'amant droits',
#  'l’ex-amant économique',
#  'l’ex-amant célèbre',
#  'amant pauvre',
#  'amant subvenir',
#  'francs diamants',
#  'diamants monsieur',
#  'prix diamants',
#  'diamants ménage',
#  'diamant soleil',
#  'taillé diamant',
#  'années diamant',
#  'noir diamant',
#  'diamants rare',
#  'taillé diamants',
#  'amant d’un',
#  'amant heureux',
#  'gros diamant',
#  'd’environ diamant',
#  'serait amant',
#  'amant n’auriez',
#  'flamants beaux',
#  'blancs flamants',
#  'l’aspect amant',
#  'amant malade',
#  'amants vrais',
#  'l’art amants',
#  'diamants j’ai',
#  'diamants s’écria',
#  'diamants mettre',
#  'diamants gage',
#  'mettant diamants',
#  'diamants femme',
#  'met diamant',
#  'accapare diamant',
#  'l’amant auriez',
#  'l’amant sirène-là',
#  'amant rendre',
#  'cheveux amant',
#  'diamants mettre',
#  'mont-de-piété diamants',
#  'autant amants',
#  'amants qu’on',
#  'père l’amant',
#  'l’amant supérieur',
#  'd’amant l’état',
#  'valérie d’amant',
#  'rendez-vous amants',
#  'pris amants',
#  'amants qu’elle',
#  'voit amants',
#  'l’enfant amant',
#  'amant débarrassant',
#  ...]
