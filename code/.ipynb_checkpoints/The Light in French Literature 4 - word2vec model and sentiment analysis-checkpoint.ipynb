# %%
import re
import os
import pandas as pd
from pathlib import Path
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
Path.cwd()
# Out:
# WindowsPath('C:/Users/lakj/Documents/GitHub/Lighting in French Literature/code')

# %% [markdown]
# # Read the data from a csv file

# %%
input_dir = Path.cwd() / '../data/csv_files' # input directory
df = pd.read_csv(input_dir /'text_data230826.csv', sep='|')

# %%
df
# Out:
#      year          author                                              title  \
# 0    1838          Balzac  Splendeurs et misères des courtisanes 1 Esther...
# 1    1838          Balzac  Splendeurs et misères des courtisanes 2 A comb...
# 2    1838          Balzac  Splendeurs et misères des courtisanes 3 Où mèn...
# 3    1838          Balzac  Splendeurs et misères des courtisanes 4 La der...
# 4    1842          Balzac                                    La Rabouilleuse
# ..    ...             ...                                                ...
# 96   1910         Colette                                       La Vagabonde
# 97   1910  DelarueMardrus                                Comme tout le monde
# 98   1910      Maupassant               Les Dimanches d'un bourgeois à Paris
# 99   1911          Daudet                                    Rose et Ninette
# 100  1913          Proust                              Du côté de chez Swann
#
#                                                   text  \
# 0    SPLENDEURS ET MISÈRESDES COURTISANES   Laissez...
# 1    Depuis huit jours, Nucingen allait marchander ...
# 2    Le lendemain, à six heures, deux voitures mené...
# 3    — Qu’y a-t-il, Madeleine? dit madame Camusot e...
# 4    LES CÉLIBATAIRES. Voici, mon cher Nodier, un o...
# ..                                                 ...
# 96   LA VAGABONDE \n\n\n\nParu dans Le Livre de Poc...
# 97   Première partie     C’est un wagon de deuxième...
# 98   Monsieur Patissot, né à Paris, après avoir fai...
# 99   au poëte et au philosophe, je dédie cette page...
# 100  À MONSIEUR GASTON CALMETTE        PREMIÈRE PAR...
#
#                                             clean_text
# 0    splendeurs et misèresdes courtisanes laissez-m...
# 1    depuis huit jours nucingen allait marchander l...
# 2    le lendemain à six heures deux voitures menées...
# 3    qu’y a-t-il madeleine dit madame camusot en vo...
# 4    les célibataires voici mon cher nodier un ouvr...
# ..                                                 ...
# 96   la vagabonde paru dans le livre de poche l'ing...
# 97   première partie c’est un wagon de deuxième cla...
# 98   monsieur patissot né à paris après avoir fait ...
# 99   au poëte et au philosophe je dédie cette page ...
# 100  à monsieur gaston calmette première partiecomb...
#
# [101 rows x 5 columns]

# %% [markdown]
# # Build a Word2vec language models with the Gensim library

# %% [markdown]
# Word2Vec is an algorithm that learns relationships between words using large amounts of text. The Word2Vec algorithm produces a language model where words with similar meanings based on context are close together and words with different meanings based on context are far apart. For example, Copenhagen and Denmark would be close together, while Copenhagen and cheese would be relatively far apart.
#
# Word2vec models can thus be used to find words that are similar in meaning and syntactic position and that have a common relationship.
#
# To build the Word2vec models, you can the library Gensim, which stands for generating similarities. Building the models is a labor-intensive process that takes many hours, so once the model is built, it is a good idea to save it for later use. Documentation for and description of how models are built and saved can be found on this page: https://radimrehurek.com/gensim/auto_examples/index.html
#
# Below we'll build a model of the corpus for French literature. One can debate whether it is responsible to build a model from novels from a wide year span, or whether a division into subsets would make more sense. For example would this model not take into account the historical and cultural changes of terms through the period.

# %%
# Build a GenSim language models

#Sources:
## https://radimrehurek.com/gensim/auto_examples/index.html#documentation

## https://stackabuse.com/implementing-word2vec-with-gensim-library-in-python/

## https://tedboy.github.io/nlps/generated/generated/gensim.models.Word2Vec.most_similar.html

import nltk
from gensim.models import Word2Vec
import time

def build_w2v_model(clean_text):
    
    # data preperation
    
    ## split the text into sentences using the sent_tokenizer of the nltk library
    sent_list = nltk.sent_tokenize(clean_text) 
    
    ## split each sentence into list of words using the nltk word_tokenizer
    tok_lists = [nltk.word_tokenize(sent) for sent in sent_list]


    ### filter for the shortest words. Here this is words equal to a lenght of 1
    tok_lists = [w for w in tok_lists if len(w) >=1]


    # Build the W2V model
    ## The value of min_count does so that only words that appears at least the value are included
    
    # w2v model based on word lists
    word2vec_tokens = Word2Vec(tok_lists, min_count=4)
    
    return word2vec_tokens

# %% [markdown]
# # Build w2v models
#
# We build three different models:
# - one model from the novels of Balzac
# - one model from the novels of Zola
# - one model from all the novels

# %%
# build w2v models

def apply_w2v(data_series):
    startTime = time.time()
    word2vec_tokens = build_w2v_model(' '.join(data_series))
    executionTime = (time.time() - startTime)
    print('Building time in sec.: ' + str(executionTime))
    return word2vec_tokens

balsac = df[df['author'] == 'Balzac']['clean_text']
zola = df[df['author'] == 'Zola']['clean_text']
all_text = df['clean_text']

# Save the balzac model for later use                                      
balzac_model = apply_w2v(balsac)                                  
balzac_model.save('balzac_model.model')

# Save the zola model for later use                                      
zola_model = apply_w2v(zola)
zola_model.save('zola_model.model')
                                      
# Save the total model for later use                                      
all_text_model = apply_w2v(all_text)
all_text_model.save('all_text_model.model')
# Out:
# Building time in sec.: 1.8003251552581787
# Building time in sec.: 8.346299886703491
# Building time in sec.: 26.394368171691895

# %% [markdown]
# # Reduce the language model for the purpose of visualisation.

# %%
# Load the model

# load models
balsac_model = Word2Vec.load(r'C:\Users\lakj\Documents\GitHub\Lighting in French Literature\data\w2v_models\balzac_model.model')
zola_model = Word2Vec.load(r'C:\Users\lakj\Documents\GitHub\Lighting in French Literature\data\w2v_models\zola_model.model')
all_text_model = Word2Vec.load(r'C:\Users\lakj\Documents\GitHub\Lighting in French Literature\data\w2v_models\all_text_model.model')

# %%
from sklearn.decomposition import IncrementalPCA    # inital reduction
from sklearn.manifold import TSNE                   # final reduction
import numpy as np                                  # array handling


def reduce_dimensions(model):
    num_dimensions = 2  # final num dimensions (2D, 3D, etc)

    # extract the words & their vectors, as numpy arrays
    vectors = np.asarray(model.wv.vectors)
    labels = np.asarray(model.wv.index_to_key)  # fixed-width numpy strings

    # reduce using t-SNE
    tsne = TSNE(n_components=num_dimensions, random_state=0)
    vectors = tsne.fit_transform(vectors)

    x_vals = [v[0] for v in vectors]
    y_vals = [v[1] for v in vectors]
    return x_vals, y_vals, labels

# %%
x_vals, y_vals, labels = reduce_dimensions(balzac_model)
# Send the x, y, and label values to a dataframe and save it for later use
df = pd.DataFrame({'x_vals':x_vals, 'y_vals':y_vals, 'labels':labels})
df.to_csv('balzac_model_values_labels_2D.csv', index=False)

x_vals, y_vals, labels = reduce_dimensions(zola_model)
# Send the x, y, and label values to a dataframe and save it for later use
df = pd.DataFrame({'x_vals':x_vals, 'y_vals':y_vals, 'labels':labels})
df.to_csv('zola_model_values_labels_2D.csv', index=False)

x_vals, y_vals, labels = reduce_dimensions(all_text_model)
# Send the x, y, and label values to a dataframe and save it for later use
df = pd.DataFrame({'x_vals':x_vals, 'y_vals':y_vals, 'labels':labels})
df.to_csv('all_text_model_values_labels_2D.csv', index=False)

# %% [markdown]
# # Load the Gensim model and make an analyse of word similarity
#
# We make an analyse of the similarity of the keywords within each of the language models to capture semantic relationships between keywords and other words.

# %%
# load the Libraries 
import nltk
from gensim.models import Word2Vec

# %%
os.getcwd()
# Out:
# 'C:\\Users\\lakj\\Documents\\GitHub\\Lighting in French Literature\\code'

# %%
# load models
balsac_model = Word2Vec.load(r'C:\Users\lakj\Documents\GitHub\Lighting in French Literature\data\w2v_models\balzac_model.model')
zola_model = Word2Vec.load(r'C:\Users\lakj\Documents\GitHub\Lighting in French Literature\data\w2v_models\zola_model.model')
all_text_model = Word2Vec.load(r'C:\Users\lakj\Documents\GitHub\Lighting in French Literature\data\w2v_models\all_text_model.model')

# read keyword lists
input_dir = Path.cwd() / '../data/key_word_lists' # input directory
with open(input_dir / 'sensation_list.txt', 'r', encoding='utf-8-sig') as f:
    emo_keywords = f.read()
emo_keyword_list = emo_keywords.lower().split('\n')
emo_keyword_list = [i.strip() for i in emo_keyword_list]
emo_keyword_list = list(set(emo_keyword_list))
emo_keyword_list.sort()

input_dir = Path.cwd() / '../data/key_word_lists' # input directory
with open(input_dir / 'lightning_list.txt', 'r', encoding='utf-8-sig') as f:
    lightning_keywords = f.read()
lightning_keyword_list = lightning_keywords.lower().split('\n')
lightning_keyword_list = [i.strip() for i in lightning_keyword_list]
lightning_keyword_list = list(set(lightning_keyword_list))
lightning_keyword_list.sort()


# Function that takes a model, a list of keywords, and returns the five most similar word for each keyword

def multiple_similar_words(model, word_list, no = 5):
    
    for term in word_list:
        try:

            print ('Keyword:', term, '\n')
            print ('Most similar words:\n', model.wv.most_similar(term, topn=no))
            print ('\n')

        except KeyError:

            print ("Term or frase is not present in the model")
            print ('\n')
            

#############            
# run the function

balsac_sim_emo_keywords = multiple_similar_words(balsac_model, emo_keyword_list, no = 5)
print (f'Keyword similarity in Balsac corpus {balsac_sim_emo_keywords}')

zola_sim_emo_keywords = multiple_similar_words(zola_model, emo_keyword_list, no = 5)
print (f'Similar words in Zola corpus {zola_sim_emo_keywords}')

all_text_sim_emo_keywords = multiple_similar_words(all_text_model, emo_keyword_list, no = 5)
print (f'Keyword similarity in all text corpus {all_text_sim_emo_keywords}')
# Out:
# Keyword: agonie
#
# Most similar words:
#  [('condamné', 0.37197813391685486), ('croirait', 0.368137389421463), ('fit-elle', 0.36025068163871765), ('fondé', 0.3441506028175354), ('périr', 0.3369585871696472)]
#
#
# Keyword: attendri
#
# Most similar words:
#  [('humain', 0.6869267821311951), ('voulaient', 0.6630045771598816), ('plusieurs', 0.6466014385223389), ('premières', 0.6461528539657593), ('mots', 0.642706573009491)]
#
#
# Keyword: bouleverser
#
# Term or frase is not present in the model
#
#
# Keyword: caressant
#
# Most similar words:
#  [('rosaces', 0.8065230846405029), ('argent', 0.7998543977737427), ('raphaël', 0.7952196002006531), ('vulgaires', 0.7886896729469299), ('seule', 0.787570595741272)]
#
#
# Keyword: caresse
#
# Term or frase is not present in the model
#
#
# Keyword: chagrin
#
# Most similar words:
#  [('rubempré', 0.8779054284095764), ('maison', 0.8746100664138794), ('m', 0.8734118342399597), ('papier', 0.8731304407119751), ('eut', 0.8725594878196716)]
#
#
# Keyword: confus
#
# Most similar words:
#  [('compagnie', 0.6795607209205627), ('fit', 0.6793333888053894), ('miracle', 0.6721602082252502), ('dépravations', 0.6717210412025452), ('terrible', 0.6691887378692627)]
#
#
# Keyword: craindre
#
# Most similar words:
#  [('fouché', 0.4193279445171356), ('mensonges', 0.40889281034469604), ('tuera', 0.401732474565506), ('contenu', 0.36900919675827026), ('impériale', 0.35454005002975464)]
#
#
# Keyword: doucement
#
# Most similar words:
#  [('pensive', 0.40090760588645935), ('montrez', 0.34488964080810547), ('curieux', 0.33483585715293884), ('nécessités', 0.3238849937915802), ('vivrez', 0.31380337476730347)]
#
#
# Keyword: doux
#
# Most similar words:
#  [('cher', 0.9340887069702148), ('quelque', 0.9339981079101562), ('avoir', 0.9339920878410339), ('avez', 0.9339282512664795), ('jamais', 0.9333896040916443)]
#
#
# Keyword: désir
#
# Most similar words:
#  [('faut', 0.8328088521957397), ('écrire', 0.8257066607475281), ('sourire', 0.8239991664886475), ('sein', 0.8208606839179993), ('autant', 0.8199520111083984)]
#
#
# Keyword: détresse
#
# Most similar words:
#  [('près', 0.7595297694206238), ('elle-même', 0.752477765083313), ('intérêt', 0.7472134232521057), ('visage', 0.7469209432601929), ('tombe', 0.746505856513977)]
#
#
# Keyword: entendre
#
# Most similar words:
#  [('séduire', 0.7271917462348938), ('douce', 0.7267802953720093), ('mauvaise', 0.7226528525352478), ('sûr', 0.721939206123352), ('contre', 0.7206324338912964)]
#
#
# Keyword: excité
#
# Term or frase is not present in the model
#
#
# Keyword: fatigant
#
# Term or frase is not present in the model
#
#
# Keyword: fiévreux
#
# Term or frase is not present in the model
#
#
# Keyword: grelotter
#
# Term or frase is not present in the model
#
#
# Keyword: heureux
#
# Most similar words:
#  [('faire', 0.98570317029953), ('par', 0.9844772815704346), ('cet', 0.9843549132347107), ('sont', 0.9843412637710571), ('que', 0.984292209148407)]
#
#
# Keyword: heurt
#
# Term or frase is not present in the model
#
#
# Keyword: inquiétant
#
# Term or frase is not present in the model
#
#
# Keyword: insomnie
#
# Term or frase is not present in the model
#
#
# Keyword: las
#
# Term or frase is not present in the model
#
#
# Keyword: remords
#
# Most similar words:
#  [('malheur', 0.6012331247329712), ('mobilier', 0.600823700428009), ('milieu', 0.5891515612602234), ('tiens', 0.5877364277839661), ('eussiez', 0.5808565616607666)]
#
#
# Keyword: sensation
#
# Most similar words:
#  [('ambassadeur', 0.5063484311103821), ('camarade', 0.4691968262195587), ('arriver', 0.4677127003669739), ('changé', 0.4623763859272003), ('confus', 0.461894154548645)]
#
#
# Keyword: sentiment
#
# Most similar words:
#  [('papier', 0.8919512033462524), ('madame', 0.8911119699478149), ('moment', 0.8908548951148987), ('celui', 0.8908044099807739), ('quoique', 0.8907305002212524)]
#
#
# Keyword: sentir
#
# Most similar words:
#  [('mode', 0.7764801383018494), ('tirent', 0.7739642262458801), ('prier', 0.7594577670097351), ('voile', 0.7578290700912476), ('difficile', 0.7556008696556091)]
#
#
# Keyword: souffrance
#
# Most similar words:
#  [('apercevait', 0.3448190689086914), ('insu', 0.336567223072052), ('sanson', 0.3194715678691864), ('fosse', 0.3186061382293701), ('panque', 0.3108609914779663)]
#
#
# Keyword: tendresse
#
# Most similar words:
#  [('femme', 0.9572181701660156), ('et', 0.9568259119987488), ('j', 0.9568028450012207), ('trop', 0.956562876701355), ('s', 0.9565617442131042)]
#
#
# Keyword: vertige
#
# Most similar words:
#  [('dieu', 0.861642599105835), ('papier', 0.8585035800933838), ('connu', 0.8579602241516113), ('ami', 0.8572739362716675), ('donc', 0.8570363521575928)]
#
#
# Keyword: voix
#
# Most similar words:
#  [('au', 0.9942243099212646), ('lui', 0.9942100644111633), ('de', 0.9941469430923462), ('des', 0.9941237568855286), ('du', 0.9940990805625916)]
#
#
# Keyword: volupté
#
# Most similar words:
#  [('gloire', 0.6985020637512207), ('personnes', 0.6960388422012329), ('sacrifices', 0.6897744536399841), ('venait', 0.6858323216438293), ('quoique', 0.6857882142066956)]
#
#
# Keyword: éblouir
#
# Term or frase is not present in the model
#
#
# Keyword: éblouissant
#
# Term or frase is not present in the model
#
#
# Keyword: étouffement
#
# Term or frase is not present in the model
#
#
# Keyword: étourdi
#
# Most similar words:
#  [('examiner', 0.3369126617908478), ('spirituellement', 0.33653557300567627), ('début', 0.33619335293769836), ('gratuitement', 0.327780544757843), ('finances', 0.31817564368247986)]
#
#
# Keyword similarity in Balsac corpus None
# Keyword: agonie
#
# Most similar words:
#  [('entière', 0.9389784932136536), ('femmes', 0.9380896687507629), ('beauvilliers', 0.9379984140396118), ('beau', 0.937863290309906), ('leva', 0.937771737575531)]
#
#
# Keyword: attendri
#
# Most similar words:
#  [('parc', 0.8637577891349792), ('vite', 0.863442599773407), ('gronda', 0.8618273138999939), ('venaient', 0.8610377907752991), ('notes', 0.8607929348945618)]
#
#
# Keyword: bouleverser
#
# Most similar words:
#  [('abominablement', 0.4216720759868622), ('chastes', 0.35117363929748535), ('sauvagnat', 0.34279102087020874), ('parallèlement', 0.3371131122112274), ('clignements', 0.3365328013896942)]
#
#
# Keyword: caressant
#
# Most similar words:
#  [('arrêterait', 0.3629927337169647), ('assommés', 0.36045750975608826), ('roulées', 0.34487926959991455), ('spirale', 0.3391188383102417), ('enlevez', 0.3360464572906494)]
#
#
# Keyword: caresse
#
# Most similar words:
#  [('misérables', 0.7861490249633789), ('feydeau', 0.7855008244514465), ('plainte', 0.7806228399276733), ('fils', 0.7805337309837341), ('restaient', 0.7800607085227966)]
#
#
# Keyword: chagrin
#
# Most similar words:
#  [('renonçant', 0.7750397324562073), ('vidant', 0.7711020708084106), ('rentré', 0.7702863216400146), ('devenue', 0.7617886066436768), ('craintes', 0.7584832906723022)]
#
#
# Keyword: confus
#
# Most similar words:
#  [('veilles', 0.37071728706359863), ('transporté', 0.3474104702472687), ('dispersés', 0.33713477849960327), ('bazaine', 0.3283446133136749), ('ouvrages', 0.3262576460838318)]
#
#
# Keyword: craindre
#
# Most similar words:
#  [('racontaient', 0.3586517870426178), ('scrofule', 0.3544156551361084), ('tribu', 0.3536878526210785), ('traîne', 0.3484475910663605), ('chatouiller', 0.34526491165161133)]
#
#
# Keyword: doucement
#
# Most similar words:
#  [('archangias', 0.9315643906593323), ('flot', 0.9315183162689209), ('arrivait', 0.9314841628074646), ('répéta', 0.930738091468811), ('frisson', 0.9306360483169556)]
#
#
# Keyword: doux
#
# Most similar words:
#  [('christ', 0.8845700621604919), ('doute', 0.8841038942337036), ('vendez', 0.8825400471687317), ('tellement', 0.8803520202636719), ('crois', 0.8801999688148499)]
#
#
# Keyword: désir
#
# Most similar words:
#  [('corporal', 0.9558200240135193), ('reprit', 0.9542883634567261), ('enfant', 0.9536376595497131), ('nouveau', 0.9534174799919128), ('croix', 0.9533054232597351)]
#
#
# Keyword: détresse
#
# Most similar words:
#  [('chancela', 0.3863162696361542), ('nôtres', 0.3498364984989166), ('terrassier', 0.34679681062698364), ('réquisition', 0.33794987201690674), ('suivez', 0.3359892666339874)]
#
#
# Keyword: entendre
#
# Most similar words:
#  [('enfant', 0.9774739146232605), ('universelle', 0.9772478938102722), ('air', 0.976830005645752), ('église', 0.9767482280731201), ('trois', 0.9766572713851929)]
#
#
# Keyword: excité
#
# Most similar words:
#  [('devra', 0.3748294711112976), ('fringale', 0.36433663964271545), ('aboutissant', 0.3329445719718933), ('supplier', 0.3277733325958252), ('perçaient', 0.32758963108062744)]
#
#
# Keyword: fatigant
#
# Most similar words:
#  [('unissait', 0.38576793670654297), ('pétrifié', 0.38342562317848206), ('somnolente', 0.3767508566379547), ('repassé', 0.3665217459201813), ('m.dewinck', 0.36145299673080444)]
#
#
# Keyword: fiévreux
#
# Most similar words:
#  [('taire', 0.8931167721748352), ('seconde', 0.8922200202941895), ('jeunesse', 0.8920509219169617), ('moineaux', 0.8916419148445129), ('ruine', 0.8908148407936096)]
#
#
# Keyword: grelotter
#
# Most similar words:
#  [('casquette', 0.3943531811237335), ('écume', 0.3715093433856964), ('écossais', 0.3644019067287445), ('illimité', 0.3580004572868347), ('patrie', 0.3397305905818939)]
#
#
# Keyword: heureux
#
# Most similar words:
#  [('sous', 0.9941350221633911), ('devait', 0.9941146373748779), ('toute', 0.9939539432525635), ('grand', 0.9937666058540344), ('père', 0.9937419295310974)]
#
#
# Keyword: heurt
#
# Most similar words:
#  [('rebondissaient', 0.3725588321685791), ('réfugiant', 0.37014201283454895), ('connaissaient', 0.3377021849155426), ('réception', 0.3212357461452484), ('empereurs', 0.318757027387619)]
#
#
# Keyword: inquiétant
#
# Most similar words:
#  [('lamenter', 0.38345789909362793), ('empressée', 0.38025981187820435), ('credo', 0.3568868339061737), ('rôdé', 0.3444405794143677), ('dirigèrent', 0.33916839957237244)]
#
#
# Keyword: insomnie
#
# Most similar words:
#  [('voient', 0.7277618646621704), ('plantes', 0.7142438292503357), ('seuil', 0.7001466751098633), ('partit', 0.6987324357032776), ('première', 0.6973445415496826)]
#
#
# Keyword: las
#
# Most similar words:
#  [('froide', 0.8802871108055115), ('devenu', 0.8791934847831726), ('doigts', 0.8781662583351135), ('passer', 0.8776718974113464), ('vobiscum', 0.8776503205299377)]
#
#
# Keyword: remords
#
# Most similar words:
#  [('muette', 0.96189284324646), ('mariage', 0.961766242980957), ('vit', 0.9609139561653137), ('petits', 0.9607593417167664), ('petit', 0.9607303738594055)]
#
#
# Keyword: sensation
#
# Most similar words:
#  [('emportait', 0.9398014545440674), ('cloche', 0.9394760727882385), ('ailleurs', 0.9394262433052063), ('davantage', 0.9392831325531006), ('autel', 0.9392564296722412)]
#
#
# Keyword: sentiment
#
# Most similar words:
#  [('écoutais', 0.3636958599090576), ('ambroise', 0.3513546884059906), ('déconcerta', 0.35134169459342957), ('entamée', 0.3423043191432953), ('coffrer', 0.34122228622436523)]
#
#
# Keyword: sentir
#
# Most similar words:
#  [('rapport', 0.6512697339057922), ('fendant', 0.6510199308395386), ('traita', 0.6473799347877502), ('saintes', 0.6451088190078735), ('condamnée', 0.6302715539932251)]
#
#
# Keyword: souffrance
#
# Most similar words:
#  [('fumier', 0.7557451725006104), ('recueillement', 0.7550920248031616), ('nue', 0.7547896504402161), ('humanité', 0.752648651599884), ('ni', 0.7519366145133972)]
#
#
# Keyword: tendresse
#
# Most similar words:
#  [('enfin', 0.981904923915863), ('cet', 0.9818437695503235), ('jour', 0.9816622138023376), ('ou', 0.9816385507583618), ('ça', 0.9814624190330505)]
#
#
# Keyword: vertige
#
# Most similar words:
#  [('remettait', 0.3836723268032074), ('médaille', 0.37482520937919617), ('matérialisait', 0.35111334919929504), ('mesures', 0.33509013056755066), ('enviait', 0.3331611156463623)]
#
#
# Keyword: voix
#
# Most similar words:
#  [('de', 0.9995627403259277), ('son', 0.9995535612106323), ('et', 0.9995474219322205), ('le', 0.999540388584137), ('en', 0.9995390772819519)]
#
#
# Keyword: volupté
#
# Most similar words:
#  [('envahirent', 0.37812182307243347), ('entrais', 0.37110403180122375), ('courbée', 0.3441266417503357), ('artistes', 0.33497941493988037), ('aigus', 0.327883780002594)]
#
#
# Keyword: éblouir
#
# Term or frase is not present in the model
#
#
# Keyword: éblouissant
#
# Most similar words:
#  [('ministère', 0.35671356320381165), ('frisant', 0.35460659861564636), ('opposée', 0.3383336365222931), ('déréglée', 0.3378780484199524), ('obscurcissait', 0.33651095628738403)]
#
#
# Keyword: étouffement
#
# Most similar words:
#  [('ficher', 0.370891809463501), ('méritée', 0.3703649342060089), ('enveloppant', 0.3640853464603424), ('obtenir', 0.3594563901424408), ('élans', 0.3528880178928375)]
#
#
# Keyword: étourdi
#
# Most similar words:
#  [('double', 0.8198049068450928), ('inutile', 0.8101477026939392), ('pieds', 0.8095216155052185), ('longue', 0.8094005584716797), ('fièvre', 0.8092065453529358)]
#
#
# Similar words in Zola corpus None
# Keyword: agonie
#
# Most similar words:
#  [('ils', 0.9662796258926392), ('cause', 0.9655207991600037), ('venait', 0.9646064043045044), ('talent', 0.9645857810974121), ('eau', 0.9641704559326172)]
#
#
# Keyword: attendri
#
# Most similar words:
#  [('odette', 0.9449383616447449), ('sic', 0.944439709186554), ('volonté', 0.9441187381744385), ('extrait', 0.9440947771072388), ('m.jeufroy', 0.9440694451332092)]
#
#
# Keyword: bouleverser
#
# Most similar words:
#  [('binocle', 0.41450807452201843), ('scélérate', 0.4078429937362671), ('tourbillonnant', 0.4029860496520996), ('désigna', 0.39866119623184204), ('exercent', 0.3880115747451782)]
#
#
# Keyword: caressant
#
# Most similar words:
#  [('édifié', 0.5034963488578796), ('prétendaient', 0.5022152662277222), ('permis', 0.5017325282096863), ('inventer', 0.5001916885375977), ('toucherez', 0.49923384189605713)]
#
#
# Keyword: caresse
#
# Most similar words:
#  [('cité', 0.9485066533088684), ('indigner', 0.9481127858161926), ('puissance', 0.9469568729400635), ('opéra', 0.9469262957572937), ('état', 0.9468964338302612)]
#
#
# Keyword: chagrin
#
# Most similar words:
#  [('beau', 0.994430422782898), ('loin', 0.9943698644638062), ('impossible', 0.9943493008613586), ('pour', 0.994083046913147), ('contraire', 0.9936540722846985)]
#
#
# Keyword: confus
#
# Most similar words:
#  [('véritable', 0.9855785369873047), ('iii', 0.9853194952011108), ('froid', 0.9852526187896729), ('cœur', 0.9852501749992371), ('chouette', 0.9852361083030701)]
#
#
# Keyword: craindre
#
# Most similar words:
#  [('emportée', 0.9360916018486023), ('étendue', 0.9354836344718933), ('mangeait', 0.9350612163543701), ('masses', 0.9335653185844421), ('lumière', 0.9334800243377686)]
#
#
# Keyword: doucement
#
# Most similar words:
#  [('contre', 0.9988052248954773), ('dont', 0.9986079931259155), ('avant', 0.9984750151634216), ('fut', 0.9984633922576904), ('presque', 0.9984114766120911)]
#
#
# Keyword: doux
#
# Most similar words:
#  [('quel', 0.9985864758491516), ('notre', 0.9985632300376892), ('donner', 0.9985594153404236), ('vos', 0.9985417127609253), ('cœur', 0.9983340501785278)]
#
#
# Keyword: désir
#
# Most similar words:
#  [('froid', 0.9982741475105286), ('donner', 0.998234212398529), ('vos', 0.9981932640075684), ('cœur', 0.9981321692466736), ('surtout', 0.9981301426887512)]
#
#
# Keyword: détresse
#
# Most similar words:
#  [('matin', 0.9906415343284607), ('comte', 0.9905431866645813), ('arnoux', 0.990513026714325), ('belle', 0.9903603792190552), ('enfin', 0.9902647137641907)]
#
#
# Keyword: entendre
#
# Most similar words:
#  [('allait', 0.9989378452301025), ('chez', 0.9988353848457336), ('déjà', 0.9988223314285278), ('devait', 0.9987429976463318), ('même', 0.9985753893852234)]
#
#
# Keyword: excité
#
# Most similar words:
#  [('glissa', 0.817484438419342), ('pâli', 0.8167822957038879), ('article', 0.8117648959159851), ('hong-kong', 0.8116034865379333), ('tranche', 0.8098588585853577)]
#
#
# Keyword: fatigant
#
# Most similar words:
#  [('apportera', 0.4359346032142639), ('intenter', 0.3873683214187622), ('provençales', 0.38661932945251465), ('chroniques', 0.3672524392604828), ('révélèrent', 0.3621253967285156)]
#
#
# Keyword: fiévreux
#
# Most similar words:
#  [('choisi', 0.9604970812797546), ('celui-ci', 0.9598925113677979), ('dit-il', 0.9597603678703308), ('rastignac', 0.9595050811767578), ('dehors', 0.959139347076416)]
#
#
# Keyword: grelotter
#
# Most similar words:
#  [('imméritée', 0.4155285358428955), ('modicité', 0.3923931121826172), ('guyane', 0.3899308741092682), ('adaptait', 0.37470167875289917), ('tronçon', 0.36665958166122437)]
#
#
# Keyword: heureux
#
# Most similar words:
#  [('maintenant', 0.998813271522522), ('répondit', 0.9987357258796692), ('aussi', 0.9986977577209473), ('mal', 0.9986886382102966), ('toi', 0.9984390139579773)]
#
#
# Keyword: heurt
#
# Most similar words:
#  [('estimable', 0.6151843070983887), ('poursuivre', 0.613642692565918), ('créé', 0.6066977381706238), ('citation', 0.6059203147888184), ('doué', 0.6058385968208313)]
#
#
# Keyword: inquiétant
#
# Most similar words:
#  [('tendit', 0.8623017072677612), ('jette', 0.8603461980819702), ('prodigue', 0.8603189587593079), ('sagesse', 0.8592208027839661), ('transpiration', 0.8577101230621338)]
#
#
# Keyword: insomnie
#
# Most similar words:
#  [('verrière', 0.6054162979125977), ('effaçait', 0.5969782471656799), ('compensation', 0.5867653489112854), ('massacres', 0.5866878628730774), ('fourneau', 0.5765516757965088)]
#
#
# Keyword: las
#
# Most similar words:
#  [('saccard', 0.9977753162384033), ('cette', 0.9976005554199219), ('cet', 0.9975683093070984), ('toujours', 0.9974671602249146), ('trois', 0.997406542301178)]
#
#
# Keyword: remords
#
# Most similar words:
#  [('enfant', 0.9935790300369263), ('là', 0.9935094118118286), ('moins', 0.9932751059532166), ('ici', 0.9931974411010742), ('fix', 0.9931927919387817)]
#
#
# Keyword: sensation
#
# Most similar words:
#  [('esprit', 0.9907635450363159), ('heure', 0.9902259707450867), ('honneur', 0.9896185994148254), ('agent', 0.9895563125610352), ('âme', 0.9894874095916748)]
#
#
# Keyword: sentiment
#
# Most similar words:
#  [('ville', 0.997864305973053), ('vierge', 0.9975276589393616), ('au', 0.9975213408470154), ('près', 0.9974001049995422), ('voie', 0.9973481297492981)]
#
#
# Keyword: sentir
#
# Most similar words:
#  [('mes', 0.9872939586639404), ('ceci', 0.987159252166748), ('dit-elle', 0.9870280623435974), ('i', 0.9867798686027527), ('marquis', 0.9865946769714355)]
#
#
# Keyword: souffrance
#
# Most similar words:
#  [("d'une", 0.995770275592804), ('madamecaroline', 0.995174765586853), ('marie', 0.9951571822166443), ('français', 0.9951316714286804), ("d'un", 0.9948030114173889)]
#
#
# Keyword: tendresse
#
# Most similar words:
#  [('objet', 0.9639464020729065), ('œuvre', 0.9624618887901306), ('jusqu', 0.9624257683753967), ('côté', 0.962205708026886), ('partout', 0.9621109366416931)]
#
#
# Keyword: vertige
#
# Most similar words:
#  [('efforts', 0.9093815088272095), ('points', 0.9087586402893066), ('légendes', 0.9061424732208252), ('lèvres', 0.9061185121536255), ('meubles', 0.9052621722221375)]
#
#
# Keyword: voix
#
# Most similar words:
#  [('après', 0.9993152618408203), ('femme', 0.9989619851112366), ('quant', 0.9989340901374817), ('étant', 0.9988939166069031), ('pécuchet', 0.998840868473053)]
#
#
# Keyword: volupté
#
# Most similar words:
#  [('approuve', 0.7633626461029053), ('masses', 0.7507529258728027), ('épreuves', 0.7462621331214905), ('renversés', 0.7429873943328857), ('dressaient', 0.7413747906684875)]
#
#
# Keyword: éblouir
#
# Most similar words:
#  [('perça', 0.6560415029525757), ('recevant', 0.644652783870697), ('dimanches', 0.6445390582084656), ('ornières', 0.6413619518280029), ('cachés', 0.6397808194160461)]
#
#
# Keyword: éblouissant
#
# Most similar words:
#  [('sûreté', 0.9010496139526367), ('soulas', 0.9008305072784424), ('vis-à-vis', 0.9002763032913208), ('camarade', 0.8996604084968567), ('confiance', 0.899451732635498)]
#
#
# Keyword: étouffement
#
# Most similar words:
#  [('dégagé', 0.38716262578964233), ('voudrons', 0.374558687210083), ('sacramentelle', 0.3506092429161072), ('consciente', 0.34885650873184204), ('approches', 0.34503456950187683)]
#
#
# Keyword: étourdi
#
# Most similar words:
#  [('engagé', 0.8967797756195068), ('aimée', 0.8961052298545837), ('faudrait', 0.8934570550918579), ('gardé', 0.893207848072052), ('elle', 0.8928866386413574)]
#
#
# Keyword similarity in all text corpus None

# %%
##############
# If you will look up a single word then 
# replace the text string after the variable 'term'
# and adjust the integer after the variable no to get x amount of simiar words 
#############
print (10 * '*-*')
term = 'lumière'
no = 5
try:
    print ('french_literature_model:', term, '\n')
    print (all_text_model.wv.most_similar(term, topn=no))
    print ('\n')

except KeyError:

    print ("Term or frase is not present in the model")
    print ('\n')
# Out:
# *-**-**-**-**-**-**-**-**-**-*
# french_literature_model: lumière
#
# [('chambre', 0.9978148341178894), ('front', 0.9973626136779785), ('vieille', 0.9971561431884766), ('rue', 0.9971288442611694), ('célèbre', 0.9969614148139954)]

# %% [markdown]
# # Visual analysis of the language models values and labels
#
# Below I will use the language model that I reduced and saved for the purpose of visualisation.
#
# I need to do a lot of scripting to get to the visualisation.
#
#
# The goal is a graph that I can use for a visual analysis of the relation between keywords of two different themes.

# %%
# Load the reducered model in a dataframe
file = r'C:\Users\lakj\Documents\GitHub\Lighting in French Literature\data\w2v_models\all_text_model_values_labels_2D.csv'
df = pd.read_csv(file)


# Open two word lists
# 1
of = open(r'C:\Users\lakj\Documents\GitHub\Lighting in French Literature\data\key_word_lists\sensation_list.txt', 'r', encoding='utf-8-sig')
sensation_word_list = of.read().lower().split('\n')
sensation_word_list = [i.strip() for i in sensation_word_list]
sensation_word_list = list(set(sensation_word_list))
sensation_word_list.sort()
of.close()

#
of = open(r'C:\Users\lakj\Documents\GitHub\Lighting in French Literature\data\key_word_lists\technology_list.txt', 'r', encoding='utf-8-sig')
technology_list = of.read().lower().split('\n')
technology_list = [i.strip() for i in technology_list]
technology_list = list(set(technology_list))
technology_list.sort()
of.close()

# %%
# Function that take a keyword and returns x and y positions and the word if the word is in the model
def get_label_values(word):
    for index, row in df.iterrows():
        if row['labels'] == word:
            return index, row['x_vals'], row['y_vals'], row['labels']
        

# Function that take an list of keywords and returns both the word and its x and y values       
def get_words_labels(key_word_list): 
    values_labels = [get_label_values(word) for word in key_word_list]
    values_labels_list = [i for i in values_labels if type(i) != 'NoneType']
    return values_labels_list


# Build two lists of keywords
values_labels_list1 = get_words_labels(sensation_word_list)
values_labels_list2 = get_words_labels(technology_list)

# %%
# Function that takes a values_labels_list and a theme word that represents the theme of the values_labels_list
# the function returns a dataframe with x and y values and a column with the theme word.

def find_x_y_values(values_labels_list, theme = 'missing'):
    index = []
    x_vals = []
    y_vals = []

    for i in values_labels_list:
        try:
            index.append(i[0])
            x_vals.append(i[1])
            y_vals.append(i[2])
        except:
            i == 'Nonetype'
            pass

    values_labels_df = pd.DataFrame({'x_vals': x_vals, 'y_vals': y_vals, 'themes':theme}, index=index)
    
    # https://www.statology.org/pandas-merge-on-index/
    merges_df = pd.merge(df, values_labels_df, left_index=True, right_index=True)
    merges_df = merges_df[['x_vals_x', 'y_vals_x', 'labels', 'themes']].rename(columns={'x_vals_x': 'x_vals', 'y_vals_x': 'y_vals'} )
    
    
    return merges_df

# %% [markdown]
# I use the function to store a dataframe that holds x values, y values, labels (keywords), and the theme that the keywords relates to.
#
#
# I merge the two dataframe and store them together in the variable 'merged_df'.

# %%
find_x_y_values_list1 =  find_x_y_values(values_labels_list1, 'sensations')
find_x_y_values_list2 =  find_x_y_values(values_labels_list2, 'technology')

# %%
merged_df = pd.concat([find_x_y_values_list1,find_x_y_values_list2])

# %%
# Scatter plot documentation: https://plotly.com/python-api-reference/generated/plotly.express.scatter.html

import plotly.express as px
fig = px.scatter(merged_df, x = 'x_vals', y = 'y_vals', color='themes', hover_data=['labels', 'themes'], 
                 title='Visual analysis of the relation between keywords in two themes')
fig.show()
# Out:
# <div>                            <div id="ad1a978c-a217-4e16-a4f2-2bfced25a374" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad1a978c-a217-4e16-a4f2-2bfced25a374")) {                    Plotly.newPlot(                        "ad1a978c-a217-4e16-a4f2-2bfced25a374",                        [{"customdata":[["voix","sensations"],["entendre","sensations"],["heureux","sensations"],["d\u00e9sir","sensations"],["doux","sensations"],["doucement","sensations"],["tendresse","sensations"],["chagrin","sensations"],["sentiment","sensations"],["sentir","sensations"],["souffrance","sensations"],["sensation","sensations"],["remords","sensations"],["las","sensations"],["caresse","sensations"],["volupt\u00e9","sensations"],["craindre","sensations"],["agonie","sensations"],["d\u00e9tresse","sensations"],["confus","sensations"],["vertige","sensations"],["attendri","sensations"],["\u00e9tourdi","sensations"],["caressant","sensations"],["fi\u00e9vreux","sensations"],["excit\u00e9","sensations"],["insomnie","sensations"],["inqui\u00e9tant","sensations"],["\u00e9touffement","sensations"],["\u00e9blouissant","sensations"],["bouleverser","sensations"],["heurt","sensations"],["fatigant","sensations"],["grelotter","sensations"],["\u00e9blouir","sensations"]],"hovertemplate":"themes=%{customdata[1]}<br>x_vals=%{x}<br>y_vals=%{y}<br>labels=%{customdata[0]}<extra></extra>","legendgroup":"sensations","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"sensations","orientation":"v","showlegend":true,"x":[39.03686,21.706598,20.579584,18.720541,18.950592,16.811657,-38.401917,-6.107472,8.886608,-29.462503,-4.1030426,-16.834913,-12.437743,5.539764,-45.597225,-56.18363,-61.85784,-36.530933,-22.728983,-29.861446,-71.24698,-52.945694,-53.46191,-28.315388,-47.27368,-57.697002,-48.91091,-65.84659,46.055035,-51.2833,-9.285654,-41.900234,68.731865,-2.2916617,-48.09715],"xaxis":"x","y":[-54.74303,-59.270668,-59.349224,-60.65989,-60.539753,-60.830624,-40.085632,-56.776657,-61.128456,-52.636383,-62.216,-52.332104,-54.192234,-60.362484,-32.13719,18.16869,-25.61718,-41.441727,-53.62516,-51.099518,-15.130462,-26.260422,-13.14353,3.7725909,-30.704477,5.718203,28.41279,-0.9448322,-18.008871,-17.625782,-25.557299,15.411738,-0.7136282,12.0384,16.388306],"yaxis":"y","type":"scatter"},{"customdata":[["feu","technology"],["lumi\u00e8re","technology"],["lampe","technology"],["gaz","technology"],["foyer","technology"],["bougie","technology"],["chandelle","technology"],["lanterne","technology"],["\u00e9lectrique","technology"],["lustre","technology"],["\u00e9lectricit\u00e9","technology"],["tige","technology"],["veilleuse","technology"],["flambeau","technology"],["torche","technology"],["bougeoir","technology"],["falot","technology"],["fanal","technology"],["r\u00e9verb\u00e8re","technology"],["phare","technology"],["allumette","technology"],["chandelier","technology"],["cand\u00e9labre","technology"],["quinquet","technology"],["lampion","technology"]],"hovertemplate":"themes=%{customdata[1]}<br>x_vals=%{x}<br>y_vals=%{y}<br>labels=%{customdata[0]}<extra></extra>","legendgroup":"technology","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"technology","orientation":"v","showlegend":true,"x":[22.044624,19.586485,-69.260475,-41.7677,-32.937183,-42.2495,-32.01419,-48.72143,21.730162,11.975385,-68.90326,70.07631,-40.22922,-53.565132,-47.16786,-29.948423,25.35291,47.406628,-64.41447,18.884546,22.606552,-53.673813,26.921303,-1.091921,-0.49188694],"xaxis":"x","y":[-61.8924,-62.852234,-7.159799,-47.924164,-55.280174,-52.0937,-54.76917,-37.641376,-18.373617,38.894775,-7.7881002,-16.198357,3.9213073,-27.697197,-32.772224,14.908741,5.490897,47.699265,-16.516003,1.8548075,6.9954267,6.7161,35.385826,25.194965,3.962255],"y ...

# %% [markdown]
# Save the graph as a html file for later use.

# %%
import plotly.io as io

html_snippet_start = '<!DOCTYPE html> <html> <head> <title>Title</title> </head> <body>' 
html_snippet_end = ' </body></html> '

html_as_string = io.to_html(fig, full_html=False)

vis_in_html = html_snippet_start + html_as_string + html_snippet_end

of = open(r'C:\Users\lakj\Documents\GitHub\Lighting in French Literature\visualisations\sens_and_tech_gensim_2d.htm', 'w', encoding='utf-8-sig')
of.write(vis_in_html)
# Out:
# 3694041

# %% [markdown]
# # Sentiment analysis of sentences holding two keywords from different themes
#
# with combinations of emotions and technology or ligthning words

# %%
import pandas as pd
import os
from afinn import Afinn
import re

# %%
os.getcwd()
# Out:
# 'C:\\Users\\lakj\\Documents\\GitHub\\Lighting in French Literature\\code'

# %%
input_dir = Path.cwd() / '../data/csv_files' # input directory
df = pd.read_csv(input_dir /'text_data230826.csv', sep='|')

# %%
df
# Out:
#      year          author                                              title  \
# 0    1838          Balzac  Splendeurs et misères des courtisanes 1 Esther...
# 1    1838          Balzac  Splendeurs et misères des courtisanes 2 A comb...
# 2    1838          Balzac  Splendeurs et misères des courtisanes 3 Où mèn...
# 3    1838          Balzac  Splendeurs et misères des courtisanes 4 La der...
# 4    1842          Balzac                                    La Rabouilleuse
# ..    ...             ...                                                ...
# 96   1910         Colette                                       La Vagabonde
# 97   1910  DelarueMardrus                                Comme tout le monde
# 98   1910      Maupassant               Les Dimanches d'un bourgeois à Paris
# 99   1911          Daudet                                    Rose et Ninette
# 100  1913          Proust                              Du côté de chez Swann
#
#                                                   text  \
# 0    SPLENDEURS ET MISÈRESDES COURTISANES   Laissez...
# 1    Depuis huit jours, Nucingen allait marchander ...
# 2    Le lendemain, à six heures, deux voitures mené...
# 3    — Qu’y a-t-il, Madeleine? dit madame Camusot e...
# 4    LES CÉLIBATAIRES. Voici, mon cher Nodier, un o...
# ..                                                 ...
# 96   LA VAGABONDE \n\n\n\nParu dans Le Livre de Poc...
# 97   Première partie     C’est un wagon de deuxième...
# 98   Monsieur Patissot, né à Paris, après avoir fai...
# 99   au poëte et au philosophe, je dédie cette page...
# 100  À MONSIEUR GASTON CALMETTE        PREMIÈRE PAR...
#
#                                             clean_text
# 0    splendeurs et misèresdes courtisanes laissez-m...
# 1    depuis huit jours nucingen allait marchander l...
# 2    le lendemain à six heures deux voitures menées...
# 3    qu’y a-t-il madeleine dit madame camusot en vo...
# 4    les célibataires voici mon cher nodier un ouvr...
# ..                                                 ...
# 96   la vagabonde paru dans le livre de poche l'ing...
# 97   première partie c’est un wagon de deuxième cla...
# 98   monsieur patissot né à paris après avoir fait ...
# 99   au poëte et au philosophe je dédie cette page ...
# 100  à monsieur gaston calmette première partiecomb...
#
# [101 rows x 5 columns]

# %%
# text string input
work = 'La Cousine Bette'
text = df[df['title'] == work].iloc[0]['text'].lower()



# split the text in sentences
def sent_tokenizer(text):
    tokenized_sentences = re.split('\.', text)
    tokenized_sentences = [s.lstrip() for s in tokenized_sentences]
    return tokenized_sentences

sentence_list = sent_tokenizer(text)


# Open two word lists
# 1
of = open(r'C:\Users\lakj\Documents\GitHub\Lighting in French Literature\data\key_word_lists\sensation_list.txt', 'r', encoding='utf-8-sig')
sensation_word_list = of.read().lower().split('\n')
sensation_word_list = [i.strip() for i in sensation_word_list]
sensation_word_list = list(set(sensation_word_list))
sensation_word_list.sort()
of.close()

#
of = open(r'C:\Users\lakj\Documents\GitHub\Lighting in French Literature\data\key_word_lists\technology_list.txt', 'r', encoding='utf-8-sig')
technology_list = of.read().lower().split('\n')
technology_list = [i.strip() for i in technology_list]
technology_list = list(set(technology_list))
technology_list.sort()
of.close()



#####################
# add two word lists and run to get a sentiment score
####################
def sentiment_analysis(word_list1 = sensation_word_list, word_list2 = technology_list):
    
    
    from_word_list_one = []
    from_word_list_two = []
    sentiment_scores = []
    sentences = []
    
    for word1 in word_list1:
        for sent in sentence_list:
            if word1 in sent:
                for word2 in word_list2:
                    if word2 in sent:
                        from_word_list_one.append(word1)
                        from_word_list_two.append(word2)
                        afinn = Afinn()
                        sent_score = afinn.score(str(sent))
                        sentiment_scores.append(sent_score)
                        sentences.append(sent)
    
    senti_dataframe = pd.DataFrame({'word1': from_word_list_one, 'word2': from_word_list_two, 
                                        'sentiment_score': sentiment_scores, 'sentence': sentences})
    
    return senti_dataframe

# add positive, negative, or neutral cetegory
def apply_sentiment_cat(row):
    if row < 0:
        return 'neg'
    elif row == 0:
        return 'neu'
    elif row > 0:
        return 'pos'
                
sentiment_dataframe = sentiment_analysis(sensation_word_list, technology_list)
sentiment_dataframe['sentiment_cat'] = sentiment_dataframe['sentiment_score'].apply(lambda x : apply_sentiment_cat(x) )

sentiment_dataframe
# Out:
#         word1     word2  sentiment_score  \
# 0     chagrin       feu              0.0
# 1      confus       feu             -4.0
# 2   doucement    lustre              6.0
# 3   doucement       feu              0.0
# 4       désir       gaz              3.0
# 5     heureux       feu              0.0
# 6     heureux       feu              5.0
# 7         las       feu             -4.0
# 8         las    lustre             -4.0
# 9   sentiment  lanterne             -1.0
# 10  sentiment      tige             -1.0
# 11    vertige      tige             -1.0
# 12    vertige      tige             -4.0
# 13       voix    lustre              0.0
# 14       voix   lumière             -3.0
#
#                                              sentence sentiment_cat
# 0   —oui, je n’ai pas un sou dans ce moment à donn...           neu
# 1   la rougeur subite qui colora sa fille rendit l...           neg
# 2   —et vous croyez, ma petite mère, dit crevel, q...           pos
# 3   — hulot est le premier exemple de l’amour quan...           neu
# 4   à quoi bon des bas de soie gris tout neufs, de...           pos
# 5   —oui, je n’ai pas un sou dans ce moment à donn...           neu
# 6   le visage heureux et souriant dans le miroir, ...           pos
# 7   —des gens qui veulent mettre l’europe en feu, ...           neg
# 8   dix jours après ces événements, on publia le p...           neg
# 9   conseillée par la redoutable intelligence de l...           neg
# 10  les philtres et les vertiges que verse à torre...           neg
# 11  les philtres et les vertiges que verse à torre...           neg
# 12  hulot fils avait le vertige, il regardait sa m...           neg
# 13  —josépha! c’est moi!…  l’illustre cantatrice n...           neu
# 14  prise de peur, croyant à une catastrophe tragi...           neg

# %%
sentiment_dataframe [sentiment_dataframe['word2'] == 'gaz']
# Out:
#    word1 word2  sentiment_score  \
# 4  désir   gaz              3.0
#
#                                             sentence sentiment_cat
# 4  à quoi bon des bas de soie gris tout neufs, de...           pos

# %% [markdown]
# Do we get mostly positive, negative, or neutral sentenses from the combination of words describing sensations and technology?

# %%
sentiment_dataframe['sentiment_cat'].value_counts()
# Out:
# sentiment_cat
# neg    8
# neu    4
# pos    3
# Name: count, dtype: int64

# %% [markdown]
# The keywords in the positive sentences.

# %%
pos_sentiment = sentiment_dataframe[sentiment_dataframe['sentiment_cat'] == 'pos']

# %% [markdown]
# The table of the sensation keyword in the sentiments sorted by frequency.

# %%
pos_sensation_words = pos_sentiment['word1'].value_counts()
pos_sensation_words
# Out:
# word1
# doucement    1
# désir        1
# heureux      1
# Name: count, dtype: int64

# %% [markdown]
# The table of the technology keywords in the sentiments sorted by frequency.

# %%
pos_tech_words = pos_sentiment['word2'].value_counts()
pos_tech_words
# Out:
# word2
# lustre    1
# gaz       1
# feu       1
# Name: count, dtype: int64

# %% [markdown]
# The keywords in the negative sentences.

# %%
neg_sentiment = sentiment_dataframe[sentiment_dataframe['sentiment_cat'] == 'neg']

# %%
neg_sen_words = neg_sentiment['word1'].value_counts()
neg_sen_words
# Out:
# word1
# las          2
# sentiment    2
# vertige      2
# confus       1
# voix         1
# Name: count, dtype: int64

# %%
neg_tech_words = neg_sentiment['word2'].value_counts()
neg_tech_words
# Out:
# word2
# tige        3
# feu         2
# lustre      1
# lanterne    1
# lumière     1
# Name: count, dtype: int64

# %% [markdown]
# A comparision. Which emo words are only in positive sentences?

# %%
sen_words_compare = [w for w in list(pos_sensation_words.index) if w not in list(neg_sen_words.index)]
sen_words_compare
# Out:
# ['doucement', 'désir', 'heureux']

# %% [markdown]
# A comparision. Which emo words are only in negative sentences?

# %%
sen_words_compare = [w for w in list(neg_sen_words.index) if w not in list(pos_sensation_words.index)]
sen_words_compare
# Out:
# ['las', 'sentiment', 'vertige', 'confus', 'voix']

# %% [markdown]
# # Parts of speech tagging with Spacy
#
# Source: https://spacy.io/models/fr

# %%
import spacy
# Load the spacy model
nlp = spacy.load('fr_core_news_md')


#########
# single text string input
########
work = 'La Cousine Bette'
text = df[df['title'] == work].iloc[0]['clean_text']


# pos tagging
doc = nlp(text)

# %%
for token in doc:
    if 'VERB' in token.pos_:
        print(token.text, token.pos_, token.dep_)
# Out:
# mises VERB acl
# nommées VERB conj
# cheminait VERB acl
# portant VERB acl
# accusés VERB acl
# trouve VERB advcl
# croient VERB ccomp
# uniforme VERB xcomp
# supposent VERB conj
# imaginer VERB advcl
# appartenant VERB acl
# respirait VERB ccomp
# faisait VERB acl:relcl
# resplendir VERB xcomp
# acquise VERB acl
# met VERB advcl
# retirés VERB acl
# devinait VERB ccomp
# croyez VERB punct
# manquait VERB ccomp
# bombée VERB acl
# campé VERB acl
# décoré VERB acl
# laissait VERB appos
# errer VERB xcomp
# recueillent VERB acl:relcl
# adressés VERB acl
# arrêta VERB acl
# comprise VERB acl
# bâtie VERB acl
# respecté VERB conj
# demeurait VERB acl:relcl
# diminuée VERB acl
# accepta VERB acl
# descendre VERB advcl
# reconnu VERB acl:relcl
# a VERB advcl
# a VERB ccomp
# remit VERB advcl
# demander VERB xcomp
# dirigea VERB advcl
# disait VERB acl:relcl
# ont VERB parataxis
# arrêtent VERB parataxis
# décorés VERB acl
# connaissent VERB parataxis
# occupé VERB advcl
# nommé VERB conj
# distinguer VERB advcl
# créé VERB acl:relcl
# chargé VERB acl
# prendre VERB xcomp
# placé VERB acl
# obtint VERB acl
# mérita VERB conj
# sonné VERB advcl
# fit VERB advcl
# remettre VERB advcl
# retroussé VERB acl:relcl
# poussé VERB fixed
# admis VERB advcl
# livrée VERB acl
# eut VERB aux:tense
# aperçu VERB ccomp
# imposant VERB conj
# suivit VERB advcl
# dit VERB acl:relcl
# ouvrant VERB advcl
# entendant VERB advcl
# portait VERB acl:relcl
# conservée VERB acl
# parut VERB xcomp
# reçu VERB xcomp
# leva VERB conj
# va VERB advcl
# dit VERB advcl
# brodait VERB acl:relcl
# salué VERB acl
# sortit VERB advcl
# emmenant VERB acl
# paraissait VERB acl:relcl
# eût VERB aux:tense
# agit VERB ccomp
# dit VERB advcl
# paraître VERB advcl
# prenait VERB acl:relcl
# renvoyer VERB xcomp
# expliqué VERB ccomp
# portait VERB advcl
# raisin VERB amod
# dataient VERB advcl
# brodée VERB acl
# pouvait VERB acl:relcl
# valoir VERB xcomp
# cousue VERB acl
# bleu VERB advcl
# bordées VERB xcomp
# voit VERB advcl
# annonçait VERB advcl
# hésité VERB advcl
# saluer VERB xcomp
# bette VERB acl
# ressemblait VERB conj
# sortit VERB advcl
# faire VERB xcomp
# répondit VERB acl:relcl
# viendrez VERB advcl
# dit VERB parataxis
# avez VERB xcomp
# demanda VERB xcomp
# bette VERB obj
# voilà VERB conj
# comptez VERB obj
# voici VERB advcl
# dit VERB xcomp
# saluant VERB advcl
# jeta VERB conj
# jette VERB acl
# croit VERB acl:relcl
# marquer VERB xcomp
# voulez VERB advcl
# suivre VERB xcomp
# causer VERB advcl
# dit VERB advmod
# désignant VERB advcl
# formait VERB acl
# séparée VERB advcl
# donnait VERB xcomp
# laissa VERB advcl
# jugea VERB conj
# fermer VERB xcomp
# pût VERB ccomp
# venir VERB xcomp
# écouter VERB xcomp
# eut VERB advcl
# fermer VERB acl
# vit VERB advcl
# établies VERB xcomp
# revint VERB acl
# laissant VERB advcl
# ouverte VERB xcomp
# entendre VERB advcl
# ouvrir VERB xcomp
# entrait VERB ccomp
# allant VERB advcl
# venant VERB conj
# observée VERB advcl
# laissait VERB advcl
# dire VERB xcomp
# vue VERB conj
# épouvanté VERB advcl
# revenant VERB conj
# voila VERB acl:relcl
# semblent VERB ROOT
# avoir VERB xcomp
# examinait VERB advcl
# trouvait VERB acl:relcl
# voyant VERB advcl
# limés VERB conj
# disparu VERB advcl
# usée VERB acl
# succédèrent VERB advcl
# figure VERB obj
# parvenu VERB advcl
# regardait VERB ccomp
# passant VERB advcl
# annonça VERB acl
# remit VERB conj
# jetée VERB advcl
# indiquant VERB acl
# terminés VERB advcl
# allait VERB acl:relcl
# laissant VERB advcl
# voir VERB xcomp
# fit VERB advcl
# asseoir VERB xcomp
# prenez VERB acl:relcl
# augure VERB fixed
# interrompant VERB advcl
# dit VERB obj
# plaçant VERB advcl
# roulant VERB conj
# font VERB acl:relcl
# voit VERB advcl
# dites VERB acl
# ensorcelé VERB xcomp
# reprit VERB acl
# pouvoir VERB advcl
# avez VERB acl:relcl
# doivent VERB parataxis
# justifiées VERB xcomp
# éblouissent VERB acl:relcl
# faire VERB advcl
# oublier VERB xcomp
# avez VERB advcl
# contrebalance VERB amod
# exige VERB acl:relcl
# possédez VERB xcomp
# dit VERB conj
# levant VERB advcl
# avançant VERB conj
# dit VERB advcl
# finir VERB advcl
# reprit VERB ccomp
# écria VERB obj
# devint VERB acl:relcl
# reprit VERB advcl
# finirons VERB advcl
# demandé VERB conj
# venir VERB xcomp
# causer VERB advcl
# fait VERB dep
# bannir VERB acl:relcl
# cru VERB obl:arg
# reprit VERB xcomp
# voyez VERB advcl
# leste VERB ccomp
# parle VERB ccomp
# a VERB acl:relcl
# rester VERB dep
# crains VERB advcl
# soupçonnée VERB acl
# enfermant VERB xcomp
# savez VERB advcl
# prié VERB obj
# venir VERB xcomp
# répliqua VERB xcomp
# prenant VERB advcl
# pinça VERB ccomp
# remit VERB conj
# abréger VERB advcl
# dit VERB ccomp
# regardant VERB obl:mod
# fit VERB parataxis
# reconnu VERB acl:relcl
# épousé VERB advcl
# dit VERB conj
# ferait VERB advcl
# répondit VERB xcomp
# m’ VERB advmod
# avez VERB advcl
# plaindre VERB xcomp
# est VERB cop
# voici VERB conj
# faire VERB advcl
# supposer VERB xcomp
# nommé VERB ccomp
# pourrait VERB conj
# devenir VERB xcomp
# voulait VERB obl:arg
# donnez VERB advcl
# entendre VERB xcomp
# avez VERB ccomp
# obligé VERB acl:relcl
# soutenir VERB advmod
# reprit VERB xcomp
# semble VERB acl:relcl
# constitués VERB acl
# passé VERB advcl
# sait VERB punct
# payer VERB acl
# meubler VERB advcl
# mirobolamment VERB ccomp
# rapporte VERB acl:relcl
# occupe VERB advcl
# redoit VERB conj
# couvre VERB conj
# donne VERB acl:relcl
# puisse VERB advcl
# nouer VERB xcomp
# gagnait VERB acl:relcl
# disait VERB acl:relcl
# va VERB xcomp
# négliger VERB xcomp
# éloigne VERB conj
# finir VERB conj
# devient VERB advcl
# nommer VERB xcomp
# aurez VERB advcl
# plaindre VERB xcomp
# voici VERB advcl
# doit VERB parataxis
# trouver VERB aux:tense
# honoré VERB xcomp
# marié VERB xcomp
# aime VERB ROOT
# aime VERB advcl
# aime VERB parataxis
# donner VERB advcl
# accepté VERB parataxis
# sachez VERB conj
# entamerai VERB conj
# paraissent VERB ccomp
# voyez VERB conj
# popinot VERB punct
# dit VERB conj
# retiré VERB acl
# commis VERB obj
# acheté VERB parataxis
# popinot VERB nmod
# commis VERB ccomp
# rappelle VERB acl:relcl
# fier VERB conj
# rendre VERB acl
# posés VERB acl
# possèdent VERB conj
# qualifiez VERB acl:relcl
# accepte VERB acl:relcl
# fait VERB acl:relcl
# mariant VERB advcl
# savez VERB acl:relcl
# conclu VERB ccomp
# écria VERB aux:tense
# maudite VERB conj
# récriminons VERB conj
# accomplis VERB acl
# reprit VERB advcl
# parlons VERB xcomp
# donne VERB ccomp
# pu VERB ccomp
# marier VERB xcomp
# dépendait VERB ccomp
# cru VERB xcomp
# pensé VERB advcl
# rendu VERB ccomp
# eu VERB acl:relcl
# reconnu VERB acl:relcl
# recevoir VERB xcomp
# compromettre VERB nmod
# empressé VERB conj
# allié VERB acl:relcl
# favoriser VERB xcomp
# manquer VERB xcomp
# répondit VERB acl:relcl
# agi VERB conj
# venu VERB parataxis
# demander VERB xcomp
# attribués VERB acl
# payés VERB advcl
# répondu VERB ccomp
# constitué VERB advcl
# avait VERB advcl
# crois VERB conj
# mourait VERB ccomp
# voilà VERB acl
# auriez VERB advcl
# tenu VERB fixed
# demanda VERB acl
# regardant VERB advcl
# manqué VERB advcl
# eu VERB conj
# dire VERB xcomp
# écria VERB advcl
# coupant VERB advcl
# trouveriez VERB conj
# joignant VERB conj
# mit VERB xcomp
# baisa VERB conj
# voyant VERB advcl
# prit VERB acl:relcl
# acheter VERB xcomp
# levez VERB nmod
# sonne VERB conj
# releva VERB advcl
# rendit VERB advcl
# furieux VERB xcomp
# remit VERB ccomp
# affectionnent VERB advcl
# croient VERB acl:relcl
# ressortir VERB xcomp
# doués VERB acl:relcl
# consistait VERB acl:relcl
# croiser VERB xcomp
# mettant VERB advcl
# jetant VERB conj
# faisait VERB acl
# lancer VERB xcomp
# dire VERB advmod
# dit VERB obj
# jouée VERB acl
# conserver VERB xcomp
# reprit VERB xcomp
# interrompant VERB advcl
# laisser VERB advcl
# prononcer VERB xcomp
# voulait VERB advcl
# entendre VERB xcomp
# tenez VERB xcomp
# écrit VERB xcomp
# venir VERB xcomp
# voulez VERB advcl
# savoir VERB xcomp
# poussez VERB acl:relcl
# dirait VERB advcl
# répète VERB acl:relcl
# croyez VERB parataxis
# ai VERB nsubj
# faire VERB xcomp
# aime VERB conj
# parlez VERB obl:arg
# ai VERB obj
# puis VERB cc
# écouter VERB xcomp
# voyons VERB xcomp
# donnez VERB xcomp
# nommer VERB xcomp
# dire VERB xcomp
# livre VERB ccomp
# jure VERB acl:relcl
# nommer VERB xcomp
# su VERB obl:arg
# allez VERB ccomp
# confier VERB xcomp
# crois VERB ccomp
# agit VERB conj
# aimez VERB advcl
# allez VERB advcl
# souffrir VERB xcomp
# voulez VERB obj
# parlez VERB xcomp
# agit VERB conj
# justifier VERB acl
# faites VERB acl:relcl
# tourmenter VERB xcomp
# voudrait VERB acl:relcl
# marier VERB xcomp
# mourir VERB conj
# voyez VERB dep
# écria VERB aux:tense
# as VERB aux:tense
# souffert VERB advcl
# taisez VERB flat:name
# sortez VERB conj
# parlez VERB conj
# savez VERB mark
# connus VERB ccomp
# répéta VERB acl
# rompant VERB conj
# faire VERB advcl
# dit VERB acl
# comprennent VERB ccomp
# veuf VERB acl
# reprit VERB xcomp
# parlant VERB advcl
# va VERB acl:relcl
# raconter VERB xcomp
# voulant VERB acl
# remarier VERB xcomp
# idolâtre VERB nsubj
# voulant VERB acl:relcl
# avoir VERB xcomp
# eusse VERB cop
# mis VERB dep
# dit VERB xcomp
# avoue VERB acl:relcl
# devins VERB advmod
# perdre VERB advcl
# prié VERB obj
# fait VERB dep
# venir VERB xcomp
# vivre VERB acl
# surveiller VERB conj
# restât VERB advcl
# dire VERB xcomp
# eu VERB advcl
# reçu VERB conj
# fallait VERB advcl
# occuper VERB xcomp
# voulais VERB conj
# lâchons VERB conj
# faire VERB xcomp
# a VERB obj
# peux VERB conj
# qualifier VERB xcomp
# disant VERB dep
# duprez VERB ccomp
# coûté VERB advcl
# donner VERB xcomp
# rendu VERB acl:relcl
# eu VERB advcl
# allais VERB ccomp
# reprit VERB advcl
# doit VERB ccomp
# eut VERB conj
# attachée VERB xcomp
# devenu VERB conj
# voulus VERB ccomp
# donner VERB xcomp
# laissai VERB advcl
# voir VERB xcomp
# destinée VERB acl:relcl
# avait VERB parataxis
# devait VERB ccomp
# élevée VERB acl:relcl
# dit VERB acl:relcl
# écria VERB advcl
# savez VERB conj
# protégé VERB advcl
# dit VERB fixed
# reprit VERB advcl
# avait VERB advcl
# connues VERB acl:relcl
# jouait VERB advcl
# aviez VERB conj
# eu VERB advcl
# laisser VERB advcl
# suffira VERB acl:relcl
# effacer VERB advcl
# commis VERB acl:relcl
# ouvrira VERB conj
# répliqua VERB xcomp
# fit VERB acl:relcl
# rougir VERB xcomp
# dites VERB acl
# adorée VERB conj
# sachez VERB aux:tense
# a VERB aux:tense
# banqueté VERB acl:relcl
# savoir VERB advcl
# valez VERB acl:relcl
# adressait VERB ccomp
# détaillant VERB acl
# connais VERB ccomp
# hésiterait VERB advcl
# hésite VERB ccomp
# arrête VERB parataxis
# apprenez VERB conj
# racontent VERB parataxis
# rient VERB acl:relcl
# crevées VERB obl:arg
# roulèrent VERB acl:relcl
# arrêtèrent VERB ccomp
# pensa VERB conj
# remettre VERB xcomp
# reprends VERB parataxis
# dit VERB parataxis
# liés VERB ccomp
# plu VERB conj
# avait VERB ccomp
# laissons VERB acl:relcl
# devenus VERB acl:relcl
# essayait VERB ccomp
# dépraver VERB xcomp
# prêcher VERB xcomp
# donner VERB xcomp
# bleu VERB amod
# voyez VERB conj
# aimais VERB xcomp
# épouser VERB xcomp
# craint VERB advcl
# avoir VERB xcomp
# étions VERB fixed
# voulez VERB mark
# pensé VERB ccomp
# marier VERB xcomp
# sais VERB nsubj
# prononce VERB ccomp
# trompés VERB conj
# soufflé VERB conj
# scélérat VERB nsubj
# savait VERB aux:tense
# supplanté VERB acl:relcl
# excusez VERB advmod
# pris VERB conj
# fait VERB dep
# entrer VERB acl:relcl
# réglé VERB acl:relcl
# entamé VERB advcl
# coûtait VERB acl:relcl
# achève VERB acl
# ruiner VERB xcomp
# nomme VERB advcl
# pouvoir VERB acl
# reconnaître VERB xcomp
# abandonnée VERB acl
# faites VERB acl:relcl
# prouvent VERB advmod
# traiter VERB acl
# tenais VERB acl:relcl
# développé VERB conj
# devenue VERB acl
# veut VERB acl:relcl
# dissipe VERB acl
# dissipe VERB acl:relcl
# essayée VERB ccomp
# appelle VERB acl:relcl
# rasé VERB advcl
# lutté VERB advcl
# keller VERB conj
# compter VERB advcl
# va VERB conj
# voir VERB xcomp
# enlever VERB xcomp
# appelez VERB acl:relcl
# a VERB dep
# avoir VERB acl
# parle VERB advcl
# sait VERB advcl
# privé VERB xcomp
# eue VERB acl:relcl
# eu VERB advcl
# rencontrer VERB advcl
# posséderais VERB ccomp
# voyez VERB acl:relcl
# mise VERB xcomp
# restée VERB advcl
# a VERB advcl
# dit VERB advcl
# jetait VERB acl:relcl
# devenu VERB acl
# dit VERB advcl
# connaissait VERB acl:relcl
# essuya VERB acl:relcl
# roulaient VERB acl:relcl
# agit VERB ccomp
# sortit VERB acl:relcl
# tombée VERB acl:relcl
# retrouve VERB advcl
# coûte VERB ROOT
# su VERB ccomp
# aime VERB advcl
# ruiner VERB advcl
# vue VERB advcl
# donnée VERB acl:relcl
# compris VERB ccomp
# aviez VERB ccomp
# avez VERB aux:tense
# reprit VERB obj
# paraissez VERB advcl
# touché VERB acl:relcl
# disais VERB advcl
# avais VERB ccomp
# puisque VERB mark
# délaisse VERB advcl
# irait VERB parataxis
# revient VERB acl:relcl
# empêche VERB acl:relcl
# aspirer VERB xcomp
# trompé VERB advcl
# devraient VERB ccomp
# juré VERB xcomp
# prendre VERB xcomp
# aurait VERB ccomp
# dire VERB acl
# acquise VERB advcl
# mis VERB advcl
# touchés VERB acl:relcl
# redoublé VERB obj
# voulez VERB ccomp
# serez VERB conj
# sais VERB conj
# voyez VERB conj
# retiré VERB acl
# a VERB acl:relcl
# a VERB acl:relcl
# toqué VERB ccomp
# êtes VERB conj
# est VERB cop
# aimais VERB punct
# parle VERB advcl
# résolu VERB acl
# dites VERB advcl
# cause VERB advcl
# joue VERB ccomp
# serez VERB parataxis
# donné VERB conj
# auriez VERB conj
# attends VERB conj
# jeta VERB ccomp
# crut VERB acl:relcl
# devenue VERB xcomp
# arrêta VERB conj
# voulu VERB ccomp
# couvert VERB obj
# défié VERB advcl
# parlé VERB parataxis
# dit VERB parataxis
# éprouvant VERB advcl
# justifier VERB xcomp
# écria VERB advcl
# connais VERB advcl
# reprit VERB xcomp
# prise VERB acl:relcl
# étais VERB cop
# enlevé VERB acl:relcl
# étais VERB cop
# vois VERB advcl
# est VERB advmod
# obtenir VERB dep
# manquer VERB acl
# faut VERB ROOT
# dit VERB conj
# essuyant VERB advcl
# essayez VERB obj
# demander VERB xcomp
# reprit VERB acl
# remit VERB acl:relcl
# attendit VERB acl:relcl
# marque VERB acl:relcl
# donnerait VERB advcl
# remplacera VERB acl:relcl
# dit VERB acl
# forçant VERB xcomp
# arrête VERB acl:relcl
# aime VERB conj
# a VERB advcl
# dit VERB ccomp
# mêle VERB obl:arg
# mettra VERB parataxis
# tenez VERB conj
# mis VERB advcl
# pu VERB advcl
# renouveler VERB xcomp
# vomi VERB ccomp
# sortira VERB acl:relcl
# épouvanté VERB xcomp
# faut VERB advcl
# connais VERB punct
# a VERB ROOT
# savoir VERB dep
# découvrir VERB ccomp
# êtes VERB cop
# dit VERB ccomp
# voit VERB advcl
# voulez VERB parataxis
# révèle VERB ccomp
# cachés VERB acl:relcl
# dit VERB advcl
# pleurait VERB acl:relcl
# mouiller VERB xcomp
# donne VERB advcl
# voilà VERB conj
# voulais VERB acl:relcl
# dire VERB xcomp
# débutant VERB advcl
# veille VERB conj
# marier VERB xcomp
# dit VERB advcl
# perdit VERB acl:relcl
# voici VERB advcl
# reprit VERB acl
# regarda VERB xcomp
# changea VERB acl:relcl
# dû VERB advcl
# attendrir VERB xcomp
# abandonner VERB conj
# reprit VERB ccomp
# ayez VERB xcomp
# mariée VERB ccomp
# donné VERB parataxis
# disais VERB advcl
# poser VERB xcomp
# fâchera VERB conj
# fait VERB dep
# valoir VERB xcomp
# restreintes VERB conj
# ai VERB dep
# sont VERB acl:relcl
# sortez VERB advcl
# dit VERB punct
# sortez VERB appos
# mise VERB acl:relcl
# savoir VERB xcomp
# conduite VERB acl
# projeté VERB acl
# lâche VERB conj
# reprit VERB xcomp
# faire VERB dep
# peser VERB xcomp
# poignait VERB acl:relcl
# reparlé VERB acl:relcl
# rentré VERB ccomp
# périront VERB nsubj
# dit VERB advcl
# reprit VERB advcl
# pu VERB ccomp
# lasser VERB xcomp
# regarde VERB ccomp
# voyez VERB conj
# mis VERB acl:relcl
# ignorais VERB conj
# succédé VERB ccomp
# écria VERB conj
# coûte VERB advcl
# êtes VERB advcl
# renoncerai VERB advcl
# éprouve VERB acl
# pouvoir VERB xcomp
# embrasser VERB xcomp
# sentir VERB xcomp
# voir VERB obl:arg
# respectée VERB xcomp
# aimée VERB acl
# rendrai VERB obj
# amen VERB acl
# dit VERB xcomp
# répand VERB acl:relcl
# échoué VERB advcl
# connaissez VERB ccomp
# tenté VERB acl:relcl
# éclairer VERB xcomp
# voulais VERB ccomp
# sauver VERB xcomp
# épellerez VERB ccomp
# prodigue VERB ccomp
# touchent VERB xcomp
# voir VERB conj
# pleurer VERB xcomp
# aime VERB acl:relcl
# dit VERB obj
# asseyant VERB advcl
# puis VERB cc
# promettre VERB obj
# est VERB advmod
# faire VERB xcomp
# envoyez VERB mark
# voilà VERB advcl
# faire VERB ccomp
# écria VERB advmod
# soutenu VERB advcl
# imposait VERB ccomp
# souffrait VERB conj
# montré VERB dep
# trouvé VERB advmod
# opposait VERB acl:relcl
# manifestait VERB acl:relcl
# humilié VERB ccomp
# détendit VERB xcomp
# montées VERB obj
# briser VERB advcl
# tordit VERB ccomp
# fondit VERB acl:relcl
# laissa VERB advcl
# baiser VERB xcomp
# devenir VERB aux:tense
# reprit VERB dep
# essuyant VERB advcl
# peut VERB acl:relcl
# voir VERB xcomp
# dépérir VERB acl
# promène VERB ccomp
# savoir VERB advcl
# trouve VERB nsubj
# a VERB aux:tense
# dit VERB acl
# faut VERB acl:relcl
# mettre VERB xcomp
# demanda VERB xcomp
# perdent VERB advcl
# levez VERB conj
# voyez VERB xcomp
# fini VERB ccomp
# renversé VERB ccomp
# dit VERB obj
# regarda VERB ccomp
# toucha VERB acl:relcl
# refoula VERB conj
# ignore VERB ccomp
# marie VERB ccomp
# reprit VERB acl
# reprenant VERB advcl
# exige VERB acl:relcl
# avoir VERB advcl
# allez VERB xcomp
# regardera VERB acl:relcl
# suivra VERB advcl
# désirera VERB parataxis
# inquiète VERB amod
# veulent VERB acl:relcl
# avoir VERB xcomp
# tuer VERB acl
# tue VERB conj
# pouvez VERB ccomp
# marier VERB acl:relcl
# voulez VERB advcl
# trouvant VERB conj
# voudrait VERB conj
# avoir VERB aux:tense
# rencontre VERB conj
# a VERB advcl
# prennent VERB ccomp
# rencontrerait VERB acl:relcl
# ferait VERB acl:relcl
# avais VERB advcl
# épouserais VERB xcomp
# leva VERB xcomp
# regarda VERB conj
# poussent VERB acl:relcl
# donnent VERB acl:relcl
# grouille VERB conj
# faire VERB xcomp
# connu VERB conj
# avait VERB aux:tense
# a VERB advcl
# pataugeaient VERB advcl
# parvenir VERB acl
# vaut VERB ccomp
# mange VERB xcomp
# mange VERB conj
# parvenir VERB xcomp
# devenu VERB obj
# voilà VERB advcl
# dit VERB advcl
# capable VERB xcomp
# épouser VERB xcomp
# popinot VERB advmod
# épousé VERB ccomp
# espérer VERB advcl
# croient VERB acl:relcl
# croient VERB advcl
# cherchez VERB advcl
# devienne VERB acl:relcl
# regarder VERB advcl
# avouerez VERB advcl
# manque VERB ccomp
# vouliez VERB advcl
# quitter VERB acl
# démolissez VERB xcomp
# regardez VERB xcomp
# aime VERB advcl
# viendrez VERB conj
# veux VERB ccomp
# dire VERB xcomp
# pris VERB ccomp
# ai VERB xcomp
# poursuivrai VERB conj
# deveniez VERB dep
# réussirai VERB advcl
# voici VERB xcomp
# dit VERB ccomp
# mettant VERB advcl
# regardant VERB conj
# rencontrerez VERB advcl
# reprit VERB obj
# aimez VERB advcl
# livrer VERB advcl
# résignerez VERB conj
# commandait VERB acl:relcl
# prendre VERB xcomp
# sera VERB acl:relcl
# peut VERB conj
# trouver VERB xcomp
# trouvait VERB advcl
# a VERB acl:relcl
# voyant VERB conj
# poussée VERB acl
# déshonorer VERB xcomp
# direz VERB parataxis
# vaut VERB parataxis
# veut VERB conj
# garder VERB xcomp
# vais VERB ccomp
# gagner VERB xcomp
# ennuie VERB parataxis
# dis VERB acl:relcl
# mordue VERB conj
# feriez VERB ccomp
# céder VERB xcomp
# font VERB advcl
# aiment VERB acl:relcl
# mettra VERB advcl
# reste VERB acl:relcl
# arrange VERB parataxis
# passe VERB acl
# fricassé VERB acl:relcl
# meublé VERB acl:relcl
# voyons VERB parataxis
# laisserez VERB xcomp
# partir VERB xcomp
# guérit VERB amod
# prendrez VERB conj
# leva VERB advcl
# forcer VERB advcl
# devrait VERB acl:relcl
# vivre VERB xcomp
# dit VERB parataxis
# montrait VERB conj
# dédoré VERB acl
# faisaient VERB acl:relcl
# reluit VERB obj
# devoir VERB xcomp
# faisant VERB advcl
# prêtez VERB ccomp
# mordit VERB advcl
# reconnaissant VERB acl
# venait VERB acl:relcl
# flétrir VERB xcomp
# demanda VERB advcl
# éconduit VERB advcl
# ajouta VERB advcl
# faisant VERB advcl
# monsieur VERB nsubj
# aurait VERB aux:tense
# voilà VERB acl
# laissa VERB ccomp
# salué VERB advcl
# salue VERB advcl
# débarrasser VERB xcomp
# retourna VERB conj
# voir VERB advcl
# alla VERB advcl
# rouvrir VERB xcomp
# fermées VERB acl:relcl
# put VERB conj
# remarquer VERB xcomp
# dit VERB obj
# marchait VERB ROOT
# épuisé VERB parataxis
# laissa VERB advcl
# tomber VERB xcomp
# trouver VERB acl
# resta VERB conj
# attachés VERB acl
# babillait VERB acl:relcl
# bette VERB punct
# aimé VERB advcl
# fini VERB advcl
# aimer VERB xcomp
# lâche VERB ccomp
# ignorait VERB advcl
# venait VERB acl:relcl
# donner VERB xcomp
# savait VERB acl:relcl
# faisait VERB advcl
# mis VERB conj
# pleuré VERB ccomp
# échappée VERB advcl
# obtenu VERB acl:relcl
# porte VERB acl
# entoure VERB nsubj
# croyait VERB advcl
# accompli VERB acl
# voyait VERB acl:relcl
# savait VERB acl:relcl
# devoir VERB xcomp
# exercent VERB advcl
# craignait VERB conj
# soupçonné VERB advcl
# révélées VERB acl
# plaindre VERB advcl
# excusées VERB ccomp
# tirées VERB advcl
# voir VERB xcomp
# expliquer VERB dep
# voici VERB conj
# situé VERB acl
# fischer VERB nmod
# partirent VERB acl
# dite VERB acl
# laissa VERB advcl
# fischer VERB advmod
# reçue VERB acl
# rendu VERB ccomp
# servir VERB xcomp
# fit VERB conj
# dut VERB acl:relcl
# vint VERB acl:relcl
# vit VERB dep
# fischer VERB xcomp
# âgée VERB acl
# pouvait VERB ccomp
# comparée VERB xcomp
# tallien VERB nsubj
# fabrique VERB ccomp
# broyé VERB acl
# travaille VERB acl:relcl
# ressemblent VERB ROOT
# bianca VERB obj
# est VERB cop
# tallien VERB amod
# récamier VERB parataxis
# restées VERB acl
# croire VERB xcomp
# existe VERB ccomp
# sortent VERB nmod
# fischer VERB nsubj
# possédait VERB advcl
# nées VERB acl
# tenue VERB ROOT
# arrêtaient VERB acl
# charmés VERB acl
# voyant VERB acl
# fit VERB acl
# fischer VERB xcomp
# fischer VERB nmod
# blessé VERB nmod
# adorait VERB advcl
# tenait VERB acl:relcl
# parlaient VERB advmod
# devaient VERB acl:relcl
# sort VERB obj
# trouvant VERB xcomp
# tirés VERB conj
# mettre VERB advcl
# rendu VERB parataxis
# obtenu VERB parataxis
# savoir VERB advcl
# envoyé VERB advcl
# préparer VERB advcl
# passa VERB acl
# nommé VERB acl:relcl
# appelé VERB advcl
# attaché VERB conj
# eut VERB advcl
# faire VERB xcomp
# appartenait VERB acl:relcl
# remarqué VERB ccomp
# interrompue VERB advcl
# pouvait VERB acl:relcl
# faillir VERB xcomp
# devait VERB advcl
# eut VERB parataxis
# aimée VERB acl:relcl
# appela VERB parataxis
# eut VERB parataxis
# refuser VERB xcomp
# fit VERB acl:relcl
# distingua VERB conj
# demandait VERB conj
# est-elle VERB amod
# venger VERB xcomp
# triomphé VERB acl:relcl
# échoué VERB acl:relcl
# reconnaître VERB advcl
# mêlait VERB acl:relcl
# dit VERB advcl
# saurait VERB ccomp
# avoir VERB xcomp
# fit VERB acl:relcl
# remarquez VERB flat:name
# douée VERB ccomp
# rendit VERB acl:relcl
# parlait VERB advcl
# disait VERB xcomp
# cherchait VERB advcl
# briller VERB xcomp
# réfléchissait VERB ccomp
# écoutait VERB advcl
# modelait VERB conj
# nées VERB advcl
# suivit VERB advcl
# vissembourg VERB nmod
# termina VERB acl
# devint VERB acl
# réintégré VERB obj
# eut VERB acl:relcl
# reparut VERB advcl
# levée VERB acl
# restait VERB dep
# avait VERB aux:tense
# obtenu VERB advcl
# pouvait VERB conj
# faire VERB dep
# inoccupé VERB acl
# mis VERB advcl
# faisait VERB punct
# remonter VERB xcomp
# avait VERB aux:tense
# tenu VERB advmod
# assoluta VERB acl
# jouissait VERB advcl
# invétérée VERB acl
# portent VERB ccomp
# résignées VERB advcl
# savait VERB advcl
# tiendrait VERB ccomp
# fermait VERB advcl
# bouchait VERB advcl
# voulait VERB advcl
# ignorer VERB xcomp
# traitait VERB acl:relcl
# traite VERB acl
# gâté VERB acl
# venait VERB acl:relcl
# avoir VERB xcomp
# reconnut VERB acl
# voilà VERB advcl
# trompes VERB xcomp
# répondit VERB nsubj
# vu VERB advcl
# éprouver VERB xcomp
# voyant VERB advcl
# dit VERB advcl
# doit VERB advcl
# souffrait VERB conj
# abandonnait VERB ccomp
# revoyant VERB conj
# revoyait VERB advcl
# perdait VERB conj
# articuler VERB acl
# voulu VERB conj
# prît VERB advcl
# osé VERB conj
# donner VERB xcomp
# entendre VERB xcomp
# connaissait VERB ccomp
# rencontrent VERB xcomp
# savent VERB acl:relcl
# recevoir VERB xcomp
# rendre VERB advcl
# ont VERB acl
# nées VERB amod
# éprouvent VERB ccomp
# tourmenter VERB nmod
# marquer VERB conj
# marque VERB advcl
# assurer VERB conj
# avait VERB acl:relcl
# devait VERB acl:relcl
# donner VERB xcomp
# avoir VERB xcomp
# commandé VERB fixed
# trouvaient VERB acl:relcl
# venu VERB obl:mod
# fixer VERB xcomp
# portait VERB acl:relcl
# sympathisait VERB acl
# admirait VERB acl:relcl
# voulu VERB advcl
# rencontrer VERB xcomp
# cherchée VERB ccomp
# déchoir VERB advcl
# disait VERB acl
# trahira VERB conj
# supporté VERB ccomp
# venaient VERB acl:relcl
# assaillir VERB xcomp
# brisé VERB acl
# blessé VERB acl
# entendait VERB conj
# eurent VERB advcl
# fallut VERB conj
# compter VERB xcomp
# change VERB xcomp
# mêle VERB advcl
# vit VERB advcl
# devenu VERB acl
# teignant VERB advcl
# portant VERB acl
# voulut VERB acl
# rester VERB xcomp
# poursuivait VERB acl:relcl
# poussa VERB ROOT
# aperçut VERB advcl
# coulait VERB acl:relcl
# prenait VERB ccomp
# dissipée VERB xcomp
# forcé VERB conj
# avouer VERB xcomp
# constituaient VERB acl:relcl
# mènera VERB acl:relcl
# répondit VERB acl
# laisse VERB parataxis
# faisant VERB advcl
# calmé VERB parataxis
# doivent VERB ccomp
# concevoir VERB xcomp
# savait VERB conj
# croyait VERB advcl
# ignorait VERB ccomp
# fait VERB ccomp
# ignorait VERB ccomp
# espérait VERB acl:relcl
# connaissait VERB advcl
# parlait VERB punct
# allait VERB advcl
# perdre VERB xcomp
# entrevoyait VERB advcl
# dû VERB acl:relcl
# perdues VERB amod
# proposé VERB acl
# oublie VERB parataxis
# dit VERB xcomp
# voit VERB ccomp
# cherchera VERB nsubj
# parlait VERB advcl
# voyait VERB conj
# riant VERB advcl
# bette VERB flat:name
# savait VERB conj
# ressemblait VERB advcl
# avait VERB conj
# ondés VERB acl
# étonner VERB xcomp
# tenait VERB advmod
# voyait VERB advcl
# vibraient VERB acl:relcl
# produisaient VERB conj
# appelait VERB ccomp
# nageant VERB amod
# verse VERB acl:relcl
# arrêtaient VERB xcomp
# tressaillait VERB advcl
# font VERB acl:relcl
# payer VERB xcomp
# altérait VERB xcomp
# égalait VERB acl:relcl
# méritait VERB ccomp
# prodigué VERB acl
# voyait VERB acl:relcl
# pouvait VERB ccomp
# retenir VERB xcomp
# disait VERB acl:relcl
# ont VERB advcl
# crier VERB acl
# passés VERB advcl
# pouvait VERB conj
# avait VERB conj
# disent VERB xcomp
# perdu VERB acl:relcl
# fait VERB dep
# paru VERB advcl
# voler VERB xcomp
# pensant VERB acl
# revint VERB acl:relcl
# vit VERB acl:relcl
# tombant VERB xcomp
# jusque VERB acl
# renvoyé VERB conj
# accompagnée VERB acl
# prophétisés VERB advcl
# perdit VERB acl:relcl
# bette VERB nmod
# causait VERB acl
# regardait VERB acl:relcl
# savoir VERB advcl
# pourraient VERB ccomp
# rentrer VERB xcomp
# lutinait VERB obj
# rouvrit VERB acl:relcl
# aperçut VERB ccomp
# lisbeth VERB obj
# fischer VERB advmod
# formait VERB obj
# mot VERB advmod
# trouvé VERB advmod
# réunis VERB conj
# vivait VERB acl:relcl
# immolé VERB acl
# travaillait VERB acl
# dorelotée VERB acl
# arriva VERB xcomp
# trouvant VERB acl
# vouloir VERB xcomp
# arracher VERB xcomp
# admiraient VERB acl:relcl
# battue VERB xcomp
# continua VERB conj
# déchirer VERB xcomp
# gâter VERB conj
# plié VERB advcl
# destinée VERB obl:mod
# plièrent VERB advcl
# souvint VERB xcomp
# fit VERB conj
# venir VERB xcomp
# arracher VERB xcomp
# établissant VERB advcl
# marier VERB acl
# voulait VERB obj
# savait VERB conj
# lire VERB xcomp
# écrire VERB xcomp
# commença VERB acl
# donner VERB xcomp
# mit VERB acl:relcl
# pons VERB dep
# nommée VERB acl
# devenue VERB acl
# eut VERB dep
# apprendre VERB xcomp
# lire VERB xcomp
# compter VERB xcomp
# écrire VERB conj
# démontré VERB conj
# posséder VERB acl
# tenir VERB advcl
# voulait VERB acl:relcl
# faire VERB dep
# métamorphosa VERB xcomp
# appelée VERB acl
# comprenait VERB advcl
# scintillaient VERB acl:relcl
# avait VERB aux:tense
# brodé VERB acl:relcl
# comprenait VERB conj
# faites VERB acl
# constituaient VERB conj
# bette VERB acl:relcl
# pons VERB xcomp
# dirigeait VERB ccomp
# pu VERB ccomp
# établir VERB xcomp
# éclata VERB acl
# tenaient VERB ccomp
# eut VERB aux:tense
# allait VERB acl:relcl
# avoir VERB xcomp
# exploiter VERB acl
# compter VERB advcl
# épouvantée VERB acl
# refusa VERB ccomp
# crut VERB acl:relcl
# justifia VERB advcl
# pons VERB obj
# voulait VERB xcomp
# associer VERB xcomp
# redevint VERB advcl
# retombée VERB advcl
# tirée VERB amod
# ruinés VERB xcomp
# servirent VERB nsubj:pass
# tué VERB mark
# condamné VERB acl
# enfuit VERB ccomp
# mourut VERB conj
# vint VERB appos
# implorer VERB xcomp
# disait VERB acl:relcl
# mangeait VERB obj
# paraissait VERB acl:relcl
# donnés VERB conj
# fischer VERB appos
# reçut VERB xcomp
# commencer VERB advcl
# obtenue VERB acl
# conservait VERB conj
# fait VERB acl:relcl
# perdit VERB acl:relcl
# senti VERB advcl
# resta VERB conj
# cachée VERB xcomp
# peut VERB acl:relcl
# éclore VERB xcomp
# ravager VERB conj
# ouvre VERB advcl
# disait VERB advcl
# sommes VERB aux:tense
# recevait VERB advcl
# payait VERB advcl
# recevait VERB advcl
# mis VERB advcl
# moquait VERB ccomp
# rougissait VERB conj
# procuré VERB xcomp
# vivait VERB acl:relcl
# offrait VERB advcl
# loger VERB xcomp
# apercevait VERB advcl
# résolu VERB ccomp
# marier VERB xcomp
# séduite VERB conj
# refusait VERB advcl
# voir VERB obl:arg
# reprocher VERB xcomp
# parlait VERB advcl
# vivre VERB xcomp
# tenir VERB conj
# devait VERB acl:relcl
# coûter VERB xcomp
# répondait VERB acl:relcl
# marierait VERB ccomp
# présentait VERB ccomp
# remarque VERB acl:relcl
# développées VERB acl:relcl
# pensent VERB acl:relcl
# parlent VERB conj
# avait VERB aux:tense
# acquis VERB advcl
# mordant VERB acl
# ressemblait VERB acl:relcl
# travaillée VERB acl
# aimé VERB xcomp
# protéger VERB xcomp
# vivre VERB acl
# changée VERB acl:relcl
# faisait VERB acl
# rouille VERB xcomp
# douée VERB amod
# devenue VERB acl
# voués VERB acl
# imprimait VERB acl:relcl
# paru VERB advcl
# brouillé VERB acl:relcl
# eut VERB advcl
# mit VERB acl:relcl
# décidée VERB advcl
# porter VERB xcomp
# suivre VERB xcomp
# obtint VERB conj
# trouva VERB acl:relcl
# perçant VERB acl
# pouvaient VERB advcl
# tenter VERB xcomp
# contenta VERB advcl
# disait VERB xcomp
# riant VERB obl:mod
# finit VERB ccomp
# trouver VERB advcl
# avoir VERB advcl
# allait VERB conj
# travaillé VERB advcl
# lever VERB xcomp
# avait VERB advcl
# pourvoir VERB advcl
# habillait VERB conj
# donnait VERB conj
# payée VERB acl
# fischer VERB flat:name
# résignée VERB acl
# laissait VERB advcl
# traiter VERB xcomp
# refusait VERB ccomp
# venir VERB xcomp
# préférant VERB acl
# permettait VERB acl:relcl
# avoir VERB xcomp
# éviter VERB conj
# raccommodée VERB acl:relcl
# fêtait VERB dep
# semblait VERB ccomp
# savait VERB acl:relcl
# amadouer VERB xcomp
# causant VERB advcl
# entrer VERB xcomp
# mettait VERB acl:relcl
# conciliait VERB advcl
# subalterne VERB amod
# exigeait VERB advcl
# fini VERB conj
# comprendre VERB xcomp
# voyant VERB advcl
# voulant VERB conj
# plaire VERB xcomp
# riait VERB advcl
# séduit VERB ccomp
# devinait VERB ccomp
# épousait VERB conj
# rendait VERB ccomp
# paraissait VERB advcl
# avait VERB advcl
# gronder VERB acl
# méritait VERB parataxis
# possédait VERB conj
# vont VERB advcl
# emploie VERB ccomp
# deviennent VERB ccomp
# réservées VERB acl
# assistent VERB acl:relcl
# regarda VERB advcl
# arrivé VERB mark
# eut VERB advcl
# croyait VERB advcl
# semblait VERB advcl
# condamnée VERB xcomp
# surnommait VERB punct
# reçus VERB acl:relcl
# gardait VERB acl:relcl
# confié VERB ccomp
# observer VERB dep
# conservait VERB ccomp
# bette VERB amod
# frappée VERB acl:relcl
# parvenu VERB advcl
# écrite VERB acl
# rongés VERB acl
# balafrée VERB acl
# vit VERB acl:relcl
# examinant VERB advcl
# finit VERB acl:relcl
# croire VERB advcl
# changé VERB xcomp
# voient VERB ccomp
# éclairé VERB acl
# bette VERB acl
# resplendissait VERB advcl
# contracté VERB xcomp
# voulait VERB conj
# obéir VERB acl
# donnait VERB ccomp
# taillée VERB acl
# retravaillait VERB acl
# gâtait VERB conj
# faisant VERB advcl
# tenait VERB acl:relcl
# devenait VERB acl:relcl
# voulait VERB ccomp
# plaire VERB xcomp
# croyait VERB conj
# faisait VERB acl:relcl
# rendait VERB acl:relcl
# vouloir VERB acl
# pouvait VERB acl:relcl
# admettre VERB xcomp
# trouvé VERB advcl
# refusée VERB conj
# devenu VERB acl
# méritait VERB advcl
# donnait VERB acl:relcl
# répondait VERB conj
# offrons VERB acl:relcl
# observée VERB acl:relcl
# présenté VERB advcl
# voulait VERB acl:relcl
# arracher VERB dep
# devenue VERB conj
# tuée VERB advcl
# domptait VERB xcomp
# passent VERB ccomp
# consiste VERB ccomp
# sépare VERB acl:relcl
# a VERB parataxis
# a VERB aux:tense
# reçoit VERB ccomp
# dire VERB advcl
# appartient VERB xcomp
# envahit VERB acl:relcl
# descendent VERB acl
# transforment VERB acl:relcl
# admet VERB advcl
# cesse VERB conj
# satisfait VERB dep
# continue VERB advcl
# bette VERB xcomp
# appartenait VERB advcl
# pense VERB acl:relcl
# peut VERB conj
# expliquer VERB xcomp
# commence VERB acl:relcl
# voulu VERB ccomp
# laisser VERB xcomp
# habiller VERB xcomp
# habituée VERB acl
# porter VERB xcomp
# gardait VERB conj
# existe VERB advcl
# point VERB obj
# faisaient VERB acl:relcl
# bette VERB advmod
# tiré VERB acl
# parti VERB xcomp
# donnaient VERB conj
# ressemblait VERB ccomp
# habillés VERB acl
# promenés VERB acl
# connue VERB advcl
# unies VERB acl
# vivait VERB acl:relcl
# restreignait VERB ccomp
# aimait VERB acl:relcl
# étonnaient VERB xcomp
# disparaissaient VERB conj
# regarde VERB acl:relcl
# causés VERB acl
# remporté VERB acl
# venait VERB acl:relcl
# surprendre VERB xcomp
# demandé VERB acl
# fera VERB acl:relcl
# rompre VERB xcomp
# devenue VERB acl
# assaillait VERB parataxis
# respirait VERB acl:relcl
# voulait VERB ccomp
# savoir VERB xcomp
# mariée VERB ccomp
# connaissait VERB acl:relcl
# refusés VERB acl
# bâti VERB xcomp
# croyait VERB ccomp
# bette VERB advmod
# résultait VERB conj
# disait VERB ccomp
# parlant VERB advcl
# avait VERB aux:tense
# répondu VERB ccomp
# dit VERB acl:relcl
# devint VERB conj
# venue VERB acl:relcl
# va VERB mark
# répondu VERB conj
# souffre VERB ccomp
# demandé VERB ccomp
# crois VERB advmod
# blond VERB ccomp
# charbonnée VERB acl
# peut VERB advcl
# aimer VERB xcomp
# fait VERB nsubj
# dit VERB acl:relcl
# reine VERB acl
# peut VERB parataxis
# aimée VERB xcomp
# pignon VERB obj
# voudrais VERB acl:relcl
# voir VERB xcomp
# écriée VERB xcomp
# savoir VERB advcl
# tourné VERB ccomp
# peut VERB acl:relcl
# aimer VERB xcomp
# répondu VERB parataxis
# doit VERB ccomp
# employé VERB acl
# dit VERB advcl
# regardant VERB advcl
# as VERB advcl
# demandé VERB ccomp
# répondu VERB ccomp
# as VERB advcl
# bette VERB appos
# dit VERB ROOT
# faisant VERB advcl
# voilà VERB advcl
# eu VERB conj
# étudier VERB xcomp
# resté VERB advcl
# devrais VERB conj
# prolonger VERB xcomp
# prendre VERB dep
# regardé VERB conj
# voyant VERB conj
# riait VERB ccomp
# répondu VERB ccomp
# marier VERB acl:relcl
# ouvrière VERB advcl
# aimons VERB advcl
# caches VERB dep
# demandé VERB ROOT
# répliqué VERB parataxis
# riant VERB advcl
# demandé VERB ROOT
# crois VERB parataxis
# aime VERB parataxis
# voilà VERB advcl
# porte VERB acl:relcl
# aimes VERB advcl
# dit VERB ccomp
# existe VERB conj
# envers VERB obj
# sais VERB parataxis
# est VERB cop
# savons VERB advcl
# naissant VERB aux:tense
# dit VERB acl:relcl
# a VERB advcl
# aiment VERB acl:relcl
# restent VERB conj
# baissé VERB ccomp
# frémir VERB conj
# reçu VERB acl:relcl
# regardé VERB conj
# présentant VERB advcl
# pourrait VERB ccomp
# placer VERB xcomp
# mettre VERB conj
# faire VERB acl
# peut VERB ccomp
# dit VERB xcomp
# écriée VERB acl
# eu VERB advcl
# battu VERB ROOT
# commencé VERB acl:relcl
# placé VERB conj
# a VERB advcl
# espérer VERB xcomp
# arrivé VERB ROOT
# fait VERB advcl
# avait VERB conj
# a VERB aux:tense
# dit VERB advcl
# vit VERB acl:relcl
# demandé VERB xcomp
# donne VERB parataxis
# dit VERB ccomp
# bette VERB amod
# reçoit VERB acl:relcl
# écriée VERB conj
# parles VERB acl:relcl
# croirait VERB parataxis
# vois VERB xcomp
# fait VERB parataxis
# rappelle VERB advcl
# mises VERB acl
# chanté VERB advcl
# eu VERB conj
# dit VERB parataxis
# bette VERB xcomp
# regardant VERB obl:mod
# revenue VERB advcl
# croit VERB acl:relcl
# peut VERB ccomp
# aimer VERB xcomp
# répondu VERB advcl
# trouvant VERB advcl
# prouve VERB parataxis
# donne VERB conj
# comte! VERB advcl
# est VERB parataxis
# va VERB parataxis
# —c’ VERB appos
# nomme VERB advcl
# voyons VERB conj
# veux VERB parataxis
# savoir VERB xcomp
# garder VERB xcomp
# muette VERB amod
# oui.—eh VERB nmod
# nomme VERB advcl
# avait VERB advcl
# portait VERB acl:relcl
# établi VERB advcl
# perdu VERB conj
# mort VERB conj
# laissant VERB xcomp
# pris VERB ccomp
# mis VERB conj
# dédis VERB advmod
# répondu VERB ROOT
# donne VERB advcl
# as VERB conj
# garderas VERB xcomp
# auras VERB advcl
# viendrai VERB acl:relcl
# aurai VERB aux:tense
# dit VERB xcomp
# bette VERB ccomp
# fascinée VERB advcl
# posséder VERB acl
# donné VERB acl
# passé VERB conj
# semblait VERB advcl
# apporté VERB acl:relcl
# comptait VERB acl:relcl
# faire VERB xcomp
# devait VERB conj
# prouver VERB xcomp
# consistait VERB acl:relcl
# composé VERB acl
# adossées VERB acl
# enveloppées VERB xcomp
# soutenant VERB conj
# représentaient VERB advcl
# reposaient VERB xcomp
# déchiraient VERB acl:relcl
# agitait VERB conj
# wagner VERB xcomp
# fait VERB dep
# faire VERB advmod
# surprendrait VERB conj
# dut VERB advcl
# ébahie VERB xcomp
# bette VERB ccomp
# eut VERB aux:tense
# présenté VERB xcomp
# disant VERB acl
# trouves VERB ccomp
# appartenaient VERB advcl
# rappelaient VERB conj
# créèrent VERB ccomp
# brunnelleschi VERB acl
# tordu VERB advcl
# symbolisaient VERB acl:relcl
# enveloppaient VERB acl:relcl
# désespérer VERB acl
# reliait VERB conj
# présentait VERB acl:relcl
# voyait VERB conj
# sculpté VERB aux:tense
# demanda VERB acl:relcl
# répondit VERB advcl
# bette VERB amod
# a VERB advcl
# gagné VERB acl
# faire VERB xcomp
# dit VERB advcl
# signifiait VERB ccomp
# signer VERB acl
# aurai VERB dep
# acheter VERB conj
# commander VERB ccomp
# donné VERB ccomp
# peut VERB ccomp
# faire VERB xcomp
# fischer VERB advmod
# aperçue VERB advcl
# garda VERB obl:agent
# exprimer VERB xcomp
# éprouvât VERB acl:relcl
# ressentent VERB acl:relcl
# ouverte VERB acl:relcl
# voient VERB advcl
# dit VERB parataxis
# reprit VERB xcomp
# aime VERB conj
# orange VERB amod
# passe VERB advcl
# travailler VERB xcomp
# fait VERB parataxis
# voilà VERB conj
# mis VERB acl:relcl
# passé VERB conj
# dit VERB ccomp
# deviendra VERB ccomp
# vois VERB conj
# tiens VERB obj
# - VERB obj
# dit VERB ROOT
# riant VERB advcl
# aime VERB advcl
# demanda VERB xcomp
# adore VERB ccomp
# prenant VERB advcl
# vois VERB parataxis
# connu VERB xcomp
# sont VERB cop
# réchauffé VERB ccomp
# promis VERB parataxis
# dit VERB ccomp
# regardant VERB acl
# laissé VERB advcl
# décrocherait VERB ccomp
# apporte VERB ROOT
# peut VERB acl:relcl
# monnayer VERB xcomp
# demanda VERB xcomp
# faut VERB parataxis
# profiter VERB advcl
# dites VERB acl
# coup VERB xcomp
# suivies VERB conj
# peut VERB ccomp
# deviner VERB xcomp
# engendraient VERB xcomp
# faisant VERB dep
# comparer VERB acl
# voyait VERB acl:relcl
# abandonnant VERB advcl
# offrir VERB conj
# veulent VERB acl:relcl
# doit VERB acl:relcl
# avoir VERB xcomp
# demanda VERB acl
# faisait VERB ccomp
# réfléchir VERB dep
# ah VERB advmod
# veux VERB xcomp
# savoir VERB xcomp
# répondit VERB xcomp
# vais VERB parataxis
# mettre VERB xcomp
# voudrais VERB advcl
# voir VERB xcomp
# comprends VERB conj
# su VERB acl:relcl
# garder VERB xcomp
# cache VERB appos
# laisse VERB conj
# vois VERB xcomp
# ai VERB aux:tense
# faut VERB xcomp
# ait VERB ccomp
# aimer VERB xcomp
# tracasser VERB xcomp
# donne VERB parataxis
# dit VERB advcl
# montrant VERB advcl
# chargée VERB acl
# emportait VERB ccomp
# travaillait VERB conj
# attendant VERB advcl
# fais VERB advcl
# sauras VERB parataxis
# reprit VERB parataxis
# as VERB advcl
# ai VERB aux:tense
# écoute VERB conj
# dit VERB ccomp
# fait VERB ccomp
# reprit VERB acl
# représente VERB acl
# déchirant VERB xcomp
# enterré VERB conj
# croire VERB xcomp
# exposé VERB acl:relcl
# connaît VERB acl:relcl
# pouvait VERB acl:relcl
# parler VERB xcomp
# vue VERB acl:relcl
# passant VERB advcl
# paraît VERB xcomp
# donnent VERB ccomp
# occuper VERB acl
# faite VERB conj
# achetaient VERB advcl
# venaient VERB conj
# examiner VERB xcomp
# prétend VERB obj
# prendrait VERB ccomp
# payerait VERB conj
# prend VERB acl:relcl
# ira VERB ccomp
# présenter VERB xcomp
# prouver VERB xcomp
# porté VERB conj
# croit VERB ccomp
# a VERB acl:relcl
# renouvelé VERB acl:relcl
# perdu VERB conj
# dit VERB acl
# veut VERB conj
# doit VERB advcl
# donner VERB xcomp
# faut VERB conj
# dit VERB advcl
# voit VERB advcl
# fera VERB conj
# m’ VERB advmod
# deviendrez VERB advcl
# reste VERB parataxis
# tracasser VERB acl
# avance VERB conj
# passe VERB advcl
# regarder VERB xcomp
# dessiner VERB conj
# continuèrent VERB conj
# plaisanter VERB xcomp
# riait VERB advcl
# efforce VERB xcomp
# envahie VERB conj
# subi VERB acl:relcl
# concrètent VERB conj
# jetée VERB acl:relcl
# prennent VERB advcl
# suspendus VERB acl
# fait VERB acl:relcl
# croyait VERB advcl
# devenu VERB conj
# avait VERB advcl
# solidifiait VERB acl:relcl
# tenait VERB acl:relcl
# éclatait VERB acl:relcl
# eut VERB xcomp
# sentait VERB advcl
# prit VERB advcl
# douter VERB xcomp
# riait VERB acl:relcl
# donner VERB advcl
# semble VERB conj
# ouverte VERB obj
# dit VERB dep
# allons VERB obj
# voir VERB xcomp
# parti VERB obj
# rompu VERB conj
# peut VERB acl:relcl
# raccommoder VERB xcomp
# agit VERB advcl
# puis VERB cop
# dire VERB xcomp
# va VERB ROOT
# dépend VERB advcl
# dira VERB ccomp
# saurai VERB conj
# a VERB ccomp
# laisse VERB ccomp
# demanda VERB acl
# montrerai VERB xcomp
# te VERB iobj
# remettrai VERB ccomp
# rends-le-moi VERB xcomp
# faut VERB ccomp
# ferai VERB conj
# voir VERB xcomp
# puisse VERB advcl
# parler VERB xcomp
# doivent VERB conj
# dit VERB parataxis
# montre VERB advcl
# voilà VERB advcl
# demande VERB acl:relcl
# connaissait VERB dep
# moquerait VERB ccomp
# te VERB iobj
# promets VERB conj
# arrivèrent VERB acl
# venait VERB acl:relcl
# évanouir VERB xcomp
# poussé VERB acl
# suffit VERB conj
# ranimer VERB xcomp
# alla VERB ccomp
# chercher VERB xcomp
# revint VERB advcl
# trouva VERB parataxis
# disant VERB conj
# ajouta VERB parataxis
# reconnaissant VERB advcl
# sonner VERB acl
# parle VERB xcomp
# leva VERB ROOT
# aller VERB advcl
# emmener VERB acl
# attendant VERB advcl
# parler VERB xcomp
# rompu VERB acl
# expliquer VERB xcomp
# essayer VERB conj
# donner VERB xcomp
# montra VERB advcl
# distingue VERB conj
# attachés VERB acl
# contractée VERB acl:relcl
# exigé VERB acl
# trouvés VERB acl:relcl
# faut VERB ccomp
# convenir VERB xcomp
# sentait VERB ccomp
# lisait VERB ccomp
# encadrée VERB acl
# offrait VERB advcl
# animée VERB acl
# signalent VERB acl:relcl
# maintenait VERB advcl
# dit VERB xcomp
# servaient VERB conj
# crevel VERB acl
# fait VERB acl:relcl
# animent VERB advmod
# sourient VERB conj
# passent VERB acl:relcl
# reverront VERB conj
# parlé VERB xcomp
# dit VERB ccomp
# voyant VERB advcl
# répondit VERB acl
# assommé VERB conj
# entendu VERB xcomp
# parler VERB xcomp
# arriver VERB advcl
# font VERB acl:relcl
# dissipent VERB acl:relcl
# point VERB xcomp
# substitué VERB acl:relcl
# réjouit VERB acl:relcl
# habitués VERB acl
# marcher VERB xcomp
# ennuyé VERB conj
# bonjour VERB xcomp
# prit VERB conj
# embrassa VERB ccomp
# assit VERB obj
# mit VERB conj
# sentir VERB advcl
# ennuyé VERB acl:relcl
# fatigué VERB xcomp
# dit VERB parataxis
# vais VERB parataxis
# ennuyer VERB aux:tense
# demanda VERB ROOT
# quitte VERB ccomp
# vu VERB conj
# prit VERB xcomp
# regarda VERB acl
# posa VERB conj
# lu VERB obj
# cédée VERB advcl
# chantait VERB advmod
# échappa VERB advcl
# regarda VERB acl:relcl
# baissa VERB obj
# sortit VERB acl
# suivit VERB advcl
# voyons VERB conj
# dit VERB ccomp
# prenant VERB xcomp
# pressant VERB conj
# sais VERB xcomp
# aime VERB advcl
# répondit VERB conj
# dit VERB conj
# demanda VERB xcomp
# lâchant VERB acl:relcl
# recula VERB acl
# écrit VERB advcl
# brûlée VERB acl:relcl
# disait VERB conj
# manqué VERB ccomp
# dit VERB conj
# su VERB parataxis
# doit VERB conj
# entendaient VERB advcl
# décroisa VERB xcomp
# saisit VERB nsubj
# pressa VERB advcl
# embrassa VERB xcomp
# dit VERB conj
# prête VERB ccomp
# répondit VERB acl
# mettant VERB advcl
# empêcher VERB obl:mod
# dire VERB xcomp
# donner VERB xcomp
# ouvres VERB conj
# verser VERB xcomp
# étouffaient VERB acl:relcl
# mis VERB acl:relcl
# souscrit VERB xcomp
# trompe VERB acl:relcl
# moque VERB ccomp
# appelle VERB advcl
# affreux VERB xcomp
# coûte VERB ccomp
# satisfaire VERB xcomp
# nourrir VERB acl
# promettrais VERB ccomp
# retourner VERB acl
# écrit VERB advcl
# irais VERB acl:relcl
# allait VERB advcl
# tourmente VERB ccomp
# dit VERB ccomp
# oubliant VERB conj
# roulaient VERB acl:relcl
# ai VERB xcomp
# valent VERB acl
# suffirait VERB advcl
# fischer VERB obj
# garde-les VERB conj
# verrai VERB advcl
# écria VERB advmod
# prenant VERB advcl
# baisant VERB conj
# offrait VERB parataxis
# donnait VERB advcl
# regarda VERB ccomp
# peut VERB conj
# prendre VERB xcomp
# laisse VERB ccomp
# obtenu VERB acl:relcl
# saurait VERB ccomp
# nier VERB xcomp
# ayant VERB acl
# racheter VERB acl
# sollicitent VERB acl
# montrant VERB advcl
# passent VERB conj
# ait VERB ccomp
# croit VERB ccomp
# dispenser VERB advcl
# faire VERB xcomp
# faut VERB conj
# retrancher VERB xcomp
# croient VERB acl:relcl
# dupés VERB xcomp
# ont VERB conj
# prétendent VERB acl:relcl
# reprochait VERB acl:relcl
# déploya VERB acl
# bette VERB advmod
# voyant VERB advcl
# venir VERB xcomp
# nourrissait VERB acl:relcl
# prit VERB acl
# trouva VERB advcl
# parla VERB parataxis
# parler VERB xcomp
# poupard VERB nsubj
# deviendrait VERB ccomp
# glissa VERB ccomp
# rendit VERB conj
# chargée VERB acl
# tenir VERB xcomp
# échangea VERB appos
# voulait VERB acl:relcl
# dire VERB xcomp
# défendait VERB ccomp
# montré VERB advcl
# emmena VERB advcl
# présenter VERB advcl
# prendre VERB acl
# surgie VERB ccomp
# pénétra VERB acl:relcl
# attendrit VERB acl:relcl
# paraissait VERB acl:relcl
# vouloir VERB xcomp
# mettre VERB xcomp
# fabriqué VERB acl:relcl
# contenant VERB xcomp
# faites VERB acl
# lâchant VERB xcomp
# prenant VERB conj
# contiennent VERB acl:relcl
# agite VERB acl:relcl
# donne VERB conj
# retient VERB xcomp
# consent VERB conj
# étouffer VERB xcomp
# vêtu VERB acl:relcl
# voici VERB conj
# dit VERB advcl
# allant VERB advcl
# recevoir VERB xcomp
# embrassé VERB advcl
# montcornet VERB advcl
# amena VERB advcl
# prenant VERB advcl
# pair VERB acl
# dispensé VERB acl
# aller VERB acl
# montrait VERB acl:relcl
# froidie VERB acl
# collés VERB advcl
# devenu VERB acl
# portait VERB conj
# conservait VERB conj
# condamnée VERB acl
# partageait VERB advcl
# voyaient VERB advcl
# parlait VERB ccomp
# savait VERB ccomp
# avoir VERB advcl
# faire VERB xcomp
# bornait VERB acl:relcl
# dit VERB acl:relcl
# voyant VERB xcomp
# répandait VERB acl:relcl
# mariée VERB conj
# ajouta VERB xcomp
# reconnaissant VERB advcl
# viendra VERB ccomp
# cria VERB xcomp
# voilà VERB advcl
# voulu VERB ccomp
# riant VERB advcl
# aimait VERB advcl
# trouvait VERB conj
# sorti VERB acl
# tenait VERB advcl
# finissait VERB advcl
# trouvaient VERB acl:relcl
# soupçonner VERB advcl
# jouissait VERB ccomp
# élevait VERB acl:relcl
# aimaient VERB conj
# considérée VERB advcl
# demandait VERB nsubj
# venait VERB ccomp
# est VERB obj
# criait VERB parataxis
# dit VERB advcl
# voyageait VERB ccomp
# fit VERB advcl
# penser VERB xcomp
# pourrait VERB acl:relcl
# ôter VERB xcomp
# voyant VERB advcl
# craignant VERB advcl
# reporta VERB advcl
# espérait VERB conj
# ramener VERB xcomp
# abjurer VERB conj
# vu VERB advcl
# eu VERB advcl
# croire VERB xcomp
# abois VERB ccomp
# occupée VERB acl
# voler VERB xcomp
# voyant VERB acl
# occupés VERB conj
# faire VERB xcomp
# partit VERB acl
# aller VERB advcl
# applaudir VERB xcomp
# emmenant VERB advcl
# bette VERB appos
# demeurait VERB acl:relcl
# prétextait VERB conj
# aller VERB advcl
# avoueront VERB advcl
# trouve VERB acl:relcl
# aiment VERB ccomp
# faire VERB xcomp
# rassure VERB advcl
# accorde VERB acl:relcl
# craigne VERB conj
# avons VERB appos
# savoir VERB xcomp
# décrire VERB xcomp
# pourrait VERB ccomp
# imaginer VERB xcomp
# verront VERB acl:relcl
# achevé VERB acl
# refuseraient VERB acl:relcl
# croire VERB xcomp
# subsisté VERB ccomp
# reçu VERB acl:relcl
# mène VERB acl:relcl
# venu VERB acl:relcl
# remarque VERB ccomp
# ruinées VERB acl
# découragés VERB acl
# font VERB acl:relcl
# résolut VERB acl
# terminer VERB xcomp
# voilà VERB acl
# voit VERB conj
# trouve VERB acl:relcl
# enterrées VERB acl
# enveloppées VERB ccomp
# projettent VERB advcl
# concourent VERB conj
# faire VERB xcomp
# passe VERB acl:relcl
# engage VERB conj
# demande VERB ccomp
# peut VERB ccomp
# demeurer VERB xcomp
# doit VERB acl:relcl
# passer VERB xcomp
# change VERB acl:relcl
# enveloppés VERB acl
# donnent VERB conj
# devient VERB advcl
# voit VERB advcl
# ont VERB advcl
# cherchent VERB acl:relcl
# cherchent VERB acl:relcl
# doivent VERB advcl
# danser VERB xcomp
# dominés VERB acl
# prouver VERB xcomp
# survit VERB acl
# voici VERB ccomp
# crie VERB acl:relcl
# éventrés VERB acl
# extirpez VERB obj
# a VERB aux:tense
# reconnu VERB advcl
# symboliser VERB acl
# caractérise VERB acl:relcl
# commencé VERB advcl
# meurt VERB acl:relcl
# garnissent VERB acl:relcl
# auront VERB nsubj
# condamnées VERB acl
# disparaître VERB advcl
# engagé VERB acl:relcl
# loger VERB xcomp
# faisait VERB acl:relcl
# retirer VERB xcomp
# close VERB acl
# accordait VERB advcl
# conservée VERB acl:relcl
# coucher VERB xcomp
# lever VERB conj
# procure VERB acl:relcl
# demeurait VERB acl:relcl
# occupé VERB acl
# rendu VERB acl
# mit VERB acl:relcl
# disant VERB advcl
# exhalant VERB acl
# choisi VERB acl
# passait VERB xcomp
# entrer VERB advcl
# échangea VERB acl
# voir VERB advcl
# rencontrent VERB advcl
# réalise VERB acl:relcl
# disent VERB xcomp
# mit VERB conj
# remonter VERB advcl
# donner VERB advcl
# pouvoir VERB conj
# suivre VERB xcomp
# balancée VERB ROOT
# voilà VERB advcl
# disait VERB xcomp
# ferais VERB acl
# volontiers VERB obj
# ferait VERB conj
# atteint VERB advcl
# desservait VERB acl:relcl
# situé VERB acl
# regarda VERB ccomp
# retourner VERB xcomp
# vit VERB conj
# cloué VERB acl
# dévoré VERB acl
# respirent VERB acl
# trouvant VERB nmod
# attachées VERB acl
# reviennent VERB acl:relcl
# fait VERB advcl
# monta VERB acl:relcl
# ouvrit VERB xcomp
# montra VERB conj
# pelé VERB acl
# révélaient VERB conj
# sont VERB dep
# dit VERB acl:relcl
# indique VERB xcomp
# prenons VERB aux:pass
# garde VERB xcomp
# leva VERB xcomp
# monté VERB advcl
# retirèrent VERB conj
# produit VERB xcomp
# dirait VERB advcl
# connaissent VERB ccomp
# pensa VERB xcomp
# expliquerait VERB advcl
# eut VERB aux:tense
# remonté VERB advcl
# pencha VERB advcl
# revoir VERB advcl
# trouva VERB conj
# revenue VERB xcomp
# prise VERB acl
# contempler VERB xcomp
# rejeta VERB ccomp
# saurai VERB ccomp
# dit VERB ccomp
# produit VERB advcl
# va VERB advcl
# voir VERB xcomp
# trouve VERB advcl
# écria VERB advmod
# quittant VERB advcl
# marneffe VERB conj
# vit VERB acl:relcl
# drôle VERB obj
# apprenions VERB acl:relcl
# vivre VERB xcomp
# répéta VERB acl
# parlons VERB xcomp
# fait VERB acl:relcl
# attends VERB ccomp
# montcornet VERB acl
# mariée VERB ccomp
# illustre VERB nmod
# arrivé VERB conj
# commis VERB acl
# nommé VERB acl
# coupé VERB advcl
# fondue VERB acl:relcl
# monte VERB acl:relcl
# habituée VERB acl
# voulut VERB acl:relcl
# renoncer VERB dep
# obligé VERB xcomp
# réaliser VERB xcomp
# sourit VERB dep
# habitaient VERB acl:relcl
# fischer VERB xcomp
# appartenait VERB conj
# résiste VERB acl:relcl
# donne VERB acl:relcl
# étiolée VERB amod
# réalisait VERB advcl
# dessine VERB acl:relcl
# traduit VERB acl
# occupé VERB acl
# offrait VERB parataxis
# règne VERB acl:relcl
# recouverts VERB acl
# passé VERB acl
# ...
# légué VERB conj
# devait VERB advcl
# avoir VERB xcomp
# instituées VERB acl
# fondée VERB acl:relcl
# est VERB cop
# marier VERB xcomp
# tiennent VERB acl:relcl
# tient VERB acl:relcl
# feignent VERB advcl
# ignorer VERB xcomp
# peuvent VERB advcl
# payer VERB xcomp
# entreprennent VERB ccomp
# décidé VERB advcl
# faire VERB xcomp
# faudrait VERB acl:relcl
# remuer VERB xcomp
# obtenir VERB advcl
# relâchât VERB ccomp
# perçoit VERB advcl
# indignent VERB acl:relcl
# puisse VERB acl:relcl
# oublié VERB xcomp
# chassant VERB acl
# faut VERB obj
# croire VERB xcomp
# constituent VERB ccomp
# inquiète VERB acl:relcl
# occuper VERB advcl
# souffrent VERB acl:relcl
# fait VERB obj
# restent VERB ccomp
# puissent VERB advcl
# unir VERB xcomp
# fondée VERB acl
# remettre VERB advcl
# est VERB advmod
# trouve VERB acl:relcl
# vérifier VERB advcl
# rétablie VERB advcl
# reprit VERB xcomp
# vint VERB conj
# prier VERB xcomp
# joindre VERB xcomp
# eut VERB nmod
# nommé VERB acl
# circonscrivent VERB conj
# miroménil VERB xcomp
# existe VERB parataxis
# peindre VERB advcl
# suffira VERB acl:relcl
# dire VERB xcomp
# habitées VERB acl
# livrés VERB acl
# osent VERB ccomp
# réclamer VERB xcomp
# trouvent VERB conj
# veuillent VERB acl:relcl
# expulser VERB xcomp
# tend VERB acl:relcl
# changer VERB xcomp
# bâtir VERB conj
# sépare VERB ccomp
# modifiera VERB advcl
# est VERB cop
# bâtissant VERB acl
# bordant VERB obj
# pratiquant VERB conj
# écarte VERB advcl
# débarrassent VERB advcl
# met VERB acl:relcl
# ordonne VERB obj
# remontait VERB acl:relcl
# étonnait VERB advcl
# voir VERB xcomp
# végètent VERB acl:relcl
# voient VERB acl:relcl
# voyez VERB acl:relcl
# coulée VERB acl
# affiché VERB acl
# pouvez VERB advcl
# penser VERB xcomp
# recèle VERB ccomp
# partant VERB conj
# acquis VERB conj
# établi VERB acl
# soupçonné VERB acl
# nommait VERB advcl
# vivait VERB conj
# laissait VERB acl:relcl
# aller VERB xcomp
# sauvés VERB acl
# réduits VERB conj
# agissant VERB acl
# remplacé VERB advcl
# entrée VERB conj
# naguère VERB nsubj
# maudissaient VERB advmod
# heureuse VERB conj
# offrit VERB acl:relcl
# demeuraient VERB advcl
# fournis VERB acl
# grouillaient VERB conj
# occupait VERB advcl
# apporté VERB advcl
# reçue VERB advcl
# apparue VERB acl
# forcée VERB acl
# attendre VERB xcomp
# savoir VERB advcl
# allaient VERB ccomp
# acquitta VERB advcl
# enquérant VERB advcl
# pouvait VERB acl:relcl
# connaître VERB xcomp
# sauveriez VERB acl:relcl
# dit VERB acl
# a VERB advcl
# retirer VERB acl
# connaissez VERB obj
# demanda VERB xcomp
# venu VERB acl
# nommé VERB advcl
# mort VERB acl:relcl
# laissant VERB advcl
# mangé VERB conj
# fini VERB conj
# épouser VERB xcomp
# eu VERB acl:relcl
# sort VERB acl:relcl
# avoir VERB aux:tense
# arrivé VERB advcl
# dit VERB acl
# impressionnée VERB acl
# nommée VERB nmod
# quitté VERB xcomp
# venir VERB advcl
# vivre VERB xcomp
# nommé VERB xcomp
# fait VERB acl:relcl
# savent VERB acl:relcl
# lire VERB xcomp
# écrire VERB conj
# dit VERB acl:relcl
# acheté VERB advcl
# épousait VERB advcl
# a VERB advcl
# vivre VERB xcomp
# dit VERB nsubj
# avoir VERB xcomp
# échapperait VERB acl:relcl
# pervertira VERB nsubj
# remercie VERB acl:relcl
# indiqué VERB xcomp
# dit VERB xcomp
# faut VERB conj
# agir VERB xcomp
# rend VERB acl:relcl
# manque VERB conj
# voyez VERB advcl
# quitté VERB dep
# crois VERB dep
# sauver VERB xcomp
# rêvait VERB conj
# tirer VERB xcomp
# parti VERB obj
# faire VERB xcomp
# souvenue VERB conj
# conseillé VERB advcl
# établir VERB obl:arg
# vu VERB advcl
# étions VERB ccomp
# laisse VERB ccomp
# venir VERB xcomp
# mariez VERB conj
# ferez VERB conj
# mariée VERB acl
# échappera VERB acl
# voudrait VERB conj
# tirer VERB advcl
# parti VERB obj
# voir VERB xcomp
# réussir VERB conj
# lancée VERB acl:relcl
# épousée VERB ccomp
# dit VERB ccomp
# crois VERB ccomp
# vouloir VERB advcl
# craint VERB ccomp
# pend VERB acl:relcl
# pouvez VERB obj
# envoyer VERB xcomp
# chercher VERB xcomp
# dit VERB ccomp
# verrais VERB acl:relcl
# saurais VERB obj
# a VERB conj
# fit VERB acl:relcl
# partit VERB acl:relcl
# revint VERB acl
# tenant VERB xcomp
# tenait VERB advcl
# devient VERB acl:relcl
# fournis VERB acl
# ressemblaient VERB acl:relcl
# fait VERB dep
# croire VERB acl:relcl
# promène VERB advcl
# prévenue VERB acl
# entendu VERB acl:relcl
# mis VERB xcomp
# décuplait VERB ccomp
# tenait VERB ccomp
# examinant VERB advcl
# étonnait VERB acl:relcl
# poussa VERB advcl
# voyant VERB advcl
# ramener VERB acl
# nommes VERB acl:relcl
# lire VERB xcomp
# écrire VERB xcomp
# fait VERB conj
# sait VERB advcl
# menée VERB ccomp
# fait VERB acl:relcl
# voulait VERB acl:relcl
# faire VERB xcomp
# ressemblent VERB acl:relcl
# écria VERB advcl
# battait VERB ccomp
# sais VERB obj
# étais VERB conj
# a VERB aux:tense
# parlé VERB xcomp
# écria VERB fixed
# ouvrit VERB conj
# disaient VERB advcl
# dit VERB advcl
# as VERB parataxis
# vu VERB ccomp
# venu VERB advcl
# entrer VERB acl
# vu VERB ccomp
# emmenait VERB ccomp
# arrivait VERB conj
# a VERB obj
# étiez VERB advcl
# appellent VERB ccomp
# est VERB cop
# entendent VERB advmod
# dit VERB conj
# battait VERB acl:relcl
# faisais VERB ccomp
# savais VERB advcl
# commettais VERB ccomp
# quittant VERB advcl
# aller VERB advcl
# vivre VERB xcomp
# regarda VERB acl
# répondit VERB conj
# dit VERB parataxis
# a VERB advcl
# dit VERB acl:relcl
# ignore VERB advcl
# demanda VERB advcl
# essayant VERB advcl
# prendre VERB xcomp
# recula VERB xcomp
# dit VERB parataxis
# voulait VERB advcl
# faire VERB xcomp
# battue VERB acl
# payé VERB parataxis
# donné VERB conj
# emmenée VERB conj
# pleurait VERB ccomp
# fallait VERB conj
# quitter VERB xcomp
# demanda VERB obj
# aimez VERB obj
# aime VERB aux:tense
# dit VERB dep
# crois VERB parataxis
# raconte VERB xcomp
# donné VERB conj
# est VERB fixed
# porte VERB conj
# sais VERB parataxis
# est VERB cop
# avoir VERB advcl
# mange VERB conj
# apporte VERB xcomp
# bon VERB conj
# fais VERB advcl
# veut VERB acl:relcl
# soigne VERB ccomp
# voir VERB xcomp
# dû VERB ccomp
# va VERB ccomp
# prendre VERB xcomp
# soigner VERB advcl
# veut VERB conj
# salisse VERB ccomp
# faire VERB xcomp
# commence VERB advcl
# gagner VERB xcomp
# apporte VERB parataxis
# mets VERB acl:relcl
# veut VERB advcl
# venir VERB advcl
# fait VERB xcomp
# veut VERB acl:relcl
# appelle VERB xcomp
# appelait VERB conj
# sais VERB acl:relcl
# ferais VERB ccomp
# - VERB obj
# fait VERB dep
# dit VERB xcomp
# regardant VERB xcomp
# rougir VERB advcl
# dit VERB ccomp
# étais VERB ccomp
# allez VERB acl
# dit VERB acl:relcl
# pu VERB acl:relcl
# abuser VERB xcomp
# remettre VERB conj
# racheter VERB xcomp
# savais VERB conj
# faisais VERB ccomp
# dit VERB punct
# pensant VERB advcl
# ignore VERB advcl
# connaissez VERB obj
# demanda VERB advcl
# dit VERB ROOT
# crains VERB advcl
# dit VERB advcl
# est VERB punct
# trouvé VERB xcomp
# cache VERB advcl
# voudrais VERB conj
# pût VERB ccomp
# mènerait VERB conj
# dit VERB advcl
# embrassant VERB advcl
# êtes VERB cop
# demanda VERB advcl
# jouait VERB ccomp
# répondit VERB conj
# veulent VERB advcl
# laisser VERB xcomp
# instruire VERB xcomp
# aller VERB conj
# dit VERB advcl
# vais VERB ccomp
# regarda VERB acl
# vois VERB advcl
# rentrée VERB advcl
# dit VERB ccomp
# montrant VERB advcl
# mariée VERB ccomp
# accouplent VERB advmod
# reprit VERB xcomp
# voulez VERB conj
# donner VERB xcomp
# donne VERB acl:relcl
# marier VERB xcomp
# savez VERB dep
# unie VERB advcl
# reprit VERB parataxis
# veut VERB parataxis
# meure VERB advcl
# dit VERB acl
# aurai VERB parataxis
# saviez VERB advcl
# fit VERB advcl
# imitant VERB advcl
# veulent VERB nsubj
# reprit VERB xcomp
# représente VERB acl:relcl
# représente VERB acl:relcl
# consacrent VERB ccomp
# vois VERB nsubj
# mariée VERB xcomp
# demanda VERB acl:relcl
# dit VERB xcomp
# pourra VERB ccomp
# reprocher VERB xcomp
# demande VERB obj
# mariée VERB advcl
# reçu VERB advcl
# regarda VERB xcomp
# demanda VERB acl:relcl
# peut VERB acl:relcl
# donner VERB xcomp
# veux VERB acl:relcl
# protége VERB advcl
# dit VERB ccomp
# tient VERB acl:relcl
# réserve VERB obl:arg
# suivent VERB acl:relcl
# a VERB acl:relcl
# dit VERB acl
# dit VERB ccomp
# peux VERB acl:relcl
# imaginer VERB xcomp
# voit VERB ccomp
# partage VERB conj
# écoutait VERB conj
# écouté VERB xcomp
# voyant VERB conj
# comprendre VERB xcomp
# pensa VERB amod
# fallait VERB ccomp
# prendre VERB xcomp
# adressant VERB advcl
# retourne VERB obj
# irai VERB flat:name
# parler VERB xcomp
# allez VERB ROOT
# vouliez VERB xcomp
# payer VERB xcomp
# doit VERB acl:relcl
# rendrait VERB ccomp
# aura VERB conj
# dit VERB advcl
# irons VERB conj
# vivre VERB xcomp
# fit VERB dep
# tomber VERB xcomp
# revit VERB parataxis
# tirée VERB ccomp
# venait VERB acl:relcl
# donner VERB xcomp
# pourrai VERB obj
# rendre VERB xcomp
# prêtées VERB acl:relcl
# fais VERB advcl
# puiserez VERB ccomp
# apporté VERB acl:relcl
# dit VERB acl
# demande VERB parataxis
# demande VERB obj
# viens VERB xcomp
# voir VERB xcomp
# vit VERB acl:relcl
# veux VERB conj
# marier VERB xcomp
# ah VERB advcl
# fait VERB advcl
# venu VERB acl:relcl
# met VERB xcomp
# crois VERB flat:name
# servi VERB ccomp
# aime VERB advcl
# décoré VERB parataxis
# porte VERB conj
# attend VERB advcl
# refait VERB advcl
# a VERB conj
# crois VERB ccomp
# cache VERB ccomp
# dites VERB acl
# payerai VERB ccomp
# veut VERB advcl
# épouser VERB xcomp
# tenez VERB ccomp
# allons VERB nsubj
# - VERB punct
# sortirent VERB xcomp
# aller VERB advcl
# dit VERB advcl
# montrant VERB advcl
# débouche VERB conj
# aperçut VERB advcl
# garni VERB acl
# vert VERB amod
# permettait VERB acl:relcl
# jeter VERB acl
# porte VERB conj
# ressemblait VERB acl:relcl
# font VERB advcl
# attendre VERB xcomp
# menait VERB punct
# éclairé VERB acl
# dépendait VERB advcl
# aperçut VERB advcl
# acheté VERB acl
# vert VERB amod
# archal VERB xcomp
# annonçaient VERB conj
# prises VERB acl
# déguiser VERB advcl
# dit VERB acl
# vais VERB xcomp
# monter VERB xcomp
# prévenir VERB xcomp
# descendre VERB conj
# baissa VERB advcl
# assit VERB conj
# pesant VERB fixed
# ébranla VERB xcomp
# put VERB ccomp
# retenir VERB xcomp
# perçant VERB acl
# voyant VERB advcl
# voulez VERB acl:relcl
# dit VERB advcl
# hulot VERB obl:arg
# leva VERB aux:tense
# saisit VERB xcomp
# dit VERB conj
# brisée VERB acl
# retrouve VERB acl:relcl
# écria VERB aux:tense
# stupéfait VERB acl
# ferma VERB acl:relcl
# cria VERB dep
# allez VERB obj
# dit VERB punct
# oubliant VERB parataxis
# peux VERB advcl
# revenir VERB xcomp
# as VERB conj
# toucher VERB acl
# morte VERB ROOT
# léguant VERB advcl
# oublié VERB acl:relcl
# va VERB punct
# peux VERB xcomp
# rentrer VERB xcomp
# trouveras VERB conj
# viens VERB amod
# voici VERB parataxis
# cherche VERB acl:relcl
# espérais VERB conj
# rencontrer VERB xcomp
# as VERB ccomp
# recevoir VERB acl
# sors VERB obj
# sors VERB xcomp
# vois VERB acl:relcl
# veux VERB ccomp
# dit VERB xcomp
# pourrai VERB nsubj
# emmener VERB xcomp
# renonce VERB conj
# fais VERB xcomp
# demandé VERB acl:relcl
# promets VERB ccomp
# doter VERB xcomp
# marier VERB xcomp
# instruire VERB xcomp
# dit VERB ccomp
# rendu VERB acl:relcl
# tombe VERB conj
# reprit VERB ccomp
# voulais VERB acl:relcl
# marier VERB dep
# reste VERB xcomp
# dit VERB dep
# vais VERB ccomp
# aller VERB xcomp
# habiller VERB xcomp
# ai VERB acl:relcl
# regarda VERB conj
# fondit VERB acl:relcl
# vivait VERB advcl
# dit VERB ccomp
# sommes VERB conj
# puni VERB advcl
# vint VERB ROOT
# saluer VERB xcomp
# dit VERB acl:relcl
# avancer VERB xcomp
# revint VERB advcl
# prendre VERB acl
# emmener VERB xcomp
# direz VERB advcl
# ajouta VERB xcomp
# veut VERB acl:relcl
# mettre VERB xcomp
# fera VERB acl:relcl
# donnerai VERB parataxis
# a VERB punct
# adore VERB conj
# descendit VERB acl
# avait VERB acl:relcl
# fais VERB dep
# quitter VERB aux:tense
# dit VERB acl
# approché VERB acl:relcl
# as VERB ccomp
# puis VERB conj
# abandonner VERB xcomp
# va VERB ROOT
# trouver VERB xcomp
# réponds VERB conj
# puis VERB cc
# suivre VERB aux:tense
# dit VERB advcl
# conduisant VERB advcl
# redevenu VERB acl
# mis VERB ROOT
# bleu VERB punct
# assise VERB advcl
# fourra VERB advcl
# dit VERB ROOT
# laissez VERB xcomp
# accompagner VERB xcomp
# aller VERB conj
# tenez VERB punct
# ferai VERB conj
# voudrez VERB acl:relcl
# séparez VERB conj
# donne VERB acl:relcl
# vais VERB xcomp
# battue VERB xcomp
# allons VERB nsubj
# dit VERB punct
# faut VERB conj
# quitter VERB xcomp
# répondit VERB ccomp
# tremble VERB conj
# tête VERB amod
# imita VERB conj
# courait VERB acl:relcl
# vint VERB conj
# emportez VERB xcomp
# dit VERB ccomp
# prit VERB xcomp
# emmena VERB conj
# dit VERB xcomp
# prenant VERB advcl
# serrant VERB conj
# changé VERB advcl
# dois VERB xcomp
# souffert VERB xcomp
# parlait VERB advcl
# parlent VERB xcomp
# revoient VERB acl:relcl
# arrivèrent VERB advcl
# trouva VERB acl:relcl
# resté VERB obj
# dit VERB nsubj
# fait VERB obj
# vit VERB conj
# nommée VERB acl
# prenez VERB ccomp
# cherche VERB advcl
# sais VERB obj
# tenu VERB conj
# dit VERB conj
# oublia VERB ccomp
# arriver VERB parataxis
# distingue VERB acl:relcl
# troublé VERB advmod
# survenu VERB acl
# quitté VERB advcl
# revenait VERB ccomp
# dégradée VERB acl
# improvisé VERB acl
# rappela VERB advcl
# fêtez VERB acl:relcl
# prodigue VERB advcl
# dit VERB xcomp
# oublié VERB parataxis
# demanda VERB xcomp
# vit VERB acl:relcl
# lève VERB advcl
# aurons VERB conj
# perdre VERB xcomp
# compte VERB ccomp
# voir VERB ROOT
# lever VERB advcl
# averti VERB advcl
# cernaient VERB conj
# cherchaient VERB parataxis
# suivait VERB acl:relcl
# présenta VERB acl
# demandant VERB acl
# voulait VERB advcl
# payer VERB xcomp
# agissait VERB ccomp
# souscrites VERB acl
# nommé VERB acl
# donné VERB acl:relcl
# pria VERB acl:relcl
# renvoyer VERB acl
# paya VERB conj
# dit VERB parataxis
# luisait VERB acl:relcl
# put VERB conj
# soutenir VERB xcomp
# empira VERB advcl
# condamnée VERB ccomp
# mourir VERB xcomp
# vaincue VERB advcl
# marquée VERB acl
# garda VERB advcl
# eut VERB advcl
# voir VERB acl
# regrettant VERB conj
# mis VERB acl
# ignorait VERB ccomp
# reprit VERB xcomp
# ressembla VERB conj
# rendit VERB advcl
# diminua VERB advcl
# finira VERB xcomp
# dit VERB advcl
# voyant VERB advcl
# témoignait VERB acl:relcl
# racontées VERB acl:relcl
# hâta VERB conj
# bette VERB amod
# mené VERB acl:relcl
# voyant VERB aux:tense
# arrivés VERB advcl
# donnèrent VERB advcl
# logèrent VERB conj
# obtint VERB acl
# léguée VERB acl
# composèrent VERB advcl
# séparée VERB advcl
# hésita VERB conj
# placer VERB xcomp
# fit VERB conj
# faisait VERB advcl
# flânait VERB conj
# pouvoir VERB advcl
# résoudre VERB xcomp
# entreprendre VERB xcomp
# redevenu VERB advcl
# avait VERB parataxis
# consulté VERB acl:relcl
# passa VERB acl:relcl
# mentent VERB acl:relcl
# jouissait VERB acl:relcl
# éclairée VERB acl
# laissait VERB conj
# gérer VERB xcomp
# réduisait VERB conj
# espérant VERB amod
# empêcherait VERB acl:relcl
# retomber VERB xcomp
# comptaient VERB conj
# semblait VERB advmod
# renoncé VERB xcomp
# mise VERB xcomp
# fini VERB advcl
# rassurer VERB xcomp
# jouissait VERB acl:relcl
# revenue VERB acl
# accompagnait VERB ccomp
# reparut VERB acl:relcl
# faisait VERB conj
# prodigue VERB acl
# reconquis VERB advmod
# donnait VERB xcomp
# détruit VERB advcl
# gardé VERB conj
# pouvait VERB acl:relcl
# faire VERB xcomp
# arriva VERB acl:relcl
# portaient VERB advcl
# oubliant VERB advcl
# va VERB advcl
# menait VERB acl:relcl
# dû VERB acl
# forcée VERB acl:relcl
# prendre VERB xcomp
# rendit VERB acl
# occupées VERB acl
# surprendre VERB xcomp
# deviennent VERB conj
# savent VERB advcl
# tourner VERB xcomp
# change VERB ccomp
# prit VERB ccomp
# munie VERB acl
# décida VERB conj
# quitter VERB xcomp
# coiffent VERB acl:relcl
# douée VERB acl
# semblait VERB advcl
# éclater VERB xcomp
# entourait VERB acl:relcl
# dit VERB advcl
# taillée VERB ccomp
# fit VERB ROOT
# appelée VERB acl
# envoie VERB ccomp
# tenta VERB advcl
# servi VERB conj
# sortait VERB acl:relcl
# faire VERB acl
# obtenir VERB conj
# montrât VERB ccomp
# courtisait VERB obj
# voyant VERB acl
# maltraitée VERB xcomp
# plaignit VERB advcl
# envoyée VERB advcl
# finissait VERB acl:relcl
# parachevait VERB conj
# ai VERB conj
# disait VERB advcl
# irai VERB advcl
# resta VERB advcl
# demandé VERB ccomp
# sortir VERB xcomp
# réveillée VERB acl
# trouva VERB advcl
# occupait VERB acl:relcl
# couchaient VERB conj
# convient VERB conj
# attendit VERB acl:relcl
# voir VERB advcl
# revenir VERB xcomp
# croyant VERB xcomp
# monta VERB ROOT
# occupé VERB acl
# couchaient VERB acl:relcl
# attirée VERB conj
# sortait VERB acl:relcl
# entrebâillée VERB xcomp
# murmure VERB obl:mod
# arrêta VERB advcl
# reconnaissant VERB advcl
# séduit VERB acl:relcl
# arrivé VERB acl:relcl
# calculée VERB xcomp
# dire VERB xcomp
# a VERB aux:tense
# vivre VERB xcomp
# veux VERB conj
# pourras VERB advcl
# jeta VERB xcomp
# laissa VERB ccomp
# tomber VERB xcomp
# enfuit VERB conj
# administrée VERB acl
# voyait VERB obj
# entourée VERB xcomp
# expirer VERB advcl
# prit VERB advcl
# pressa VERB advcl
# dit VERB conj
# avais VERB advcl
# donner VERB xcomp
# pourras VERB conj
# faire VERB xcomp
# vit VERB conj
# doit VERB acl:relcl
# sortir VERB acl
# vaincu VERB advcl
# échappa VERB advcl
# entendre VERB advcl
# quitta VERB acl
# apprit VERB ccomp
# célébré VERB acl:relcl
# peuvent VERB ccomp
# opposer VERB xcomp
# peuvent VERB conj
# empêcher VERB xcomp
# dit VERB acl
# popinot VERB punct
# parlait VERB acl:relcl

# %%
for token in doc:
    if token.pos_ == 'NOUN':
        print(token.text, token.pos_, token.dep_)
# Out:
# milieu NOUN obl:mod
# mois NOUN nmod
# juillet NOUN nmod
# année NOUN nmod
# voitures NOUN nmod
# circulation NOUN obl:arg
# places NOUN nmod
# milords NOUN obj
# rue NOUN obj
# université NOUN nmod
# homme NOUN obj
# taille NOUN nmod
# uniforme NOUN nmod
# capitaine NOUN nmod
# garde NOUN nmod
# nombre NOUN nmod
# parisiens NOUN nmod
# habits NOUN obl:mod
# femmes NOUN obl:arg
# goûts NOUN nmod
# impressionnées NOUN advcl
# aspect NOUN obl:mod
# bonnet NOUN nmod
# poil NOUN nmod
# harnais NOUN conj
# physionomie NOUN nsubj
# capitaine NOUN nmod
# légion NOUN obl:arg
# contentement NOUN obj
# teint NOUN obj
# figure NOUN conj
# auréole NOUN obl:mod
# richesse NOUN nsubj
# commerce NOUN obl:mod
# front NOUN obl:arg
# boutiquiers NOUN nmod
# élus NOUN nmod
# adjoint NOUN obj
# arrondissement NOUN nmod
# ruban NOUN nsubj
# légion NOUN nmod
# honneur NOUN nmod
# poitrine NOUN obl:arg
# prussienne NOUN obl:arg
# coin NOUN obl:mod
# milord NOUN nmod
# homme NOUN nmod
# regard NOUN obj
# passants NOUN obl:arg
# sourires NOUN nsubj
# yeux NOUN obl:mod
# milord NOUN nmod
# partie NOUN obl:mod
# rue NOUN nmod
# rue NOUN obl:arg
# bellechasse NOUN nmod
# rue NOUN conj
# bourgogne NOUN nmod
# porte NOUN obl:mod
# maison NOUN nmod
# portion NOUN obl:arg
# cour NOUN nmod
# hôtel NOUN nmod
# jardin NOUN nmod
# hôtel NOUN obj
# forme NOUN obl:mod
# fond NOUN nmod
# cour NOUN nmod
# moitié NOUN nmod
# manière NOUN obl:mod
# capitaine NOUN nsubj
# services NOUN obj
# milord NOUN obl:arg
# gestes NOUN obj
# franche NOUN amod
# lourdeur NOUN obj
# indiscrétion NOUN obj
# acte NOUN nmod
# naissance NOUN nmod
# capitaine NOUN nsubj
# gant NOUN obj
# main NOUN obl:arg
# droite NOUN nmod
# concierge NOUN obl:arg
# perron NOUN obl:arg
# hôtel NOUN nmod
# air NOUN nmod
# portiers NOUN obj
# coup NOUN obj
# œil NOUN nmod
# point NOUN obj
# gens NOUN nsubj
# vêtus NOUN obj
# bleu NOUN obl:arg
# démarche NOUN obl:arg
# rez-de-chaussée NOUN nsubj:pass
# monsieur NOUN obl:mod
# baron NOUN nmod
# ervy NOUN nmod
# commissaire NOUN amod
# ordonnateur NOUN amod
# république NOUN obl:mod
# intendant NOUN obl:mod
# général NOUN amod
# armée NOUN nmod
# directeur NOUN conj
# administrations NOUN amod
# ministère NOUN nmod
# guerre NOUN nmod
# conseiller NOUN obl:mod
# pria NOUN obj
# atala NOUN obj
# direction NOUN obl:arg
# monsieur NOUN nmod
# curé NOUN nmod
# madeleine NOUN nmod
# jour NOUN nmod
# communion NOUN obj
# francs NOUN obj
# dot NOUN nmod
# mari NOUN conj
# brave NOUN nmod
# homme NOUN appos
# fils NOUN nmod
# madame NOUN conj
# ans NOUN obj
# enfant NOUN obj
# baron NOUN obj
# moment NOUN obl:mod
# yeux NOUN obj
# oreille NOUN obl:arg
# femme NOUN nmod
# créature NOUN nmod
# amour NOUN obl:arg
# fond NOUN obj
# larmes NOUN nmod
# milieu NOUN obl:arg
# honnête NOUN nmod
# mœurs NOUN obl:arg
# baron NOUN obj
# femme NOUN obj
# citadine NOUN nmod
# baron NOUN obj
# ervy NOUN nmod
# pantalon NOUN obj
# redingote NOUN conj
# drap NOUN nmod
# gilet NOUN obj
# cravate NOUN obj
# gants NOUN conj
# baronne NOUN nsubj:pass
# fond NOUN obl:arg
# voiture NOUN nmod
# mouvement NOUN obl:arg
# couleuvre NOUN nmod
# madame NOUN nsubj
# père NOUN obl:arg
# vyder NOUN amod
# bienfaiteur NOUN nmod
# choses NOUN nsubj
# baron NOUN obj
# dame NOUN nsubj
# femme NOUN conj
# feuille NOUN obl:arg
# oh NOUN amod
# railleusement NOUN xcomp
# tressaillement NOUN obj
# baronne NOUN nmod
# fumiste NOUN nmod
# judici NOUN obl:arg
# portière NOUN obl:arg
# voiture NOUN nmod
# baronne NOUN nsubj
# fumiste NOUN amod
# bras NOUN obl:mod
# force NOUN obl:arg
# merci NOUN nmod
# sacrifice NOUN nmod
# ami NOUN nmod
# main NOUN obj
# baron NOUN nmod
# joie NOUN obl:mod
# surprise NOUN obj
# fille NOUN obl:mod
# fils NOUN obl:mod
# amants NOUN nsubj
# absence NOUN obl:mod
# choses NOUN nmod
# fois NOUN nmod
# minutes NOUN nmod
# baron NOUN conj
# femme NOUN conj
# rue NOUN obj
# lettre NOUN obj
# monsieur NOUN obj
# baron NOUN nmod
# ervy NOUN nmod
# mois NOUN obj
# rue NOUN nmod
# charonne NOUN obl:arg
# nom NOUN obl:mod
# hector NOUN nmod
# passage NOUN obl:mod
# soleil NOUN nmod
# nom NOUN obl:mod
# vyder NOUN nmod
# écritures NOUN obj
# fille NOUN nsubj
# précautions NOUN obj
# madame NOUN amod
# baron NOUN obj
# intérêt NOUN obl:mod
# comédienne NOUN nsubj
# parole NOUN obj
# retour NOUN obj
# baron NOUN nmod
# transports NOUN nmod
# joie NOUN nmod
# convertirent NOUN acl:relcl
# vie NOUN obl:arg
# famille NOUN nmod
# atala NOUN obj
# excès NOUN dep
# passion NOUN nmod
# mobilité NOUN obl:arg
# sensations NOUN nmod
# enfance NOUN obj
# bonheur NOUN obj
# famille NOUN nmod
# changement NOUN obl:agent
# baron NOUN obl:mod
# enfants NOUN obj
# voûté NOUN obj
# physionomie NOUN obj
# dîner NOUN nsubj
# célestine NOUN obl:agent
# dîners NOUN obj
# cantatrice NOUN nmod
# vieillard NOUN nmod
# étourdi NOUN obl:mod
# cuisinier NOUN amod
# louise NOUN nsubj
# femme NOUN obj
# chambre NOUN nmod
# comtesse NOUN nmod
# sort NOUN obl:arg
# prétexte NOUN obl:mod
# chef NOUN nsubj
# plat NOUN obj
# sauce NOUN obj
# chance NOUN dep
# maison NOUN obl:mod
# fois NOUN obj
# nuit NOUN obj
# bruit NOUN obl:agent
# lit NOUN obl:mod
# sien NOUN obl:arg
# lits NOUN obl:arg
# vieillards NOUN obl:arg
# heure NOUN obj
# baron NOUN obj
# prise NOUN amod
# peur NOUN nmod
# catastrophe NOUN obl:arg
# étage NOUN obl:mod
# mansardes NOUN obl:agent
# chambre NOUN obl:mod
# lumière NOUN nmod
# porte NOUN obl:agent
# voix NOUN nmod
# voix NOUN nsubj
# baron NOUN nmod
# charmes NOUN obl:agent
# atroce NOUN obl:arg
# paroles NOUN obj
# femme NOUN nsubj
# - NOUN obl:mod
# temps NOUN obl:arg
# baronne NOUN nsubj
# cri NOUN obj
# bougeoir NOUN obj
# jours NOUN nmod
# baronne NOUN obl:mod
# veille NOUN obl:mod
# agonie NOUN obl:arg
# famille NOUN obl:agent
# larmes NOUN obl:mod
# moment NOUN obl:mod
# main NOUN obj
# mari NOUN obl:arg
# oreille NOUN obl:arg
# ami NOUN obj
# vie NOUN dep
# moment NOUN obl:mod
# baronne NOUN obj
# larmes NOUN nsubj
# yeux NOUN obl:arg
# morte NOUN obl:arg
# férocité NOUN obj
# vice NOUN nmod
# patience NOUN obj
# ange NOUN nmod
# bord NOUN obl:mod
# éternité NOUN nmod
# mot NOUN obj
# reproche NOUN nmod
# vie NOUN obl:arg
# baron NOUN obj
# jours NOUN obl:arg
# enterrement NOUN obl:mod
# femme NOUN nmod
# mois NOUN nmod
# victorin NOUN nsubj
# mariage NOUN obj
# père NOUN nmod
# mademoiselle NOUN nmod
# isigny NOUN obl:arg
# février NOUN obj
# ancêtres NOUN nsubj
# mariage NOUN obl:arg
# enfants NOUN nmod
# enfants NOUN nsubj
# folies NOUN obj
# ancêtres NOUN obl:arg
# enfance NOUN nmod
# maître NOUN xcomp
# maître NOUN nmod
# fils NOUN obj
# ministre NOUN nmod
# commerce NOUN nmod
# mariage NOUN obl:arg

# %%
# See Keyword in context 
import re
context = re.findall(r'.{0,50}\blampe.{0,80}|.{0,50}\blustre.{0,80}', text)
context

for sent in context:
    doc2 = nlp(sent)
    for token in doc2:
        if 'VERB' in token.pos_:
            print(token.text, token.pos_, token.dep_)
        elif token.pos_ == 'NOUN':
            print(token.text, token.pos_, token.dep_)
    print ('*'*15)
# Out:
# madame NOUN nsubj
# dit VERB ROOT
# montrait VERB conj
# lampe NOUN obj
# lustre NOUN nmod
# dédoré VERB acl
# cordes NOUN nmod
# tapis NOUN nmod
# haillons NOUN dep
# opulence NOUN nmod
# faisa VERB acl:relcl
# ***************
# plâtre NOUN nmod
# jouant VERB acl
# bronze NOUN obj
# lustre NOUN obj
# mis VERB xcomp
# couleur NOUN obl:arg
# bobèches NOUN obl:arg
# cristal NOUN obl:mod
# fondu VERB ROOT
# tapis NOUN obj
# ***************
# trouva VERB ROOT
# travaillant VERB xcomp
# lueur NOUN obl:arg
# lampe NOUN nmod
# clarté NOUN nsubj
# augmentait VERB acl:relcl
# passant VERB advcl
# travers NOUN fixed
# globe NOUN obl:arg
# eau NOUN nmod
# héros NOUN nmod
# ***************
# aidé VERB ROOT
# femme NOUN obj
# nettoyer VERB xcomp
# meubles NOUN obj
# rendre VERB acl
# lustre NOUN obl:arg
# objets NOUN obl:mod
# savonnant NOUN acl
# brossant VERB advcl
# époussetant VERB advcl
# ***************
# dustrie NOUN obl:mod
# flambeaux NOUN nmod
# bras NOUN nmod
# lustre NOUN nsubj
# pendule NOUN nmod
# appartenaient VERB ROOT
# genre NOUN obl:arg
# table NOUN obj
# milieu NOUN nmod
# ***************
# flambeaux NOUN obl:mod
# suivant VERB ROOT
# mariette NOUN obj
# portait VERB acl:relcl
# lampe NOUN obj
# salle NOUN nmod
# manger VERB acl
# chambre NOUN obl:mod
# coucher VERB nmod
# moment NOUN obl:mod
# victorin NOUN advmod
# ***************
# bricant VERB ROOT
# exploite NOUN nsubj
# coûte VERB ccomp
# cents NOUN nsubj
# francs NOUN conj
# lustre NOUN nmod
# boule NOUN nmod
# monte VERB xcomp
# vente NOUN obl:mod
# francs NOUN obl:mod
# lustr NOUN obj
# ***************
# vec NOUN dep
# glace NOUN obj
# encadrée VERB acl
# style NOUN obl:mod
# lampe NOUN nsubj
# plafond NOUN nmod
# donnait VERB ROOT
# demi-jour NOUN obj
# accru VERB acl
# bougies NOUN obl:mod
# table NOUN nmod
# ***************

# %% [markdown]
# # Keyword in context and N-grams
#
# Source: https://programminghistorian.org/en/lessons/keywords-in-context-using-n-grams#from-text-to-n-grams

# %%
# Given a list of words and a number n, return a list
# of n-grams.

def getNGrams(wordlist, n):
    return [wordlist[i:i+n] for i in range(len(wordlist)-(n-1))]

stopwords = open(r'C:\Users\lakj\Documents\GitHub\Lighting in French Literature\data\stopwords\fr_stopwords.txt','r', encoding='utf-8-sig').read().split('\n')
text = ' '.join(df[df['author'] == 'Balzac']['clean_text'])
wordlist = re.findall(r'\b\S+\b', text)
wordlist_filtered = [w for w in wordlist if w not in stopwords]

bigrams = getNGrams(wordlist_filtered, 3)

words = ['lumière', 'clarté']

bi_grams_filtered = []
for i in words:
    bi_grams  = [w for w in bigrams if i in w]
    bi_grams_filtered.append(bi_grams)
    
    
bi_grams_filtered = [x for y in bi_grams_filtered for x in y]
bi_grams_filtered
# Out:
# [['cabaret', 'malpropre', 'lumière'],
#  ['malpropre', 'lumière', 'boutique'],
#  ['lumière', 'boutique', 'lingère'],
#  ['matérielles', 'l’air', 'lumière'],
#  ['l’air', 'lumière', 'locaux'],
#  ['lumière', 'locaux', 'moraliste'],
#  ['attestaient', 'force', 'lumière'],
#  ['force', 'lumière', 'entrait'],
#  ['lumière', 'entrait', 'fois'],
#  ['noir', 'rouge', 'lumière'],
#  ['rouge', 'lumière', 'buste'],
#  ['lumière', 'buste', 'd’athlète'],
#  ['hasard', 'rayonne', 'lumière'],
#  ['rayonne', 'lumière', 'divine'],
#  ['lumière', 'divine', 'venu'],
#  ['racines', 'perdues', 'lumière'],
#  ['perdues', 'lumière', 'glissant'],
#  ['lumière', 'glissant', 'sillon'],
#  ['naissais', 'vie', 'lumière'],
#  ['vie', 'lumière', 'milieu'],
#  ['lumière', 'milieu', 'acclamations'],
#  ['fut', 'illuminé', 'lumière'],
#  ['illuminé', 'lumière', 'intérieure'],
#  ['lumière', 'intérieure', 'voyant'],
#  ['peyrade', 'mit', 'lumière'],
#  ['mit', 'lumière', 'fenêtre'],
#  ['lumière', 'fenêtre', 'chose'],
#  ['obtenir', 'moindre', 'lumière'],
#  ['moindre', 'lumière', 'sujet'],
#  ['lumière', 'sujet', 'boueux'],
#  ['attiraient', 'sobrement', 'lumière'],
#  ['sobrement', 'lumière', 'maintenant'],
#  ['lumière', 'maintenant', 'pouvez'],
#  ['regards', 'atmosphère', 'lumière'],
#  ['atmosphère', 'lumière', 'parfaitement'],
#  ['lumière', 'parfaitement', 'harmonie'],
#  ['voûtées', 'formidables', 'lumière'],
#  ['formidables', 'lumière', 'tournent'],
#  ['lumière', 'tournent', 'autour'],
#  ['venait', 'faible', 'lumière'],
#  ['faible', 'lumière', 'dit'],
#  ['lumière', 'dit', 'sûreté'],
#  ['peintres', 'besoin', 'lumière'],
#  ['besoin', 'lumière', 'égale'],
#  ['lumière', 'égale', 'pure'],
#  ['interrogent', 'exposée', 'lumière'],
#  ['exposée', 'lumière', 'd’eux'],
#  ['lumière', 'd’eux', 'bout'],
#  ['émanation', 'âme', 'lumière'],
#  ['âme', 'lumière', 'soleil'],
#  ['lumière', 'soleil', 'enfin'],
#  ['dernier', 'trait', 'lumière'],
#  ['trait', 'lumière', 'juge'],
#  ['lumière', 'juge', 'avez'],
#  ['général', 'entra', 'lumière'],
#  ['entra', 'lumière', 'dit-elle'],
#  ['lumière', 'dit-elle', 'garçon'],
#  ['regard', 's’empreint', 'lumière'],
#  ['s’empreint', 'lumière', 'l’air'],
#  ['lumière', 'l’air', 'éléments'],
#  ['revint', 'trait', 'lumière'],
#  ['trait', 'lumière', 'aperçut'],
#  ['lumière', 'aperçut', 'parti'],
#  ['voyais', 'impossible', 'lumière'],
#  ['impossible', 'lumière', 'l’éclairait'],
#  ['lumière', 'l’éclairait', 'bonheur'],
#  ['théâtre', 'mariette', 'lumière'],
#  ['mariette', 'lumière', 'conduite'],
#  ['lumière', 'conduite', 'transpira'],
#  ['atelier', 'portait', 'lumière'],
#  ['portait', 'lumière', 'papillotait'],
#  ['lumière', 'papillotait', 'bas-reliefs'],
#  ['rues', 'répandit', 'lumière'],
#  ['répandit', 'lumière', 'maisons'],
#  ['lumière', 'maisons', 'conta'],
#  ['bonnet', 'coton', 'lumière'],
#  ['coton', 'lumière', 'main'],
#  ['lumière', 'main', 's’interrogeant'],
#  ['espérant', 'saisir', 'lumière'],
#  ['saisir', 'lumière', 'énormités'],
#  ['lumière', 'énormités', 'imputées'],
#  ['point', 'déjà', 'lumière'],
#  ['déjà', 'lumière', 'plan'],
#  ['lumière', 'plan', 'êtes'],
#  ['éclairée', 'trait', 'lumière'],
#  ['trait', 'lumière', 'aperçut'],
#  ['lumière', 'aperçut', 'torts'],
#  ['génie', 'éclatait', 'lumière'],
#  ['éclatait', 'lumière', 'eut'],
#  ['lumière', 'eut', 'puissance'],
#  ['pouvait', 'coucher', 'lumière'],
#  ['coucher', 'lumière', 'soyez'],
#  ['lumière', 'soyez', 'tranquille'],
#  ['éclair', 'jet', 'lumière'],
#  ['jet', 'lumière', 'accompagné'],
#  ['lumière', 'accompagné', 'd’un'],
#  ['revenons', 'verrez', 'lumière'],
#  ['verrez', 'lumière', 'croisée'],
#  ['lumière', 'croisée', 'entendant'],
#  ['t’a', 'parlé', 'lumière'],
#  ['parlé', 'lumière', 'fenêtre'],
#  ['lumière', 'fenêtre', 'bonhomme'],
#  ['d’un', 'trait', 'lumière'],
#  ['trait', 'lumière', 'oui'],
#  ['lumière', 'oui', 'puis'],
#  ['vertu', 'céleste', 'lumière'],
#  ['céleste', 'lumière', 'balayé'],
#  ['lumière', 'balayé', 'l’impureté'],
#  ['banque', 'torrents', 'lumière'],
#  ['torrents', 'lumière', 'produisaient'],
#  ['lumière', 'produisaient', 'cascades'],
#  ['resplendir', 'nappes', 'lumière'],
#  ['nappes', 'lumière', 'épaules'],
#  ['lumière', 'épaules', 'rivales'],
#  ['lactée', 'renvoyait', 'lumière'],
#  ['renvoyait', 'lumière', 'eussiez'],
#  ['lumière', 'eussiez', 'dit'],
#  ['d’agathe', 'autant', 'lumière'],
#  ['autant', 'lumière', 'sortait'],
#  ['lumière', 'sortait', 'porte'],
#  ['beauté', 'dépendait', 'lumière'],
#  ['dépendait', 'lumière', 'venait'],
#  ['lumière', 'venait', 'colorer'],
#  ['pouvait', 'venir', 'lumière'],
#  ['venir', 'lumière', 'crut'],
#  ['lumière', 'crut', 'hasard'],
#  ['fraisier', 'aurez', 'lumière'],
#  ['aurez', 'lumière', 'n’est-ce'],
#  ['lumière', 'n’est-ce', 'bougie'],
#  ['yeux', 'peuples', 'lumière'],
#  ['peuples', 'lumière', 'chef-d’œuvre'],
#  ['lumière', 'chef-d’œuvre', 'dieu'],
#  ['aperçut', 'faible', 'clarté'],
#  ['faible', 'clarté', 'vie'],
#  ['clarté', 'vie', 'ténébreuse'],
#  ['autant', 'instruction', 'clarté'],
#  ['instruction', 'clarté', 'dénoûement'],
#  ['clarté', 'dénoûement', 'histoire'],
#  ['nommons-les', 'prénoms', 'clarté'],
#  ['prénoms', 'clarté', 'histoire'],
#  ['clarté', 'histoire', 'l’un'],
#  ['petite', 'lampe', 'clarté'],
#  ['lampe', 'clarté', 's’augmentait'],
#  ['clarté', 's’augmentait', 'passant'],
#  ['continuer', 'figurer', 'clarté'],
#  ['figurer', 'clarté', 'récit'],
#  ['clarté', 'récit', 'voulez'],
#  ['avez', 'mérite', 'clarté'],
#  ['mérite', 'clarté', 'regarde'],
#  ['clarté', 'regarde', 'êtes']]
